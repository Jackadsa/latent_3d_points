# %% [markdown]
# ## This notebook will help you train a vanilla Point-Cloud AE with the basic architecture we used in our paper.
#     (it assumes latent_3d_points is in the PYTHONPATH and the structural losses have been compiled)

# %%
import os.path as osp



import sys
sys.path.append('/home/jcollins')

from latent_3d_points.src.ae_templates import mlp_architecture_ala_iclr_18, default_train_params, \
                                              jack_vae_template_3,jack_vae_template_1_bnormtest, jack_2_template
from latent_3d_points.src.autoencoder import VAEConfiguration as Conf
from latent_3d_points.src.point_net_ae import PointNetAutoEncoder, PointNetVarAutoEncoder

from latent_3d_points.src.in_out import snc_category_to_synth_id, create_dir, PointCloudDataSet, \
                                        load_all_point_clouds_under_folder

from latent_3d_points.src.encoders_decoders_vae import variational_encoder_with_convs_and_symmetry,decoder_with_convs_and_fc
    
from latent_3d_points.src.tf_utils import reset_tf_graph
from latent_3d_points.src.general_utils import plot_3d_point_cloud

from latent_3d_points.src.tf_sinkhorn import ground_distance_tf, sinkhorn_knopp_tf, sinkhorn_loss_tf

import gc

import os
print("Working on GPU: ",os.environ['CUDA_VISIBLE_DEVICES'])

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True
sess = tf.Session(config=config)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import ot
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ('Working on GPU: ', '1')

# %% [markdown]
# Define Basic Parameters

# %%
top_out_dir = '../data/'          # Use to save Neural-Net check-points etc.
top_in_dir = '../data/shape_net_core_uniform_samples_2048/' # Top-dir of where point-clouds are stored.

experiment_name = 'vae_bneck-100-pot-tf-11-bnorm'
train_dir = create_dir(osp.join(top_out_dir, experiment_name))
n_pc_points = 500                # Number of points per model.
bneck_size = 256                 # Bottleneck-AE size
ae_loss = 'emd'                   # Loss to optimize: 'emd' or 'chamfer'

# %% [markdown]
# Load Point-Clouds

# %%
import pandas as pd
numjets = 500000
numvalid = 50000
outstore = pd.HDFStore("/data1/users/jcollins/Heidelberg_sample/train_vecs_top_uncentered_normalized_test.h5")
rawdata = outstore.select("points",stop=numjets).values
rawdata = rawdata.reshape(numjets,100,3)
validdata = outstore.select("points",start=numjets,stop=numjets+numvalid).values
validdata = validdata.reshape(numvalid,100,3)
all_pc_data = PointCloudDataSet(rawdata,copy=False)
valid_pc_data = PointCloudDataSet(validdata,copy=False)

# %% [markdown]
# Load default training parameters (some of which are listed beloq). For more details please print the configuration object.
#
#     'batch_size': 50
#
#     'denoising': False     (# by default AE is not denoising)
#
#     'learning_rate': 0.0005
#
#     'z_rotate': False      (# randomly rotate models of each batch)
#
#     'loss_display_step': 1 (# display loss at end of these many epochs)
#     'saver_step': 10       (# over how many epochs to save neural-network)

# %%
train_params = default_train_params()
train_params['saver_step'] = 2

def vae_template(bneck_size, bneck_post_mlp=False):
    ''' Single class experiments.
    '''
#     if n_pc_points != 2048:
#         raise ValueError()

    encoder = variational_encoder_with_convs_and_symmetry
    decoder = decoder_with_convs_and_fc

    n_input = [100, 3]
    n_output = [500,2]

    encoder_args = {'n_filters': [256, 256, 256],
                    'filter_sizes': [1],
                    'strides': [1],
                    'b_norm': True,
                    'verbose': True,
                    'symmetry': tf.reduce_mean,
                    'fully_connected_layers': [256,256,256],
                    'latent_size':bneck_size,
                    'bnorm_momentum':0.99,
                    'bnorm_clipping':{'rmin':1/5,'rmax':5,'dmax':5}
                    }

    decoder_args = {'n_filters': [256,256,256,2],
                    'filter_sizes': [4,2,2,1],
                    'strides': [1],
                    'upsample_sizes': [2,2,None,None],
                    'b_norm': True,
                    'b_norm_finish': True,
                    'verbose': True,
                    'fully_connected_layers': [256,256,125*8],
                    'reshape_last_connected': [125,8],
                    'bnorm_momentum':0.99,
                    'bnorm_clipping':{'rmin':1/5,'rmax':5,'dmax':5}
                    }

    if bneck_post_mlp:
        encoder_args['n_filters'].pop()
        decoder_args['layer_sizes'][0] = bneck_size

    return encoder, decoder, encoder_args, decoder_args

encoder, decoder, enc_args, dec_args = vae_template(bneck_size)

# %% [markdown]
# Build AE Model.

# %% [markdown]
# Train the AE (save output to train_stats.txt)

# %% [markdown]
# If you ran the above lines, you can reload a saved model like this:

# %%
load_pre_trained_ae = True
restore_epoch = 130
if load_pre_trained_ae:
    conf = Conf.load(train_dir + '/configuration')
    conf.sinkhorn_reg = 0.01
    conf.close_with_tanh=False
    conf.encoder_args['bnorm_clipping']={'rmin':1/3,'rmax':3,'dmax':5}
    conf.decoder_args['bnorm_clipping']={'rmin':1/3,'rmax':3,'dmax':5}
    conf.encoder_args['bnorm_momentum']=0.9999
    conf.decoder_args['bnorm_momentum']=0.9999
    reset_tf_graph()
    ae = PointNetVarAutoEncoder(conf.experiment_name, conf)
    ae.restore_model(conf.train_dir, epoch=restore_epoch)
# Out:
# Building Encoder
# encoder_conv_layer_0 conv params =  1024
# Tensor("Relu:0", shape=(?, 100, 256), dtype=float32)
# output size: 25600
#
# encoder_conv_layer_1 conv params =  65792
# Tensor("Relu_1:0", shape=(?, 100, 256), dtype=float32)
# output size: 25600
#
# encoder_conv_layer_2 conv params =  65792
# Tensor("Relu_2:0", shape=(?, 100, 256), dtype=float32)
# output size: 25600
#
# Symmetry Layer:
# Tensor("Mean:0", shape=(?, 256), dtype=float32)
#
# encoder_dense_layer_0 FC params =  65792 Tensor("Relu_3:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# encoder_dense_layer_1 FC params =  65792 Tensor("Relu_4:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# encoder_dense_layer_2 FC params =  65792 Tensor("encoder_dense_layer_2_bnorm/batchnorm/add_1:0", shape=(?, 256), dtype=float32)
# output size: 256
#
# [<tf.Tensor 'z_mean/BiasAdd:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'z_log_var/BiasAdd:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'z/add_1:0' shape=(?, 256) dtype=float32>]
# Building Decoder
# decoder_fc_0 FC params =  131584 Tensor("vae_bneck-100-pot-tf-11-bnorm_2/Relu:0", shape=(?, 512), dtype=float32)
# output size: 512
#
# decoder_fc_1 FC params =  525312 Tensor("vae_bneck-100-pot-tf-11-bnorm_2/Relu_1:0", shape=(?, 1024), dtype=float32)
# output size: 1024
#
# decoder_fc_2 FC params =  1049600 Tensor("vae_bneck-100-pot-tf-11-bnorm_2/Relu_2:0", shape=(?, 1024), dtype=float32)
# output size: 1024
#
# decoder_fc_3 FC params =  1025000 Tensor("vae_bneck-100-pot-tf-11-bnorm_2/Reshape/Reshape:0", shape=(?, 500, 2), dtype=float32)
# output size: 1000
#
# INFO:tensorflow:Restoring parameters from ../data/vae_bneck-100-pot-tf-11-bnorm/models.ckpt-130

# %% [markdown]
# Get a batch of reconstuctions and their latent-codes.

# %% [markdown]
# Use any plotting mechanism such as matplotlib to visualize the results.

# %%
all_pc_data._index_in_epoch = 0
for i in range(5000):
    feed_pc, feed_model_names, _ = all_pc_data.next_batch(100)
    loss1, recon1, latent1 = ae.sess.run((ae.loss, ae.x_reconstr, ae.encoder), feed_dict={ae.x: feed_pc, ae.beta: [conf.beta]})
    loss1b, recon1b, latent1b = ae.sess.run((ae.loss, ae.x_reconstr, ae.encoder), feed_dict={ae.x: feed_pc, ae.beta: [conf.beta]})
    _, latent, loss, match, ground_distance, ground_grad, recon = ae.sess.run((ae.train_step, ae.encoder, ae.loss, ae.match, ae.ground_distance, ae.ground_grad,ae.x_reconstr), feed_dict={ae.x: feed_pc, ae.beta: [conf.beta]})
    loss2, recon2, latent2 = ae.sess.run((ae.loss, ae.x_reconstr, ae.encoder), feed_dict={ae.x: feed_pc, ae.beta: [conf.beta]})
    print(i,loss1, loss,
          loss2)
    if loss > 10:
        break
# Out:
# (0, 0.12855184, 0.12848285, 0.12889625)
# (1, 0.13519284, 0.13483474, 0.13331999)
# (2, 0.1293637, 0.12934919, 0.12636003)
# (3, 0.124447554, 0.124649264, 0.12633902)
# (4, 0.13232268, 0.13231564, 0.13371749)
# (5, 0.13419493, 0.13408412, 0.13010594)
# (6, 0.11945775, 0.11933452, 0.12027311)
# (7, 0.13264187, 0.13015524, 0.13145745)
# (8, 0.13182332, 0.13180417, 0.12770323)
# (9, 0.1347645, 0.13468562, 0.13229157)
# (10, 0.12923346, 0.12920652, 0.1288546)
# (11, 0.13261391, 0.13240021, 0.12884192)
# (12, 0.12827058, 0.12939687, 0.1285871)
# (13, 0.12944937, 0.12925836, 0.1281621)
# (14, 0.1265506, 0.12653305, 0.12518814)
# (15, 0.12210564, 0.12250875, 0.12101427)
# (16, 0.12526864, 0.12555951, 0.12482658)
# (17, 0.12773483, 0.12772463, 0.1270484)
# (18, 0.1300678, 0.12990928, 0.12897396)
# (19, 0.12859444, 0.12849988, 0.12683745)
# (20, 0.1287876, 0.12884428, 0.12753786)
# (21, 0.12583633, 0.12587297, 0.12461978)
# (22, 0.12639923, 0.1502899, 0.12802415)
# (23, 0.12323226, 0.12319105, 0.122842185)
# (24, 0.14294536, 0.14188564, 0.13028117)
# (25, 0.12758403, 0.12745345, 0.12524833)
# (26, 0.12685187, 0.12673612, 0.12509581)
# (27, 0.12714434, 0.1272857, 0.12546065)
# (28, 0.12940551, 0.12937766, 0.1303531)
# (29, 0.12519827, 0.12516509, 0.123931676)
# (30, 0.12936722, 0.12934536, 0.12717018)
# (31, 0.13127355, 0.1311296, 0.12973487)
# (32, 0.12538204, 0.12561694, 0.12527505)
# (33, 0.13064207, 0.13053495, 0.13003965)
# (34, 0.12581483, 0.12555622, 0.1230081)
# (35, 0.122179136, 0.12231904, 0.120653875)
# (36, 0.12563546, 0.1256227, 0.12495777)
# (37, 0.12791663, 0.12794906, 0.12634149)
# (38, 0.12763295, 0.12766464, 0.12553743)
# (39, 0.13142984, 0.13126981, 0.13094324)
# (40, 0.13055378, 0.13073869, 0.12989789)
# (41, 0.12729189, 0.12736157, 0.12690483)
# (42, 0.12759957, 0.12769388, 0.1261993)
# (43, 0.13234141, 0.13241181, 0.13140811)
# (44, 0.12698542, 0.1271484, 0.12527272)
# (45, 0.13016003, 0.1302023, 0.1286981)
# (46, 0.12628138, 0.12630716, 0.12545636)
# (47, 0.12645426, 0.12659729, 0.12629674)
# (48, 0.1317717, 0.13186769, 0.13001452)
# (49, 0.12810417, 0.12803696, 0.12677474)
# (50, 0.12783504, 0.12785263, 0.12648396)
# (51, 0.12673116, 0.12677334, 0.1255669)
# (52, 0.12718612, 0.12736614, 0.12538978)
# (53, 0.12541446, 0.12526877, 0.124549024)
# (54, 0.12776697, 0.12778583, 0.12656157)
# (55, 0.12611575, 0.12609416, 0.12446973)
# (56, 0.1256999, 0.1256722, 0.12501642)
# (57, 0.13455826, 0.13452843, 0.13358182)
# (58, 0.13064304, 0.13077563, 0.12986016)
# (59, 0.14100982, 0.14099373, 0.13973826)
# (60, 0.12888071, 0.12901825, 0.12802412)
# (61, 0.13092466, 0.13089456, 0.1293354)
# (62, 0.12559962, 0.12574035, 0.12608223)
# (63, 0.13206322, 0.13218996, 0.13106148)
# (64, 0.12939234, 0.12928289, 0.12792784)
# (65, 0.13325164, 0.1332485, 0.13120346)
# (66, 0.12822546, 0.1281914, 0.12591419)
# (67, 0.13119158, 0.13130827, 0.12892349)
# (68, 0.12830783, 0.12824295, 0.12724514)
# (69, 0.12657043, 0.12661678, 0.1252885)
# (70, 0.12672399, 0.12668134, 0.12528165)
# (71, 0.1314266, 0.13148805, 0.13047378)
# (72, 0.12673007, 0.12697221, 0.124945134)
# (73, 0.12571627, 0.12578595, 0.12528796)
# (74, 0.1243387, 0.124339625, 0.12371081)
# (75, 0.12978913, 0.12980366, 0.12854418)
# (76, 0.13205361, 0.13192727, 0.13127375)
# (77, 0.13155136, 0.13157868, 0.13073538)
# (78, 0.13019735, 0.1301635, 0.12911397)
# (79, 0.12879147, 0.12873831, 0.12811163)
# (80, 0.12820852, 0.12804815, 0.12599018)
# (81, 0.12960902, 0.12962177, 0.12804699)
# (82, 0.12401994, 0.124019615, 0.1231543)
# (83, 0.12503612, 0.12519468, 0.1235948)
# (84, 0.13463059, 0.1345973, 0.13342677)
# (85, 0.12941583, 0.12951174, 0.12771776)
# (86, 0.12645674, 0.12652878, 0.12481701)
# (87, 0.12487382, 0.12501752, 0.12413871)
# (88, 0.12803024, 0.12790295, 0.12634456)
# (89, 0.13721712, 0.14107752, 0.13081326)
# (90, 0.12763321, 0.12781072, 0.12695317)
# (91, 0.13435988, 0.14271049, 0.13071057)
# (92, 0.12786369, 0.12794262, 0.12595236)
# (93, 0.12773547, 0.12760688, 0.12554677)
# (94, 0.13615142, 0.1362335, 0.13545401)
# (95, 0.13325502, 0.13337839, 0.13125715)
# (96, 0.12873854, 0.1287893, 0.12840012)
# (97, 0.12790956, 0.12775153, 0.12746096)
# (98, 0.1297352, 0.12960017, 0.129477)
# (99, 0.12873748, 0.12872645, 0.12681076)
# (100, 0.13019729, 0.13012427, 0.12828878)
# (101, 0.12513688, 0.12489103, 0.12378225)
# (102, 0.12874468, 0.12888949, 0.12738024)
# (103, 0.12964542, 0.12932914, 0.12855075)
# (104, 0.1294948, 0.12944512, 0.12775043)
# (105, 0.13111323, 0.13133538, 0.12879753)
# (106, 0.1314869, 0.13152128, 0.12998182)
# (107, 0.13123958, 0.13136594, 0.12978768)
# (108, 0.1270379, 0.12703064, 0.12546983)
# (109, 0.12488204, 0.12497079, 0.12383833)
# (110, 0.12583327, 0.12567861, 0.12596522)
# (111, 0.13145986, 0.13155943, 0.13103426)
# (112, 0.13262336, 0.13269907, 0.1304082)
# (113, 0.13182922, 0.13182333, 0.13098383)
# (114, 0.13503657, 0.13500315, 0.1346206)
# (115, 0.1354925, 0.13559493, 0.13317566)
# (116, 0.12397672, 0.124104455, 0.124231935)
# (117, 0.13243109, 0.13230805, 0.1296268)
# (118, 0.12868303, 0.12867089, 0.12764451)
# (119, 0.120836124, 0.12091659, 0.120612524)
# (120, 0.13271698, 0.13250878, 0.130315)
# (121, 0.12780274, 0.12780714, 0.12686917)
# (122, 0.12841819, 0.12853096, 0.12696426)
# (123, 0.1304327, 0.13052414, 0.12855403)
# (124, 0.13026145, 0.13030066, 0.13015962)
# (125, 0.12833455, 0.12837473, 0.12695333)
# (126, 0.12974326, 0.12965679, 0.12816134)
# (127, 0.12902729, 0.12892924, 0.12706354)
# (128, 0.13014795, 0.12622525, 0.12775306)
# (129, 0.1326469, 0.13268743, 0.1319088)
# (130, 0.12744156, 0.12744547, 0.12401567)
# (131, 0.12400089, 0.123975456, 0.12321476)
# (132, 0.13228332, 0.1323888, 0.1329191)
# (133, 0.13000827, 0.12981765, 0.12927777)
# (134, 0.12431155, 0.12438861, 0.12275964)
# (135, 0.1284654, 0.12829557, 0.12653431)
# (136, 0.13112164, 0.13077575, 0.13061413)
# (137, 0.12553303, 0.12568712, 0.12382533)
# (138, 0.13219187, 0.13210039, 0.12966295)
# (139, 0.13071506, 0.13087258, 0.1299274)
# (140, 0.12815627, 0.12825695, 0.129172)
# (141, 0.13073547, 0.13060932, 0.12867048)
# (142, 0.1278786, 0.12784296, 0.12748127)
# (143, 0.12853959, 0.12860377, 0.12853079)
# (144, 0.12907802, 0.12920813, 0.12758003)
# (145, 0.13137585, 0.13141428, 0.13125238)
# (146, 0.13353357, 0.13349661, 0.13174671)
# (147, 0.12772615, 0.1275502, 0.12624413)
# (148, 0.12920983, 0.12931854, 0.1304035)
# (149, 0.13441235, 0.13454254, 0.1314901)
# (150, 0.12848057, 0.12851036, 0.12761423)
# (151, 0.1299927, 0.12989071, 0.13076608)
# (152, 0.13084972, 0.13087477, 0.1273238)
# (153, 0.13008821, 0.1300658, 0.13106534)
# (154, 0.12899363, 0.12907743, 0.12951425)
# (155, 0.13568774, 0.13574785, 0.13149188)
# (156, 0.12503621, 0.12504807, 0.12681031)
# (157, 0.13579026, 0.13573015, 0.13707063)
# (158, 0.13380012, 0.13375767, 0.12918752)
# (159, 0.12214191, 0.122047275, 0.12355959)
# (160, 0.12853941, 0.12860513, 0.13095866)
# (161, 0.13247803, 0.13221548, 0.12888978)
# (162, 0.13009799, 0.13029812, 0.12989706)
# (163, 0.1274941, 0.12767078, 0.12905833)
# (164, 0.1289824, 0.12888312, 0.12603699)
# (165, 0.13124955, 0.1312387, 0.13114318)
# (166, 0.13001743, 0.12970753, 0.12956816)
# (167, 0.13200912, 0.1317332, 0.13000727)
# (168, 0.12911047, 0.12926933, 0.12835301)
# (169, 0.12777507, 0.1276439, 0.12529826)
# (170, 0.122291274, 0.1222066, 0.12143817)
# (171, 0.1296868, 0.12982139, 0.12785569)
# (172, 0.12811095, 0.12828407, 0.12747605)
# (173, 0.12793623, 0.1279345, 0.12692429)
# (174, 0.1258108, 0.1257253, 0.12615499)
# (175, 0.12838991, 0.12843391, 0.12713557)
# (176, 0.13049558, 0.13051334, 0.12931702)
# (177, 0.123960644, 0.12378702, 0.12254072)
# (178, 0.13217556, 0.1321051, 0.13140593)
# (179, 0.12421018, 0.12414229, 0.1232285)
# (180, 0.12403192, 0.124127, 0.12267361)
# (181, 0.12949802, 0.12951328, 0.12789942)
# (182, 0.13008131, 0.13006161, 0.12923357)
# (183, 0.12903047, 0.12898451, 0.12777096)
# (184, 0.12862869, 0.12860927, 0.1274775)
# (185, 0.12867086, 0.128469, 0.12667122)
# (186, 0.12964931, 0.1296756, 0.12832655)
# (187, 0.123674504, 0.12363376, 0.12277274)
# (188, 0.1277315, 0.12778628, 0.12633814)
# (189, 0.12805219, 0.12785856, 0.1271072)
# (190, 0.12738353, 0.12763126, 0.12747501)
# (191, 0.12524962, 0.12539677, 0.123689696)
# (192, 0.12921879, 0.12932639, 0.12845431)
# (193, 0.13115077, 0.13109648, 0.13049588)
# (194, 0.129183, 0.12907374, 0.12660964)
# (195, 0.1288769, 0.12880915, 0.12783141)
# (196, 0.15417747, 0.15194367, 0.1344839)
# (197, 0.13186753, 0.13207217, 0.12988581)
# (198, 0.12517583, 0.12493737, 0.12603593)
# (199, 0.13170789, 0.13162388, 0.13194974)
# (200, 0.12648164, 0.12643528, 0.12298376)
# (201, 0.12545143, 0.12541062, 0.12579906)
# (202, 0.13553953, 0.13550058, 0.13584144)
# (203, 0.12720002, 0.12706062, 0.12462031)
# (204, 0.1276317, 0.12771384, 0.12878703)
# (205, 0.1324512, 0.13237877, 0.13763782)
# (206, 0.12866436, 0.12847404, 0.14784512)
# (207, 0.13380203, 0.13358995, 0.13505204)
# (208, 0.12892592, 0.12899943, 0.12969638)
# (209, 0.13182296, 0.13157764, 0.12771457)
# (210, 0.12908903, 0.12906694, 0.13138308)
# (211, 0.13394092, 0.1339472, 0.13499485)
# (212, 0.13713078, 0.1371029, 0.13303511)
# (213, 0.123455465, 0.123290405, 0.12393823)
# (214, 0.12636034, 0.12617832, 0.12850823)
# (215, 0.1346786, 0.15372373, 0.13640067)
# (216, 0.13676968, 0.13664612, 0.13224407)
# (217, 0.13113108, 0.13159066, 0.12619942)
# (218, 0.122361094, 0.12232633, 0.12286162)
# (219, 0.13028236, 0.13008805, 0.12816022)
# (220, 0.13299015, 0.15430704, 0.12719978)
# (221, 0.12769559, 0.12753406, 0.12589014)
# (222, 0.13108341, 0.13107204, 0.1286543)
# (223, 0.12415156, 0.124213375, 0.12355883)
# (224, 0.12848544, 0.12845066, 0.1274099)
# (225, 0.14600603, 0.14914073, 0.13541462)
# (226, 0.1316299, 0.13165623, 0.1305117)
# (227, 0.12986362, 0.12996784, 0.12778169)
# (228, 0.12744913, 0.12738258, 0.12580405)
# (229, 0.12981108, 0.12968701, 0.128928)
# (230, 0.12823285, 0.12840961, 0.12692729)
# (231, 0.12138778, 0.12150088, 0.12035511)
# (232, 0.13052113, 0.13056926, 0.12957388)
# (233, 0.1257697, 0.12563342, 0.12367346)
# (234, 0.13166766, 0.14961272, 0.13067701)
# (235, 0.13175417, 0.13170056, 0.1303269)
# (236, 0.13259195, 0.13258612, 0.13004088)
# (237, 0.13012342, 0.15618949, 0.13049224)
# (238, 0.12941414, 0.12788138, 0.12656762)
# (239, 0.13074672, 0.13077828, 0.1292194)
# (240, 0.12915775, 0.12939447, 0.12872562)
# (241, 0.12807281, 0.12817435, 0.12724607)
# (242, 0.13458529, 0.1346598, 0.13280438)
# (243, 0.13016507, 0.13024741, 0.12878492)
# (244, 0.13403207, 0.13412988, 0.13269483)
# (245, 0.12974311, 0.12461305, 0.12392355)
# (246, 0.13072702, 0.13082409, 0.1301553)
# (247, 0.12690346, 0.12712263, 0.12583481)
# (248, 0.12615031, 0.12625647, 0.12486204)
# (249, 0.1250248, 0.12507066, 0.12328928)
# (250, 0.12860097, 0.12857755, 0.1281151)
# (251, 0.123328, 0.123187006, 0.12181916)
# (252, 0.13436715, 0.1343293, 0.132624)
# (253, 0.12584868, 0.1258179, 0.12383194)
# (254, 0.1261888, 0.12630662, 0.1249796)
# (255, 0.13337535, 0.13319506, 0.13200508)
# (256, 0.12795979, 0.12788951, 0.12657443)
# (257, 0.1328478, 0.13294762, 0.13056158)
# (258, 0.12832446, 0.12820339, 0.12625095)
# (259, 0.13035452, 0.13035202, 0.12925516)
# (260, 0.12659511, 0.12635513, 0.12470484)
# (261, 0.12890646, 0.12894766, 0.12827921)
# (262, 0.12698644, 0.12701714, 0.12588586)
# (263, 0.12728412, 0.12726387, 0.12741944)
# (264, 0.13065788, 0.1306656, 0.13062245)
# (265, 0.13101761, 0.13105266, 0.12876926)
# (266, 0.12813878, 0.12831336, 0.12875879)
# (267, 0.13564652, 0.13565497, 0.13486537)
# (268, 0.13369131, 0.13349932, 0.13075824)
# (269, 0.1255939, 0.1256587, 0.12564759)
# (270, 0.12787367, 0.12808017, 0.12656118)
# (271, 0.12905249, 0.1292205, 0.12865603)
# (272, 0.13017507, 0.13012153, 0.12892137)
# (273, 0.13326123, 0.1331203, 0.13148281)
# (274, 0.1286215, 0.1287615, 0.12831135)
# (275, 0.12956126, 0.12962128, 0.12746106)
# (276, 0.12604499, 0.12624995, 0.124107435)
# (277, 0.12394509, 0.1237984, 0.122490756)
# (278, 0.12885879, 0.12902556, 0.12720548)
# (279, 0.12693991, 0.12704873, 0.12614742)
# (280, 0.12939823, 0.12911049, 0.12856354)
# (281, 0.12886819, 0.12872362, 0.12728627)
# (282, 0.12772858, 0.12787144, 0.12598006)
# (283, 0.12915793, 0.12915078, 0.12818941)
# (284, 0.1322861, 0.13221556, 0.13099149)
# (285, 0.1338621, 0.1334611, 0.13247281)
# (286, 0.12948021, 0.12959802, 0.12814747)
# (287, 0.12854081, 0.12847792, 0.12656482)
# (288, 0.1288692, 0.12885302, 0.12755664)
# (289, 0.12808894, 0.12805682, 0.1270666)
# (290, 0.1349055, 0.13503297, 0.13340399)
# (291, 0.12951526, 0.12948129, 0.12797424)
# (292, 0.13234581, 0.1322648, 0.1319028)
# (293, 0.12761123, 0.12763707, 0.12616995)
# (294, 0.13010354, 0.13003616, 0.12838198)
# (295, 0.13217546, 0.13223174, 0.13039301)
# (296, 0.12932606, 0.1293319, 0.12905207)
# (297, 0.124391474, 0.12430441, 0.12326587)
# (298, 0.12913072, 0.1290801, 0.1295972)
# (299, 0.12964192, 0.12986247, 0.13020104)
# (300, 0.13150202, 0.13166621, 0.12845051)
# (301, 0.1323921, 0.13234147, 0.13335189)
# (302, 0.13048345, 0.13041925, 0.13195641)
# (303, 0.12861545, 0.12861776, 0.124488614)
# (304, 0.12932369, 0.12933016, 0.12862836)
# (305, 0.13147396, 0.13165413, 0.13516438)
# (306, 0.13173564, 0.1316189, 0.1289516)
# (307, 0.13286032, 0.13285357, 0.12896661)
# (308, 0.13038155, 0.13030006, 0.12966742)
# (309, 0.13202265, 0.13218838, 0.12950718)
# (310, 0.12833154, 0.12845708, 0.12792626)
# (311, 0.13249716, 0.13272238, 0.13165528)
# (312, 0.12697554, 0.12691414, 0.12579018)
# (313, 0.13139206, 0.13157491, 0.13047454)
# (314, 0.1307504, 0.13063382, 0.12880217)
# (315, 0.12667029, 0.12672868, 0.12494984)
# (316, 0.12794666, 0.1279699, 0.12794006)
# (317, 0.13197362, 0.1319234, 0.13187827)
# (318, 0.13645232, 0.13643956, 0.13414416)
# (319, 0.12806319, 0.14258674, 0.13047841)
# (320, 0.13021415, 0.13025542, 0.12886548)
# (321, 0.1320714, 0.13181143, 0.13001394)
# (322, 0.13338256, 0.13358057, 0.13325074)
# (323, 0.1291686, 0.12933864, 0.12650244)
# (324, 0.12744015, 0.12744164, 0.12629113)
# (325, 0.12692097, 0.12691797, 0.12553939)
# (326, 0.13307308, 0.13295831, 0.13126081)
# (327, 0.1285436, 0.12848863, 0.1267726)
# (328, 0.12684, 0.126784, 0.12413005)
# (329, 0.12428195, 0.12412275, 0.123912975)
# (330, 0.12703511, 0.12688622, 0.12550813)
# (331, 0.12749998, 0.12747672, 0.12608936)
# (332, 0.12712131, 0.12725487, 0.12621786)
# (333, 0.12546746, 0.12539382, 0.123536095)
# (334, 0.12558039, 0.12558463, 0.12406638)
# (335, 0.13566719, 0.13565466, 0.13455324)
# (336, 0.13595955, 0.13617021, 0.13510898)
# (337, 0.12993115, 0.12999618, 0.12847152)
# (338, 0.1337042, 0.13345353, 0.13164565)
# (339, 0.13159908, 0.13172214, 0.13027328)
# (340, 0.13129525, 0.13143268, 0.12907654)
# (341, 0.13170075, 0.1315323, 0.13048124)
# (342, 0.12678838, 0.12690905, 0.12596193)
# (343, 0.12618321, 0.12616225, 0.1247486)
# (344, 0.12673837, 0.12675624, 0.12753218)
# (345, 0.13587737, 0.13389303, 0.13907975)
# (346, 0.1387633, 0.13875726, 0.1369119)
# (347, 0.13736223, 0.13714153, 0.1324992)
# (348, 0.13132504, 0.13127622, 0.13282447)
# (349, 0.13560563, 0.13581476, 0.1370244)
# (350, 0.13171099, 0.13201852, 0.12807426)
# (351, 0.13265471, 0.1340622, 0.13236716)
# (352, 0.12824418, 0.12813383, 0.12719238)
# (353, 0.13601968, 0.13606521, 0.13400993)
# (354, 0.13218313, 0.13223395, 0.1302592)
# (355, 0.13056372, 0.13063638, 0.13002267)
# (356, 0.12946475, 0.12958106, 0.1280405)
# (357, 0.13080283, 0.13084844, 0.12796609)
# (358, 0.15249349, 0.12631355, 0.12651566)
# (359, 0.12887727, 0.12875281, 0.12793174)
# (360, 0.125866, 0.12593484, 0.12381593)
# (361, 0.12980202, 0.12969458, 0.12837493)
# (362, 0.13007987, 0.13008283, 0.12895674)
# (363, 0.12565248, 0.12550277, 0.12517281)
# (364, 0.13133386, 0.13142619, 0.13005699)
# (365, 0.13269499, 0.13266581, 0.13161702)
# (366, 0.12816077, 0.12822601, 0.12789635)
# (367, 0.13408366, 0.13412443, 0.13273725)
# (368, 0.12758012, 0.12754488, 0.12570797)
# (369, 0.12756929, 0.12743276, 0.12815733)
# (370, 0.1307752, 0.13074546, 0.12991999)
# (371, 0.12726614, 0.12721623, 0.12581268)
# (372, 0.13456042, 0.1345105, 0.1350452)
# (373, 0.13355438, 0.13348013, 0.13245249)
# (374, 0.1303825, 0.13036913, 0.12823325)
# (375, 0.13068464, 0.13075608, 0.13084108)
# (376, 0.13091204, 0.13093993, 0.12999868)
# (377, 0.12989947, 0.13003385, 0.12693684)
# (378, 0.12983361, 0.12965934, 0.1279428)
# (379, 0.122580074, 0.12253038, 0.121219575)
# (380, 0.131185, 0.1312261, 0.12901868)
# (381, 0.1226996, 0.12254014, 0.12095399)
# (382, 0.12323232, 0.123165265, 0.122437395)
# (383, 0.1274578, 0.12965204, 0.1290617)
# (384, 0.12791543, 0.1278911, 0.12675494)
# (385, 0.12963879, 0.12965228, 0.12740164)
# (386, 0.12770304, 0.12784114, 0.1259082)
# (387, 0.13334249, 0.1332904, 0.13499446)
# (388, 0.13057975, 0.13054398, 0.13026768)
# (389, 0.13226187, 0.13230151, 0.13097802)
# (390, 0.12890531, 0.12902723, 0.12754336)
# (391, 0.12969632, 0.13318184, 0.13207147)
# (392, 0.12844233, 0.12849227, 0.12697558)
# (393, 0.13084118, 0.13075903, 0.15322635)
# (394, 0.13253942, 0.13242263, 0.13261011)
# (395, 0.13522944, 0.13534749, 0.1328821)
# (396, 0.12861428, 0.12868696, 0.12950331)
# (397, 0.12699938, 0.1270619, 0.12746103)
# (398, 0.13423978, 0.13425386, 0.12981719)
# (399, 0.13338095, 0.13314338, 0.13385803)
# (400, 0.12875304, 0.12888372, 0.12934813)
# (401, 0.13097134, 0.13099018, 0.12777373)
# (402, 0.1302475, 0.13027138, 0.13028091)
# (403, 0.13416581, 0.1341778, 0.13497342)
# (404, 0.13781942, 0.13776384, 0.13341278)
# (405, 0.12353378, 0.12360272, 0.12576121)
# (406, 0.13435605, 0.13453554, 0.13753687)
# (407, 0.13146235, 0.1313666, 0.12759985)
# (408, 0.13157928, 0.13160852, 0.12916851)
# (409, 0.1318033, 0.13179602, 0.1339309)
# (410, 0.13076952, 0.13066433, 0.1286663)
# (411, 0.12492561, 0.12496355, 0.12225018)
# (412, 0.1302221, 0.13052939, 0.12934345)
# (413, 0.12550303, 0.12552467, 0.12280389)
# (414, 0.13303183, 0.133201, 0.13423392)
# (415, 0.12869294, 0.1284799, 0.12973115)
# (416, 0.1295341, 0.1296157, 0.12711528)
# (417, 0.12928791, 0.12942712, 0.1309197)
# (418, 0.1318671, 0.13189748, 0.13368087)
# (419, 0.12959827, 0.12954493, 0.12607768)
# (420, 0.12931748, 0.12953703, 0.12761271)
# (421, 0.12870005, 0.12868617, 0.12904102)
# (422, 0.12803262, 0.12804154, 0.124849975)
# (423, 0.12645714, 0.12638745, 0.12805067)
# (424, 0.12917428, 0.12912934, 0.12992889)
# (425, 0.12972128, 0.1296287, 0.1261528)
# (426, 0.14485496, 0.13129058, 0.13067272)
# (427, 0.13396898, 0.13388105, 0.13239112)
# (428, 0.12665103, 0.12668738, 0.12512772)
# (429, 0.12970735, 0.1295712, 0.128037)
# (430, 0.12804434, 0.12790628, 0.12636873)
# (431, 0.120195545, 0.12026486, 0.1193152)
# (432, 0.12578364, 0.125747, 0.12477665)
# (433, 0.12769344, 0.12752713, 0.12604308)
# (434, 0.1260193, 0.1259254, 0.12423303)
# (435, 0.1264314, 0.12636104, 0.1244824)
# (436, 0.1285193, 0.1285749, 0.12741819)
# (437, 0.1308842, 0.13088883, 0.12963463)
# (438, 0.12814164, 0.12834385, 0.12714146)
# (439, 0.13069215, 0.13085409, 0.12855637)
# (440, 0.1294101, 0.12947737, 0.1403892)
# (441, 0.12787123, 0.12777606, 0.12711148)
# (442, 0.12867777, 0.1287421, 0.12655878)
# (443, 0.12814699, 0.12800618, 0.12768601)
# (444, 0.13319828, 0.13290307, 0.13290395)
# (445, 0.13105394, 0.13087068, 0.13040957)
# (446, 0.12992, 0.12998223, 0.12866111)
# (447, 0.13009351, 0.13019359, 0.1285858)
# (448, 0.14003947, 0.14020063, 0.1377286)
# (449, 0.12847616, 0.12871632, 0.12649263)
# (450, 0.12843025, 0.12852247, 0.12723866)
# (451, 0.12465208, 0.124782614, 0.12350482)
# (452, 0.1313662, 0.13126521, 0.13064727)
# (453, 0.13112193, 0.13114426, 0.13025618)
# (454, 0.12836939, 0.1283027, 0.12799524)
# (455, 0.13529985, 0.1352808, 0.1350505)
# (456, 0.13318644, 0.13339037, 0.13093023)
# (457, 0.12825705, 0.12837887, 0.12741235)
# (458, 0.13277288, 0.13269745, 0.13067526)
# (459, 0.12821497, 0.12849653, 0.12741011)
# (460, 0.12759985, 0.1275792, 0.12700897)
# (461, 0.1334048, 0.13341567, 0.13090864)
# (462, 0.12747769, 0.12731135, 0.12598027)
# (463, 0.12692033, 0.12681828, 0.12541966)
# (464, 0.12707902, 0.12704489, 0.12654872)
# (465, 0.12804723, 0.12797414, 0.12686075)
# (466, 0.12708169, 0.12670825, 0.12689419)
# (467, 0.12864698, 0.12864196, 0.12802427)
# (468, 0.12442953, 0.12438404, 0.12296118)
# (469, 0.12965962, 0.12962034, 0.12929711)
# (470, 0.13089818, 0.13100523, 0.12930568)
# (471, 0.1280563, 0.12802193, 0.12895747)
# (472, 0.13120279, 0.13119085, 0.13278574)
# (473, 0.13375372, 0.13375357, 0.12955609)
# (474, 0.13559209, 0.13567105, 0.13381244)
# (475, 0.13081665, 0.13072863, 0.13038741)
# (476, 0.13704257, 0.13688195, 0.13318205)
# (477, 0.12836981, 0.12845114, 0.12851852)
# (478, 0.12768686, 0.12784827, 0.12635535)
# (479, 0.1293435, 0.1294563, 0.12637143)
# (480, 0.12829646, 0.1282092, 0.1278233)
# (481, 0.12797335, 0.12804654, 0.12620579)
# (482, 0.12540412, 0.12555708, 0.12380755)
# (483, 0.12902759, 0.12897842, 0.1275143)
# (484, 0.12324959, 0.12307289, 0.12271005)
# (485, 0.13241227, 0.13227633, 0.13141619)
# (486, 0.14553374, 0.1319454, 0.12965378)
# (487, 0.13156827, 0.13152485, 0.13013755)
# (488, 0.1308094, 0.13093522, 0.12976904)
# (489, 0.12424973, 0.12445642, 0.12369167)
# (490, 0.13136017, 0.13145134, 0.12974699)
# (491, 0.12601985, 0.1258937, 0.124977395)
# (492, 0.1328201, 0.1328058, 0.13135791)
# (493, 0.13529468, 0.13529806, 0.13520996)
# (494, 0.12859748, 0.12868091, 0.1272769)
# (495, 0.12815778, 0.12834606, 0.12715346)
# (496, 0.12889406, 0.12896109, 0.12766282)
# (497, 0.12907182, 0.12899666, 0.12800874)
# (498, 0.1307197, 0.13071579, 0.1296113)
# (499, 0.128746, 0.12889282, 0.12822503)
# (500, 0.13010257, 0.13034418, 0.12878384)
# (501, 0.12852234, 0.1284063, 0.12761953)
# (502, 0.12993789, 0.1299991, 0.12789854)
# (503, 0.12422762, 0.12414929, 0.12374085)
# (504, 0.13170187, 0.1317212, 0.13092734)
# (505, 0.1288603, 0.12905903, 0.12835765)
# (506, 0.12928328, 0.12920895, 0.12907755)
# (507, 0.13330036, 0.13333356, 0.1310545)
# (508, 0.12610401, 0.12616923, 0.12584335)
# (509, 0.1320192, 0.1322528, 0.13255736)
# (510, 0.13277425, 0.1327371, 0.13034958)
# (511, 0.12428141, 0.1243249, 0.123771936)
# (512, 0.13251159, 0.13249731, 0.13052432)
# (513, 0.13111427, 0.13124628, 0.13037656)
# (514, 0.12289, 0.122729234, 0.12280369)
# (515, 0.13379976, 0.13371557, 0.13089666)
# (516, 0.12551242, 0.12557995, 0.12688948)
# (517, 0.13020086, 0.13023323, 0.13152228)
# (518, 0.13608956, 0.13606782, 0.13210894)
# (519, 0.13166504, 0.1315863, 0.13108295)
# (520, 0.13612024, 0.13623436, 0.13764389)
# (521, 0.13577825, 0.13576038, 0.13206935)
# (522, 0.13373797, 0.13364674, 0.13245021)
# (523, 0.13031985, 0.13015454, 0.13224812)
# (524, 0.13100733, 0.13114275, 0.1275972)
# (525, 0.13418213, 0.13427047, 0.12951109)
# (526, 0.12742788, 0.12744229, 0.12680298)
# (527, 0.12940183, 0.1296765, 0.12763612)
# (528, 0.12672314, 0.12650257, 0.12585282)
# (529, 0.1276167, 0.12732105, 0.1261245)
# (530, 0.1318825, 0.13175766, 0.13064285)
# (531, 0.1269711, 0.12702484, 0.12680525)
# (532, 0.12485307, 0.12485555, 0.12316148)
# (533, 0.13056064, 0.13058239, 0.12869915)
# (534, 0.12098475, 0.121231526, 0.12073814)
# (535, 0.126557, 0.12631395, 0.1252416)
# (536, 0.1342977, 0.13444579, 0.13304529)
# (537, 0.15030098, 0.12262854, 0.12346735)
# (538, 0.12815039, 0.12810798, 0.12615468)
# (539, 0.12725675, 0.12739873, 0.12761769)
# (540, 0.13152692, 0.13163258, 0.1514635)
# (541, 0.1324182, 0.13260767, 0.13217793)
# (542, 0.13154322, 0.13140595, 0.13112183)
# (543, 0.12709384, 0.12705034, 0.12506168)
# (544, 0.1257166, 0.12577051, 0.12397779)
# (545, 0.12710242, 0.12732726, 0.12635784)
# (546, 0.12593098, 0.12604603, 0.12505455)
# (547, 0.12808245, 0.12795994, 0.12734446)
# (548, 0.12671463, 0.12676121, 0.12569188)
# (549, 0.12470356, 0.12476294, 0.12365955)
# (550, 0.13139352, 0.13141815, 0.1304529)
# (551, 0.123427495, 0.1232531, 0.12309881)
# (552, 0.12607081, 0.12596281, 0.12450775)
# (553, 0.13025665, 0.13041925, 0.1291587)
# (554, 0.12885746, 0.12905884, 0.12849852)
# (555, 0.1260758, 0.12675993, 0.12654795)
# (556, 0.1289704, 0.12896664, 0.12808864)
# (557, 0.12552616, 0.1254374, 0.12404427)
# (558, 0.12880212, 0.1288844, 0.12752667)
# (559, 0.12972827, 0.12962224, 0.12872861)
# (560, 0.12878104, 0.1287533, 0.12649606)
# (561, 0.12302855, 0.123165086, 0.12121468)
# (562, 0.13226579, 0.13209791, 0.13042158)
# (563, 0.12376577, 0.12377642, 0.12178721)
# (564, 0.12462078, 0.124767676, 0.123741426)
# (565, 0.13007055, 0.12998797, 0.12863144)
# (566, 0.13190952, 0.13196975, 0.12947123)
# (567, 0.12691656, 0.12692302, 0.12545072)
# (568, 0.1274516, 0.12770736, 0.12615445)
# (569, 0.12839621, 0.12838477, 0.12712058)
# (570, 0.1280959, 0.12814802, 0.12805219)
# (571, 0.129404, 0.1295016, 0.127939)
# (572, 0.13295913, 0.1328841, 0.13242468)
# (573, 0.123633295, 0.12346679, 0.122291535)
# (574, 0.12856, 0.12857366, 0.1282692)
# (575, 0.12745053, 0.12756687, 0.12620702)
# (576, 0.12668617, 0.12685516, 0.12685247)
# (577, 0.1288432, 0.12902288, 0.12905867)
# (578, 0.13264573, 0.13273406, 0.13084781)
# (579, 0.13071807, 0.13059705, 0.12851262)
# (580, 0.12579434, 0.12565061, 0.12495747)
# (581, 0.124884725, 0.12475924, 0.12362998)
# (582, 0.13097642, 0.13105519, 0.12894093)
# (583, 0.1243592, 0.124194406, 0.12306382)
# (584, 0.12794712, 0.12805843, 0.12801628)
# (585, 0.13176309, 0.13153395, 0.13015139)
# (586, 0.12594514, 0.12585814, 0.1239206)
# (587, 0.13090242, 0.13102809, 0.12908937)
# (588, 0.12508605, 0.12500246, 0.123074226)
# (589, 0.12783462, 0.12789312, 0.12649137)
# (590, 0.12878767, 0.12872486, 0.12791383)
# (591, 0.12456854, 0.12474857, 0.122981556)
# (592, 0.13277923, 0.1327326, 0.13188711)
# (593, 0.1255549, 0.12571514, 0.12456511)
# (594, 0.1311543, 0.13125643, 0.13031812)
# (595, 0.13168345, 0.13144913, 0.12958157)
# (596, 0.13017184, 0.12998962, 0.12901706)
# (597, 0.17280012, 0.15322655, 0.12921487)
# (598, 0.13508706, 0.1353205, 0.13425903)
# (599, 0.12895557, 0.12893371, 0.12705076)
# (600, 0.1583827, 0.15074393, 0.13793615)
# (601, 0.13479775, 0.13467178, 0.1332486)
# (602, 0.1300819, 0.13007307, 0.12678435)
# (603, 0.12965718, 0.12985903, 0.12828095)
# (604, 0.12315868, 0.12317016, 0.12407665)
# (605, 0.13800111, 0.13820238, 0.13677976)
# (606, 0.13007225, 0.1300933, 0.12926747)
# (607, 0.13231675, 0.13256072, 0.13068575)
# (608, 0.12879919, 0.1290776, 0.12819865)
# (609, 0.12850876, 0.12866074, 0.12750168)
# (610, 0.12978983, 0.12980106, 0.12818119)
# (611, 0.13149376, 0.13141516, 0.12986553)
# (612, 0.13513492, 0.13518196, 0.13253944)
# (613, 0.12952575, 0.12934367, 0.12896279)
# (614, 0.13426404, 0.13418753, 0.13279043)
# (615, 0.13060588, 0.13039464, 0.12922245)
# (616, 0.12665085, 0.12652434, 0.1265148)
# (617, 0.12961714, 0.12955181, 0.12895663)
# (618, 0.13104108, 0.13111737, 0.12949826)
# (619, 0.15705271, 0.14485356, 0.13710406)
# (620, 0.13598344, 0.13589686, 0.1325303)
# (621, 0.13188443, 0.13198529, 0.13300486)
# (622, 0.13043566, 0.13035436, 0.12938198)
# (623, 0.13189298, 0.1318999, 0.12887083)
# (624, 0.1305925, 0.13064992, 0.12897736)
# (625, 0.12854199, 0.12857196, 0.12649877)
# (626, 0.14820014, 0.1248337, 0.12333004)
# (627, 0.12467204, 0.12488297, 0.123176455)
# (628, 0.13030107, 0.1301023, 0.1293357)
# (629, 0.13270839, 0.1324531, 0.13202652)
# (630, 0.13047233, 0.13058814, 0.12948984)
# (631, 0.13042146, 0.13050829, 0.12890053)
# (632, 0.13054083, 0.1303649, 0.12924331)
# (633, 0.1289035, 0.12895368, 0.12789893)
# (634, 0.12960249, 0.129608, 0.1277785)
# (635, 0.13033283, 0.13024136, 0.12921184)
# (636, 0.12716132, 0.12704301, 0.12560852)
# (637, 0.12962025, 0.12955837, 0.12767972)
# (638, 0.12752655, 0.12742859, 0.12541696)
# (639, 0.12728088, 0.12737632, 0.1267039)
# (640, 0.12933809, 0.12925938, 0.1275475)
# (641, 0.12938032, 0.12918934, 0.1281554)
# (642, 0.13008612, 0.1301134, 0.12855186)
# (643, 0.12875587, 0.12872025, 0.12681061)
# (644, 0.129858, 0.12977321, 0.12843369)
# (645, 0.13410896, 0.13427092, 0.13222529)
# (646, 0.13316052, 0.13318843, 0.13154696)
# (647, 0.12052151, 0.120646216, 0.11923306)
# (648, 0.13138588, 0.1314172, 0.13039993)
# (649, 0.1285453, 0.12868816, 0.12751088)
# (650, 0.123811156, 0.123704255, 0.12227206)
# (651, 0.12552778, 0.12555012, 0.12411392)
# (652, 0.12689823, 0.12692457, 0.12604113)
# (653, 0.12722342, 0.1270852, 0.12554929)
# (654, 0.12680474, 0.12685734, 0.12525216)
# (655, 0.12519655, 0.12531792, 0.12381063)
# (656, 0.12733558, 0.12715898, 0.1262282)
# (657, 0.129697, 0.1294663, 0.12834811)
# (658, 0.12695345, 0.12686346, 0.12588416)
# (659, 0.12658454, 0.12641335, 0.12581821)
# (660, 0.12891306, 0.12883605, 0.12910882)
# (661, 0.12991825, 0.1299141, 0.12902018)
# (662, 0.12550737, 0.12541632, 0.12338559)
# (663, 0.13001306, 0.12988833, 0.12892845)
# (664, 0.12807718, 0.12806994, 0.12622969)
# (665, 0.13074301, 0.13086118, 0.12949778)
# (666, 0.13333555, 0.13339584, 0.13267918)
# (667, 0.12500618, 0.12472508, 0.12276)
# (668, 0.12566057, 0.12564689, 0.12509331)
# (669, 0.12973243, 0.1297944, 0.1292322)
# (670, 0.1253713, 0.12541032, 0.12482414)
# (671, 0.12748069, 0.12740232, 0.12578462)
# (672, 0.12811343, 0.12828846, 0.12755291)
# (673, 0.13017021, 0.1301392, 0.12862523)
# (674, 0.12932462, 0.12925695, 0.12931226)
# (675, 0.13010997, 0.1301958, 0.12845619)
# (676, 0.13084415, 0.13080144, 0.13029604)
# (677, 0.15289295, 0.15336138, 0.132498)
# (678, 0.1371697, 0.13711035, 0.13610391)
# (679, 0.13159491, 0.13178442, 0.12653175)
# (680, 0.13250455, 0.1324816, 0.13340501)
# (681, 0.13366106, 0.13376495, 0.13418019)
# (682, 0.13478702, 0.13476026, 0.13111454)
# (683, 0.12807718, 0.12824765, 0.13007559)
# (684, 0.13271208, 0.13262069, 0.13351248)
# (685, 0.1391044, 0.13910146, 0.13518962)
# (686, 0.12966666, 0.12970074, 0.12812023)
# (687, 0.12820219, 0.12817246, 0.12845066)
# (688, 0.12974814, 0.12961361, 0.12703417)
# (689, 0.12795024, 0.12799856, 0.12892595)
# (690, 0.13277875, 0.13255922, 0.13161573)
# (691, 0.12789214, 0.12780775, 0.12523133)
# (692, 0.124931976, 0.12488787, 0.12477347)
# (693, 0.123481944, 0.123591885, 0.12186604)
# (694, 0.12955937, 0.12958506, 0.12932234)
# (695, 0.1380086, 0.13304864, 0.13681296)
# (696, 0.13488866, 0.13512212, 0.13478282)
# (697, 0.13469379, 0.13469684, 0.12902246)
# (698, 0.12975493, 0.12950699, 0.12990883)
# (699, 0.12771864, 0.12766863, 0.12906638)
# (700, 0.12915114, 0.12880893, 0.12559395)
# (701, 0.13783821, 0.15149266, 0.1273906)
# (702, 0.12762871, 0.1278787, 0.1267117)
# (703, 0.12530681, 0.12543459, 0.12327261)
# (704, 0.12671958, 0.1267818, 0.12655948)
# (705, 0.12383642, 0.12392316, 0.12325077)
# (706, 0.12824179, 0.12823093, 0.1266648)
# (707, 0.13161641, 0.13154592, 0.13083519)
# (708, 0.12826781, 0.12829486, 0.12609132)
# (709, 0.12750266, 0.12737164, 0.12600519)
# (710, 0.12572892, 0.1258178, 0.12482995)
# (711, 0.13081013, 0.13059436, 0.12895852)
# (712, 0.13084874, 0.13068599, 0.12928082)
# (713, 0.15464666, 0.15435222, 0.12944315)
# (714, 0.13243866, 0.13219517, 0.13091405)
# (715, 0.12407368, 0.12397063, 0.12163624)
# (716, 0.12703171, 0.1270112, 0.12583768)
# (717, 0.124447875, 0.12447994, 0.124652565)
# (718, 0.122120045, 0.122370355, 0.12128038)
# (719, 0.13249362, 0.13274139, 0.13068026)
# (720, 0.12927926, 0.12921666, 0.12895036)
# (721, 0.12962776, 0.12950471, 0.12889762)
# (722, 0.13429368, 0.1342571, 0.13247833)
# (723, 0.1230164, 0.12334522, 0.12217277)
# (724, 0.12280652, 0.122736536, 0.12185312)
# (725, 0.12911466, 0.12891972, 0.12786964)
# (726, 0.1300329, 0.12996681, 0.12809183)
# (727, 0.12517345, 0.12549622, 0.12595518)
# (728, 0.12956831, 0.12961856, 0.12977661)
# (729, 0.16192044, 0.13627917, 0.13576241)
# (730, 0.12768888, 0.12750544, 0.12609707)
# (731, 0.12862629, 0.12872747, 0.12772606)
# (732, 0.13197899, 0.13209535, 0.13030005)
# (733, 0.13021079, 0.13027662, 0.13041998)
# (734, 0.13510586, 0.13517343, 0.13334061)
# (735, 0.12844434, 0.12840742, 0.12766004)
# (736, 0.1325897, 0.13269101, 0.13137533)
# (737, 0.1302722, 0.13028371, 0.12976728)
# (738, 0.13433757, 0.13436355, 0.13252868)
# (739, 0.13375533, 0.13375422, 0.13229749)
# (740, 0.12361839, 0.123621926, 0.122410186)
# (741, 0.13023272, 0.13035457, 0.12946552)
# (742, 0.12540765, 0.12548834, 0.12369423)
# (743, 0.12718597, 0.12721077, 0.12763023)
# (744, 0.13204621, 0.13182874, 0.13181958)
# (745, 0.13874775, 0.13869181, 0.13638869)
# (746, 0.12865777, 0.12858832, 0.1272369)
# (747, 0.13078919, 0.13073424, 0.129524)
# (748, 0.13188879, 0.1319879, 0.1308122)
# (749, 0.12488966, 0.12487136, 0.12353501)
# (750, 0.13067661, 0.13072437, 0.12969123)
# (751, 0.13129278, 0.13119218, 0.12944323)
# (752, 0.1326206, 0.13254198, 0.13213457)
# (753, 0.13119952, 0.13096201, 0.12969062)
# (754, 0.13372475, 0.13378525, 0.13169906)
# (755, 0.124533825, 0.12461811, 0.124049544)
# (756, 0.13419625, 0.1339952, 0.13190046)
# (757, 0.1250919, 0.1250702, 0.12553023)
# (758, 0.1286387, 0.12849998, 0.12811624)
# (759, 0.12913561, 0.12911859, 0.12828971)
# (760, 0.13204177, 0.13181198, 0.13017568)
# (761, 0.12836553, 0.12835827, 0.12798253)
# (762, 0.13165978, 0.13155185, 0.1298947)
# (763, 0.13476162, 0.13463044, 0.13355017)
# (764, 0.13094565, 0.13105965, 0.1292552)
# (765, 0.13093413, 0.13082747, 0.13095392)
# (766, 0.12764223, 0.1276151, 0.12681699)
# (767, 0.12475607, 0.124849394, 0.12394908)
# (768, 0.13092574, 0.13135168, 0.13046142)
# (769, 0.12937315, 0.12932535, 0.12693262)
# (770, 0.13514923, 0.13532028, 0.13323672)
# (771, 0.13538185, 0.13541646, 0.13384196)
# (772, 0.12722869, 0.1271287, 0.12723693)
# (773, 0.13136095, 0.1313771, 0.12952629)
# (774, 0.13031614, 0.13009252, 0.12876424)
# (775, 0.12864403, 0.12870248, 0.12719977)
# (776, 0.12724888, 0.12715684, 0.12580374)
# (777, 0.124945894, 0.12480283, 0.12393793)
# (778, 0.12866786, 0.12893741, 0.12759504)
# (779, 0.13100386, 0.13107371, 0.13061371)
# (780, 0.13597277, 0.13612226, 0.14030316)
# (781, 0.13292474, 0.13304417, 0.13129127)
# (782, 0.12845175, 0.12832868, 0.12627277)
# (783, 0.13319305, 0.13328572, 0.13208167)
# (784, 0.12566842, 0.1255432, 0.12415679)
# (785, 0.13057347, 0.1304854, 0.12898315)
# (786, 0.12724257, 0.12724024, 0.1259699)
# (787, 0.13029307, 0.13036281, 0.1303609)
# (788, 0.1320812, 0.13223884, 0.13157937)
# (789, 0.12964746, 0.12937263, 0.12889346)
# (790, 0.12681717, 0.12678126, 0.12495065)
# (791, 0.12514515, 0.12498543, 0.124069646)
# (792, 0.126857, 0.12690392, 0.12589967)
# (793, 0.12343827, 0.123441495, 0.123884685)
# (794, 0.13061681, 0.13039857, 0.12941982)
# (795, 0.13080335, 0.1308931, 0.12860702)
# (796, 0.13027413, 0.13008547, 0.12908408)
# (797, 0.12530275, 0.12538551, 0.123224474)
# (798, 0.12531148, 0.12527607, 0.12493707)
# (799, 0.12800248, 0.12784675, 0.1280683)
# (800, 0.13175066, 0.13171394, 0.1294182)
# (801, 0.12640354, 0.12636468, 0.12586913)
# (802, 0.13398576, 0.13418508, 0.13259995)
# (803, 0.124070294, 0.1241022, 0.12303486)
# (804, 0.12979148, 0.12981144, 0.12776618)
# (805, 0.1301054, 0.13031363, 0.12877387)
# (806, 0.1419401, 0.1322328, 0.15357876)
# (807, 0.12844807, 0.12836695, 0.1271015)
# (808, 0.12868048, 0.12876146, 0.12669693)
# (809, 0.13387766, 0.1338769, 0.13261169)
# (810, 0.12993897, 0.12995541, 0.12924102)
# (811, 0.13342053, 0.1332927, 0.13286631)
# (812, 0.13352856, 0.13351023, 0.131686)
# (813, 0.12793323, 0.1278483, 0.12550335)
# (814, 0.12891355, 0.12882775, 0.1267678)
# (815, 0.12599304, 0.12605275, 0.12623292)
# (816, 0.1304893, 0.13060105, 0.13026579)
# (817, 0.12670511, 0.12691966, 0.12524912)
# (818, 0.12952483, 0.12952965, 0.1283928)
# (819, 0.12454481, 0.12446775, 0.12357246)
# (820, 0.14175084, 0.14168742, 0.13636218)
# (821, 0.13800026, 0.13810886, 0.13656902)
# (822, 0.13383557, 0.13387647, 0.130799)
# (823, 0.13595043, 0.13595459, 0.13363624)
# (824, 0.12943006, 0.12915342, 0.13806282)
# (825, 0.12801173, 0.12796105, 0.12709351)
# (826, 0.12600783, 0.12620172, 0.12384587)
# (827, 0.12734886, 0.12720788, 0.12525403)
# (828, 0.13244659, 0.13238373, 0.1323432)
# (829, 0.1293692, 0.1294675, 0.12819256)
# (830, 0.14996389, 0.14370206, 0.13198155)
# (831, 0.12953831, 0.12949154, 0.12756948)
# (832, 0.13088642, 0.1311166, 0.12903282)
# (833, 0.13404262, 0.13385373, 0.13144703)
# (834, 0.1290799, 0.12906761, 0.12785661)
# (835, 0.12507582, 0.124837264, 0.1242406)
# (836, 0.12575114, 0.12592979, 0.124877155)
# (837, 0.12496134, 0.12486702, 0.12287788)
# (838, 0.13184512, 0.13186629, 0.13021545)
# (839, 0.124527626, 0.12436148, 0.12287645)
# (840, 0.1315087, 0.13152102, 0.13031007)
# (841, 0.12170244, 0.121791214, 0.12067539)
# (842, 0.12744296, 0.12749572, 0.12615499)
# (843, 0.12767749, 0.12779307, 0.12635934)
# (844, 0.12723836, 0.12723532, 0.12674566)
# (845, 0.13141188, 0.13157679, 0.13006532)
# (846, 0.13051511, 0.13055667, 0.1287831)
# (847, 0.13064137, 0.13062587, 0.12989387)
# (848, 0.12833267, 0.12817961, 0.12717448)
# (849, 0.1287196, 0.1288031, 0.12796447)
# (850, 0.12879507, 0.1287039, 0.12818564)
# (851, 0.13070934, 0.13048372, 0.12857404)
# (852, 0.12158654, 0.12150775, 0.11939114)
# (853, 0.12702134, 0.12705366, 0.12557814)
# (854, 0.12546386, 0.12549572, 0.12447134)
# (855, 0.12660411, 0.12655354, 0.12450142)
# (856, 0.13027838, 0.13040727, 0.12807763)
# (857, 0.1260493, 0.12588061, 0.12442827)
# (858, 0.12556316, 0.12578256, 0.12468192)
# (859, 0.12988271, 0.12976006, 0.12824205)
# (860, 0.13007751, 0.13011786, 0.12883848)
# (861, 0.12535691, 0.1253595, 0.12412246)
# (862, 0.1238615, 0.12408778, 0.122348055)
# (863, 0.13015118, 0.12995535, 0.12841758)
# (864, 0.13071436, 0.13058472, 0.128355)
# (865, 0.1239742, 0.123869784, 0.12307646)
# (866, 0.13373882, 0.13376808, 0.13288319)
# (867, 0.12632667, 0.12620665, 0.124257386)
# (868, 0.13264784, 0.13266943, 0.13126461)
# (869, 0.12974651, 0.12962277, 0.12810898)
# (870, 0.13288699, 0.1327509, 0.13094401)
# (871, 0.12802966, 0.12794876, 0.12777586)
# (872, 0.13216671, 0.13217533, 0.13108198)
# (873, 0.1357389, 0.13580798, 0.13368249)
# (874, 0.13065222, 0.13080402, 0.12871717)
# (875, 0.14124848, 0.15043712, 0.12909216)
# (876, 0.13034059, 0.13032441, 0.13056129)
# (877, 0.16424522, 0.13462314, 0.13593635)
# (878, 0.1311558, 0.13124095, 0.12842256)
# (879, 0.13290754, 0.13291416, 0.12874475)
# (880, 0.12849833, 0.12849908, 0.12873128)
# (881, 0.15513535, 0.13284929, 0.1333464)
# (882, 0.12769492, 0.12799108, 0.12523137)
# (883, 0.12995853, 0.13012657, 0.1272811)
# (884, 0.1301577, 0.13049687, 0.12845512)
# (885, 0.13003488, 0.13009739, 0.13022237)
# (886, 0.1397932, 0.15785243, 0.1347019)
# (887, 0.13724102, 0.13720064, 0.13524915)
# (888, 0.13643879, 0.13660516, 0.13319665)
# (889, 0.13026443, 0.13022223, 0.12847646)
# (890, 0.12981567, 0.12962924, 0.12806429)
# (891, 0.1321818, 0.13206924, 0.1316863)
# (892, 0.13182026, 0.13168097, 0.13025463)
# (893, 0.12949789, 0.129503, 0.12726435)
# (894, 0.12862782, 0.12870754, 0.12719846)
# (895, 0.12453656, 0.12450105, 0.12347652)
# (896, 0.12834947, 0.12809879, 0.12666172)
# (897, 0.12670803, 0.12672365, 0.1253696)
# (898, 0.12773417, 0.12791471, 0.12611799)
# (899, 0.12982881, 0.13012484, 0.12831062)
# (900, 0.13201705, 0.131947, 0.13097443)
# (901, 0.12754716, 0.12740497, 0.12665142)
# (902, 0.12808494, 0.12808529, 0.12605341)
# (903, 0.13046432, 0.13065243, 0.12882163)
# (904, 0.12973398, 0.12966532, 0.12869903)
# (905, 0.12867281, 0.12856135, 0.12754169)
# (906, 0.13313995, 0.1330713, 0.13235444)
# (907, 0.12879524, 0.12891504, 0.12828195)
# (908, 0.13016029, 0.13004842, 0.1287724)
# (909, 0.12936562, 0.12936653, 0.12869902)
# (910, 0.12894964, 0.128802, 0.13007964)
# (911, 0.12934111, 0.12924668, 0.12671791)
# (912, 0.1291686, 0.12909104, 0.12832285)
# (913, 0.1279061, 0.12790607, 0.12780607)
# (914, 0.12376265, 0.1237301, 0.124165624)
# (915, 0.1298576, 0.12998617, 0.12878057)
# (916, 0.13450453, 0.13453536, 0.13311878)
# (917, 0.12644525, 0.12616386, 0.12427421)
# (918, 0.1272087, 0.12702964, 0.12615052)
# (919, 0.12966804, 0.12959582, 0.12806274)
# (920, 0.12134622, 0.12128572, 0.11932332)
# (921, 0.12974772, 0.12957451, 0.1284373)
# (922, 0.12799081, 0.12794548, 0.12639965)
# (923, 0.12756714, 0.12752287, 0.1268169)
# (924, 0.1251572, 0.1251669, 0.12418491)
# (925, 0.12844306, 0.12838192, 0.12788397)
# (926, 0.1267409, 0.12671773, 0.1254929)
# (927, 0.13301645, 0.13303672, 0.13193762)
# (928, 0.1292381, 0.12949583, 0.12664871)
# (929, 0.12980357, 0.12956426, 0.12789153)
# (930, 0.13115148, 0.13125215, 0.13174844)
# (931, 0.13170819, 0.13163328, 0.13099056)
# (932, 0.12920934, 0.12892678, 0.126889)
# (933, 0.12685493, 0.1268659, 0.124560446)
# (934, 0.124805465, 0.124589644, 0.123718075)
# (935, 0.12278509, 0.1227726, 0.12176134)
# (936, 0.12395362, 0.12383352, 0.122598946)
# (937, 0.12968643, 0.1296492, 0.1285708)
# (938, 0.12588805, 0.12589014, 0.124135986)
# (939, 0.12955345, 0.12951796, 0.1289095)
# (940, 0.13422821, 0.13422404, 0.13173498)
# (941, 0.13189176, 0.13184626, 0.13059089)
# (942, 0.12341146, 0.12332785, 0.12224926)
# (943, 0.12992874, 0.12993976, 0.12884429)
# (944, 0.12844245, 0.12831804, 0.12685405)
# (945, 0.12571315, 0.12569858, 0.1237658)
# (946, 0.12324067, 0.123405084, 0.1227262)
# (947, 0.12607521, 0.12625213, 0.12532948)
# (948, 0.12809554, 0.12820509, 0.12650935)
# (949, 0.1276758, 0.1274935, 0.12612526)
# (950, 0.13435444, 0.13441554, 0.13371558)
# (951, 0.12331052, 0.1234043, 0.1228339)
# (952, 0.12694925, 0.1268585, 0.12613182)
# (953, 0.12955041, 0.12963144, 0.12954642)
# (954, 0.13040912, 0.13058294, 0.13151279)
# (955, 0.1325288, 0.1322993, 0.13005711)
# (956, 0.12632287, 0.12645477, 0.1262756)
# (957, 0.12622306, 0.12646005, 0.12547742)
# (958, 0.12799346, 0.12798905, 0.12649311)
# (959, 0.12204376, 0.122199096, 0.120971695)
# (960, 0.1295774, 0.12963927, 0.12827355)
# (961, 0.12402556, 0.12410995, 0.1230157)
# (962, 0.12311913, 0.12300693, 0.122429796)
# (963, 0.12468361, 0.12459565, 0.12284529)
# (964, 0.12474897, 0.124934845, 0.123169206)
# (965, 0.12505043, 0.12526317, 0.12355179)
# (966, 0.12922004, 0.1291854, 0.12742122)
# (967, 0.1287054, 0.12874267, 0.12725605)
# (968, 0.122612074, 0.122533835, 0.12095276)
# (969, 0.12582219, 0.12582867, 0.12488643)
# (970, 0.12590781, 0.12587664, 0.12460064)
# (971, 0.1359314, 0.13386598, 0.13157424)
# (972, 0.13055825, 0.1309502, 0.12865558)
# (973, 0.13539372, 0.13524973, 0.13388915)
# (974, 0.1318276, 0.1315858, 0.13044843)
# (975, 0.13309856, 0.13299797, 0.13018149)
# (976, 0.124803476, 0.12485019, 0.12541923)
# (977, 0.1305892, 0.13042152, 0.12870622)
# (978, 0.12635483, 0.1263678, 0.12602155)
# (979, 0.13407479, 0.1341812, 0.13331446)
# (980, 0.1272721, 0.1274464, 0.12566058)
# (981, 0.13353091, 0.13349365, 0.1306386)
# (982, 0.1370281, 0.13702019, 0.13588963)
# (983, 0.13063851, 0.13039744, 0.12982658)
# (984, 0.12443183, 0.12463966, 0.12347018)
# (985, 0.12956329, 0.12936623, 0.12789981)
# (986, 0.12534223, 0.12529519, 0.12436775)
# (987, 0.13417837, 0.13411996, 0.13420247)
# (988, 0.13034755, 0.13029508, 0.1305764)
# (989, 0.13527562, 0.13507895, 0.13299847)
# (990, 0.13137382, 0.13149148, 0.12898874)
# (991, 0.15071398, 0.14303708, 0.1307101)
# (992, 0.13089025, 0.13090315, 0.12969452)
# (993, 0.13024755, 0.1301939, 0.12963599)
# (994, 0.16610447, 0.1453223, 0.14831151)
# (995, 0.13966756, 0.13958548, 0.1382581)
# (996, 0.15808545, 0.13508283, 0.12984057)
# (997, 0.13148805, 0.13144246, 0.13193776)
# (998, 0.13254923, 0.1325919, 0.13625377)
# (999, 0.13653342, 0.13644701, 0.13250428)
# (1000, 0.13390388, 0.13395429, 0.12707129)
# (1001, 0.14097674, 0.132886, 0.13358958)
# (1002, 0.13003536, 0.13005075, 0.14927125)
# (1003, 0.13343817, 0.13360299, 0.12962395)
# (1004, 0.1332941, 0.13312006, 0.13457796)
# (1005, 0.1317111, 0.13180743, 0.13226016)
# (1006, 0.12943177, 0.12956524, 0.12638149)
# (1007, 0.124926366, 0.12501018, 0.12612322)
# (1008, 0.1299212, 0.1300183, 0.1296278)
# (1009, 0.12668563, 0.12703177, 0.12470182)
# (1010, 0.14117417, 0.13028476, 0.12575631)
# (1011, 0.12962604, 0.12946005, 0.12763622)
# (1012, 0.13060495, 0.13061956, 0.12989384)
# (1013, 0.1286863, 0.12858626, 0.12803584)
# (1014, 0.1260768, 0.1259186, 0.14197823)
# (1015, 0.12760794, 0.12749247, 0.12715542)
# (1016, 0.12693408, 0.12677343, 0.12498968)
# (1017, 0.12484508, 0.12499582, 0.12328171)
# (1018, 0.12696199, 0.12692937, 0.12684049)
# (1019, 0.12773538, 0.12800354, 0.12667412)
# (1020, 0.13280836, 0.13328433, 0.13119948)
# (1021, 0.12609278, 0.1261646, 0.12584999)
# (1022, 0.12971592, 0.12964799, 0.12797269)
# (1023, 0.12846217, 0.12862861, 0.12885262)
# (1024, 0.12688133, 0.12692302, 0.12689334)
# (1025, 0.1288927, 0.12925677, 0.12654446)
# (1026, 0.12674956, 0.12675934, 0.12632012)
# (1027, 0.13036603, 0.13058436, 0.1288939)
# (1028, 0.12596379, 0.12598756, 0.12556025)
# (1029, 0.12978354, 0.12964544, 0.12840164)
# (1030, 0.12741707, 0.12752762, 0.14559339)
# (1031, 0.13107498, 0.1310592, 0.12950678)
# (1032, 0.12592441, 0.12603132, 0.12442488)
# (1033, 0.1291095, 0.12907386, 0.12785049)
# (1034, 0.13100182, 0.13096207, 0.12998703)
# (1035, 0.13167706, 0.13168927, 0.1304475)
# (1036, 0.15107946, 0.13039331, 0.13133767)
# (1037, 0.12624338, 0.12606366, 0.12524952)
# (1038, 0.1318348, 0.1318596, 0.1297871)
# (1039, 0.12946557, 0.12914388, 0.12779357)
# (1040, 0.12469619, 0.124731585, 0.123479806)
# (1041, 0.13023883, 0.13027772, 0.12929313)
# (1042, 0.12998375, 0.12978238, 0.1284062)
# (1043, 0.12847927, 0.12873775, 0.12765789)
# (1044, 0.13065974, 0.1308296, 0.12872232)
# (1045, 0.13079718, 0.13065755, 0.13139844)
# (1046, 0.12749171, 0.12743697, 0.12866592)
# (1047, 0.13396178, 0.13402149, 0.1303923)
# (1048, 0.1267312, 0.12659754, 0.12789264)
# (1049, 0.1295074, 0.12940262, 0.13040161)
# (1050, 0.15119082, 0.13666753, 0.13476403)
# (1051, 0.13964139, 0.13971134, 0.13573664)
# (1052, 0.13006358, 0.13002163, 0.12846074)
# (1053, 0.13073112, 0.13052839, 0.13031542)
# (1054, 0.12887448, 0.12894002, 0.12539563)
# (1055, 0.12632039, 0.12641479, 0.1285594)
# (1056, 0.1334671, 0.13358977, 0.13610348)
# (1057, 0.1335477, 0.13341984, 0.13008717)
# (1058, 0.12896045, 0.12884527, 0.12704949)
# (1059, 0.13042071, 0.13045472, 0.13258964)
# (1060, 0.13245735, 0.13261488, 0.13069494)
# (1061, 0.13100989, 0.13093232, 0.1268767)
# (1062, 0.12890981, 0.12913488, 0.13034013)
# (1063, 0.12702745, 0.1271158, 0.12630762)
# (1064, 0.12898631, 0.12902062, 0.12570053)
# (1065, 0.12865987, 0.12895048, 0.1297715)
# (1066, 0.12870468, 0.12862131, 0.12956165)
# (1067, 0.12983811, 0.12979536, 0.12707835)
# (1068, 0.1321539, 0.13030256, 0.14082383)
# (1069, 0.12829405, 0.12814234, 0.12829258)
# (1070, 0.13495976, 0.13512938, 0.13107687)
# (1071, 0.13003127, 0.12997326, 0.12977502)
# (1072, 0.13236098, 0.13231629, 0.1328865)
# (1073, 0.13367558, 0.13355844, 0.13062564)
# (1074, 0.13142145, 0.1314134, 0.13081765)
# (1075, 0.13551202, 0.13543506, 0.13481833)
# (1076, 0.14422144, 0.13232687, 0.14104275)
# (1077, 0.13033481, 0.13028845, 0.13154584)
# (1078, 0.13279971, 0.13298121, 0.13380231)
# (1079, 0.1319217, 0.13223115, 0.12796193)
# (1080, 0.12695211, 0.12701868, 0.1293341)
# (1081, 0.13121575, 0.1312966, 0.13352679)
# (1082, 0.13645838, 0.13637394, 0.13241841)
# (1083, 0.13311103, 0.13329536, 0.12807089)
# (1084, 0.12774824, 0.12767392, 0.12870546)
# (1085, 0.12905279, 0.12907246, 0.12685588)
# (1086, 0.13065977, 0.13072646, 0.12854406)
# (1087, 0.1269941, 0.1267266, 0.12669969)
# (1088, 0.13590825, 0.13583289, 0.13351949)
# (1089, 0.12678601, 0.12641491, 0.12626748)
# (1090, 0.12634493, 0.12637138, 0.12514356)
# (1091, 0.12815484, 0.12811668, 0.12708063)
# (1092, 0.12709178, 0.1271475, 0.12505703)
# (1093, 0.12815562, 0.12825403, 0.12567432)
# (1094, 0.13297491, 0.13316268, 0.13211682)
# (1095, 0.12726629, 0.12741363, 0.12591165)
# (1096, 0.12657598, 0.12642866, 0.124818966)
# (1097, 0.13100772, 0.13097249, 0.1299728)
# (1098, 0.13183385, 0.13209784, 0.13857491)
# (1099, 0.12989436, 0.12985328, 0.12768176)
# (1100, 0.12352006, 0.12334879, 0.121562585)
# (1101, 0.12852456, 0.12857267, 0.12719646)
# (1102, 0.13532296, 0.135336, 0.13378818)
# (1103, 0.12682481, 0.12691145, 0.12586996)
# (1104, 0.12490384, 0.12494975, 0.12362461)
# (1105, 0.12742963, 0.12733082, 0.1252694)
# (1106, 0.12891865, 0.12909041, 0.12808745)
# (1107, 0.12715986, 0.12722231, 0.12615341)
# (1108, 0.13074316, 0.13084123, 0.130292)
# (1109, 0.13583569, 0.1359999, 0.1346266)
# (1110, 0.13023968, 0.13023823, 0.1291158)
# (1111, 0.12889439, 0.12873805, 0.12736675)
# (1112, 0.13015315, 0.13010281, 0.1298855)
# (1113, 0.13204381, 0.13194345, 0.1310778)
# (1114, 0.15394998, 0.13024214, 0.13013688)
# (1115, 0.12961778, 0.12959537, 0.12834007)
# (1116, 0.13002637, 0.12982126, 0.12708977)
# (1117, 0.13029157, 0.13050985, 0.12961629)
# (1118, 0.13195513, 0.1319522, 0.13161683)
# (1119, 0.13118194, 0.132835, 0.13371438)
# (1120, 0.1349475, 0.1350036, 0.13444406)
# (1121, 0.13409789, 0.13426483, 0.13169202)
# (1122, 0.13270733, 0.13285547, 0.12954098)
# (1123, 0.12628442, 0.12624522, 0.12532967)
# (1124, 0.13066241, 0.13060242, 0.13060062)
# (1125, 0.12814361, 0.12833413, 0.12739807)
# (1126, 0.12628719, 0.12629093, 0.12474688)
# (1127, 0.12796, 0.12788348, 0.12638964)
# (1128, 0.12956274, 0.12942638, 0.12795332)
# (1129, 0.12712248, 0.12694965, 0.1257706)
# (1130, 0.1302503, 0.13025498, 0.12865281)
# (1131, 0.12698634, 0.12696552, 0.12572896)
# (1132, 0.12663598, 0.12658098, 0.12423055)
# (1133, 0.12936577, 0.1295576, 0.12844191)
# (1134, 0.1321552, 0.13198632, 0.13158885)
# (1135, 0.1269094, 0.12705372, 0.12562087)
# (1136, 0.12643576, 0.12645903, 0.124096714)
# (1137, 0.13139296, 0.13143875, 0.1308191)
# (1138, 0.13567364, 0.13572805, 0.13564321)
# (1139, 0.13035657, 0.13036866, 0.12873149)
# (1140, 0.13162544, 0.13154267, 0.1292326)
# (1141, 0.12720667, 0.12719968, 0.1255064)
# (1142, 0.13234061, 0.1319545, 0.13110735)
# (1143, 0.12768582, 0.12756802, 0.12620878)
# (1144, 0.12772934, 0.12750575, 0.12595281)
# (1145, 0.13105084, 0.1308929, 0.12984635)
# (1146, 0.12935252, 0.12934826, 0.12756404)
# (1147, 0.13487312, 0.13488364, 0.1330533)
# (1148, 0.12728223, 0.12716657, 0.12501553)
# (1149, 0.13117632, 0.13100033, 0.12980883)
# (1150, 0.13529654, 0.13532636, 0.13361923)
# (1151, 0.12904929, 0.12897117, 0.12725551)
# ...
# (4624, 0.12940001, 0.12959045, 0.12823589)
# (4625, 0.13286202, 0.13280511, 0.13146)
# (4626, 0.12678131, 0.12669922, 0.12525879)
# (4627, 0.12980896, 0.12944518, 0.12851241)
# (4628, 0.1345117, 0.13463539, 0.13256973)
# (4629, 0.12148811, 0.12155586, 0.12030011)
# (4630, 0.12503803, 0.125087, 0.12352999)
# (4631, 0.13416618, 0.1342131, 0.1341113)
# (4632, 0.13201743, 0.13203001, 0.1310686)
# (4633, 0.13164157, 0.13163085, 0.12916093)
# (4634, 0.13114816, 0.13109078, 0.12934841)
# (4635, 0.13095357, 0.1309351, 0.1300721)
# (4636, 0.12816387, 0.12806861, 0.12667331)
# (4637, 0.12802002, 0.12825839, 0.12656257)
# (4638, 0.13000816, 0.12989339, 0.12858248)
# (4639, 0.12330003, 0.12317249, 0.121862754)
# (4640, 0.12661445, 0.12654772, 0.1250132)
# (4641, 0.1253353, 0.12546091, 0.12502459)
# (4642, 0.14950557, 0.13895123, 0.14105763)
# (4643, 0.13495089, 0.13489957, 0.13434221)
# (4644, 0.1316289, 0.13154684, 0.12665364)
# (4645, 0.13502935, 0.13489167, 0.13521898)
# (4646, 0.13356629, 0.13364948, 0.13334593)
# (4647, 0.13737121, 0.13757062, 0.13352701)
# (4648, 0.12600468, 0.12603123, 0.12766217)
# (4649, 0.13006607, 0.12995955, 0.13115178)
# (4650, 0.13638602, 0.13638976, 0.1325831)
# (4651, 0.12814932, 0.1279472, 0.12699333)
# (4652, 0.13184178, 0.15256335, 0.13781275)
# (4653, 0.13764592, 0.13761306, 0.13801017)
# (4654, 0.14114872, 0.1412402, 0.13583344)
# (4655, 0.13540033, 0.13535596, 0.13329336)
# (4656, 0.13082613, 0.1307402, 0.13089259)
# (4657, 0.1347652, 0.13477628, 0.13170038)
# (4658, 0.1313758, 0.13138591, 0.12766021)
# (4659, 0.12584111, 0.12594438, 0.12622504)
# (4660, 0.1272621, 0.12719971, 0.12601477)
# (4661, 0.12675363, 0.12671845, 0.12580888)
# (4662, 0.13104212, 0.13117659, 0.13116966)
# (4663, 0.13095285, 0.13088384, 0.12791005)
# (4664, 0.12271109, 0.122833535, 0.12337777)
# (4665, 0.12917323, 0.12923092, 0.12924246)
# (4666, 0.13032058, 0.1305502, 0.12767017)
# (4667, 0.13263187, 0.13246702, 0.1332454)
# (4668, 0.12916082, 0.1290739, 0.12973486)
# (4669, 0.12793179, 0.12776719, 0.12454453)
# (4670, 0.12855564, 0.12841325, 0.12927328)
# (4671, 0.13185614, 0.13191256, 0.1342316)
# (4672, 0.12992723, 0.12965779, 0.12682423)
# (4673, 0.12889913, 0.12884544, 0.12570277)
# (4674, 0.13202496, 0.13216533, 0.13280664)
# (4675, 0.1329928, 0.13284503, 0.13213536)
# (4676, 0.13268878, 0.13251458, 0.13022007)
# (4677, 0.13065943, 0.13041094, 0.13121077)
# (4678, 0.12923096, 0.12918247, 0.12901504)
# (4679, 0.12629038, 0.12619632, 0.122657806)
# (4680, 0.12908095, 0.12894884, 0.13080703)
# (4681, 0.13049506, 0.13037534, 0.13139564)
# (4682, 0.13265331, 0.13268104, 0.13107708)
# (4683, 0.13304052, 0.1331083, 0.1330469)
# (4684, 0.13440208, 0.1345664, 0.13491562)
# (4685, 0.13093849, 0.13128997, 0.12759693)
# (4686, 0.1272791, 0.12734428, 0.12711221)
# (4687, 0.13220774, 0.1320893, 0.13355425)
# (4688, 0.13371828, 0.13385244, 0.13136189)
# (4689, 0.12869258, 0.12791699, 0.1267742)
# (4690, 0.12681253, 0.12685415, 0.12647189)
# (4691, 0.12579247, 0.12546887, 0.123034626)
# (4692, 0.1253058, 0.12516248, 0.123850584)
# (4693, 0.12911415, 0.1292445, 0.12784176)
# (4694, 0.12695019, 0.12712978, 0.1253349)
# (4695, 0.12806715, 0.1247295, 0.122238785)
# (4696, 0.12728588, 0.12722011, 0.12687351)
# (4697, 0.12536989, 0.12548247, 0.12684515)
# (4698, 0.1259599, 0.12591903, 0.12503368)
# (4699, 0.12842058, 0.12860517, 0.12661713)
# (4700, 0.12706128, 0.12701473, 0.12575606)
# (4701, 0.12784651, 0.12799814, 0.12656887)
# (4702, 0.1307345, 0.13070463, 0.1296126)
# (4703, 0.12765121, 0.12737286, 0.12584962)
# (4704, 0.1263142, 0.12638895, 0.1252327)
# (4705, 0.13500327, 0.13526878, 0.13339747)
# (4706, 0.13120613, 0.13108571, 0.12948535)
# (4707, 0.12681797, 0.12662083, 0.12561683)
# (4708, 0.12890711, 0.12897979, 0.12740757)
# (4709, 0.12888277, 0.12905891, 0.12783974)
# (4710, 0.12888539, 0.12895454, 0.12849137)
# (4711, 0.13005652, 0.1301446, 0.12886907)
# (4712, 0.12745968, 0.12754478, 0.1262675)
# (4713, 0.12668158, 0.12667553, 0.12511581)
# (4714, 0.12799323, 0.1278385, 0.12696387)
# (4715, 0.13176975, 0.1318779, 0.13009124)
# (4716, 0.12494355, 0.1251651, 0.12397455)
# (4717, 0.12855862, 0.12854958, 0.12822576)
# (4718, 0.12549482, 0.12559, 0.124464534)
# (4719, 0.12897295, 0.12891522, 0.12789638)
# (4720, 0.1264614, 0.1265437, 0.12446766)
# (4721, 0.1274233, 0.12736098, 0.12696692)
# (4722, 0.1262132, 0.12640123, 0.1260201)
# (4723, 0.1305291, 0.13047369, 0.12938003)
# (4724, 0.14520504, 0.16714266, 0.13322334)
# (4725, 0.1311668, 0.13130768, 0.1295155)
# (4726, 0.13104367, 0.13095745, 0.12904404)
# (4727, 0.13193825, 0.13215087, 0.13117002)
# (4728, 0.1283224, 0.12839304, 0.12649333)
# (4729, 0.12670684, 0.12668839, 0.12661898)
# (4730, 0.12695341, 0.12685448, 0.12520126)
# (4731, 0.12497051, 0.12473959, 0.12391119)
# (4732, 0.12499161, 0.1247306, 0.123565204)
# (4733, 0.13032581, 0.13037968, 0.12879682)
# (4734, 0.13000172, 0.12994367, 0.12939447)
# (4735, 0.1349125, 0.13474181, 0.13267992)
# (4736, 0.123831, 0.12389589, 0.124042615)
# (4737, 0.13066399, 0.1305139, 0.12975739)
# (4738, 0.12947813, 0.12966377, 0.1286576)
# (4739, 0.12604094, 0.12642194, 0.12599182)
# (4740, 0.1266124, 0.12662798, 0.12460971)
# (4741, 0.12868366, 0.12858203, 0.12883209)
# (4742, 0.13136144, 0.13153574, 0.13213861)
# (4743, 0.12528977, 0.12548542, 0.12304712)
# (4744, 0.12884015, 0.1289002, 0.12837812)
# (4745, 0.12937517, 0.12910008, 0.12783632)
# (4746, 0.13046952, 0.13032568, 0.1302007)
# (4747, 0.12728992, 0.12732022, 0.12657098)
# (4748, 0.12762077, 0.12762016, 0.1265692)
# (4749, 0.12625468, 0.1261642, 0.12546185)
# (4750, 0.12969914, 0.12972647, 0.12794568)
# (4751, 0.12577216, 0.12585661, 0.124883294)
# (4752, 0.12876634, 0.12867352, 0.12742978)
# (4753, 0.12892745, 0.12907438, 0.1277336)
# (4754, 0.1271019, 0.12726048, 0.12577324)
# (4755, 0.12720497, 0.12748942, 0.12526737)
# (4756, 0.12467849, 0.1246309, 0.12276477)
# (4757, 0.1279105, 0.12813236, 0.12610736)
# (4758, 0.12438793, 0.12431598, 0.12320516)
# (4759, 0.12851214, 0.12824371, 0.12589481)
# (4760, 0.13070387, 0.13049978, 0.1304416)
# (4761, 0.13006674, 0.13014762, 0.12892208)
# (4762, 0.13044943, 0.13043684, 0.12845673)
# (4763, 0.1268848, 0.12699088, 0.1258893)
# (4764, 0.12778297, 0.12789199, 0.12768652)
# (4765, 0.12751906, 0.12769534, 0.12750655)
# (4766, 0.15007216, 0.15170431, 0.13194524)
# (4767, 0.1296655, 0.12965052, 0.12812297)
# (4768, 0.12921153, 0.1291492, 0.12960121)
# (4769, 0.13439459, 0.13450454, 0.13302237)
# (4770, 0.12589371, 0.12576528, 0.12338474)
# (4771, 0.123902924, 0.123928264, 0.12542816)
# (4772, 0.12855552, 0.12870835, 0.1281065)
# (4773, 0.1306339, 0.13069372, 0.12814611)
# (4774, 0.13093035, 0.13093205, 0.13049191)
# (4775, 0.16006586, 0.14277464, 0.1369326)
# (4776, 0.13456684, 0.15799889, 0.13975424)
# (4777, 0.14389987, 0.14404914, 0.1408854)
# (4778, 0.1342016, 0.13406527, 0.12920147)
# (4779, 0.1304977, 0.13058357, 0.13167548)
# (4780, 0.1343163, 0.13425799, 0.13680717)
# (4781, 0.13799998, 0.13781922, 0.13264269)
# (4782, 0.1434069, 0.14168876, 0.13211714)
# (4783, 0.13579379, 0.13565338, 0.13518927)
# (4784, 0.13594271, 0.1358516, 0.13561627)
# (4785, 0.1311404, 0.13079408, 0.12731993)
# (4786, 0.12758727, 0.12777096, 0.12810475)
# (4787, 0.1280964, 0.12790862, 0.12784672)
# (4788, 0.13082348, 0.13071857, 0.12861979)
# (4789, 0.1351635, 0.13528566, 0.13345726)
# (4790, 0.12581109, 0.12582493, 0.124132626)
# (4791, 0.13015917, 0.13010573, 0.1297728)
# (4792, 0.12950173, 0.12953655, 0.12877151)
# (4793, 0.14729352, 0.14075156, 0.13232844)
# (4794, 0.13025132, 0.13026342, 0.12917618)
# (4795, 0.1333647, 0.13336109, 0.13172947)
# (4796, 0.1280849, 0.12808889, 0.12658192)
# (4797, 0.12683377, 0.12674117, 0.12504293)
# (4798, 0.14234996, 0.123860426, 0.12247886)
# (4799, 0.13135357, 0.1309504, 0.12877063)
# (4800, 0.12677005, 0.12676495, 0.12516437)
# (4801, 0.12907954, 0.12904723, 0.1287556)
# (4802, 0.12839128, 0.12850894, 0.12745517)
# (4803, 0.13213629, 0.13211484, 0.12978671)
# (4804, 0.12813793, 0.12800206, 0.12660182)
# (4805, 0.13036698, 0.13035858, 0.12897523)
# (4806, 0.12576406, 0.1258282, 0.12395889)
# (4807, 0.1244601, 0.12440603, 0.12421003)
# (4808, 0.13088736, 0.13069315, 0.12938991)
# (4809, 0.12896638, 0.12890819, 0.12721626)
# (4810, 0.12806346, 0.12805015, 0.12678884)
# (4811, 0.13164212, 0.13173488, 0.13074014)
# (4812, 0.13365556, 0.13359302, 0.1315819)
# (4813, 0.12812091, 0.12798718, 0.1266565)
# (4814, 0.134521, 0.13449946, 0.1330832)
# (4815, 0.13033287, 0.13046338, 0.12956256)
# (4816, 0.13006823, 0.12987182, 0.12825109)
# (4817, 0.13435379, 0.13451838, 0.1338146)
# (4818, 0.12937209, 0.12935504, 0.12857848)
# (4819, 0.12731227, 0.1273707, 0.12589027)
# (4820, 0.12726314, 0.12738055, 0.12631561)
# (4821, 0.13042635, 0.13028987, 0.12912333)
# (4822, 0.13143434, 0.1312054, 0.12962931)
# (4823, 0.13357623, 0.13356, 0.13298953)
# (4824, 0.12629303, 0.12646084, 0.12570885)
# (4825, 0.1269413, 0.12690343, 0.1260266)
# (4826, 0.13138314, 0.13168609, 0.13068706)
# (4827, 0.13038635, 0.13046108, 0.1293915)
# (4828, 0.12808287, 0.12815793, 0.12693983)
# (4829, 0.12837946, 0.12843458, 0.12579083)
# (4830, 0.12905423, 0.12894018, 0.15478206)
# (4831, 0.12612173, 0.12612286, 0.12512693)
# (4832, 0.1299356, 0.13000652, 0.12897192)
# (4833, 0.12788367, 0.12818354, 0.1261257)
# (4834, 0.12943475, 0.12939836, 0.12814288)
# (4835, 0.12624404, 0.12618285, 0.12478141)
# (4836, 0.12455473, 0.1242917, 0.122466624)
# (4837, 0.13408734, 0.13412118, 0.13330375)
# (4838, 0.13012785, 0.13017645, 0.12921526)
# (4839, 0.13267294, 0.13295719, 0.13233285)
# (4840, 0.12949738, 0.12951411, 0.12875806)
# (4841, 0.12789619, 0.12791479, 0.12742227)
# (4842, 0.13033117, 0.13047075, 0.12946364)
# (4843, 0.125315, 0.12529543, 0.122937985)
# (4844, 0.12067556, 0.12086776, 0.11965017)
# (4845, 0.13268171, 0.13269216, 0.13131887)
# (4846, 0.1291676, 0.12908216, 0.12787691)
# (4847, 0.13108608, 0.13121447, 0.12942456)
# (4848, 0.1270572, 0.12691557, 0.125035)
# (4849, 0.12937832, 0.129396, 0.12890747)
# (4850, 0.1300169, 0.13003872, 0.12886594)
# (4851, 0.13570018, 0.129247, 0.14135478)
# (4852, 0.12981749, 0.1298413, 0.12797177)
# (4853, 0.1272119, 0.12733449, 0.12602484)
# (4854, 0.1264005, 0.12635076, 0.12519933)
# (4855, 0.124728866, 0.12464317, 0.123899855)
# (4856, 0.12638782, 0.12637787, 0.12670332)
# (4857, 0.12987238, 0.13004056, 0.12861705)
# (4858, 0.13029364, 0.13039374, 0.1302805)
# (4859, 0.1264131, 0.12639111, 0.12578654)
# (4860, 0.13169594, 0.13167919, 0.1315766)
# (4861, 0.13172975, 0.13180706, 0.13080887)
# (4862, 0.12771, 0.1277174, 0.12574273)
# (4863, 0.13222907, 0.13206866, 0.13048045)
# (4864, 0.13102087, 0.13115485, 0.1303061)
# (4865, 0.13184388, 0.13201366, 0.13145705)
# (4866, 0.13138855, 0.13158767, 0.12926756)
# (4867, 0.12742563, 0.1274133, 0.1242356)
# (4868, 0.1264211, 0.12659381, 0.12525341)
# (4869, 0.131347, 0.13133618, 0.13097803)
# (4870, 0.12813018, 0.12818873, 0.13192144)
# (4871, 0.13135567, 0.15874566, 0.13384795)
# (4872, 0.13249993, 0.13289168, 0.13193828)
# (4873, 0.12829795, 0.1282637, 0.12651299)
# (4874, 0.12731986, 0.12732776, 0.12558132)
# (4875, 0.13065854, 0.13064608, 0.13051897)
# (4876, 0.12914853, 0.12905279, 0.12877288)
# (4877, 0.12826565, 0.12790701, 0.12620538)
# (4878, 0.1345247, 0.13447861, 0.13405055)
# (4879, 0.13169156, 0.13163993, 0.12995815)
# (4880, 0.1303955, 0.1301594, 0.13001058)
# (4881, 0.13066421, 0.13085756, 0.1291678)
# (4882, 0.1317546, 0.1316926, 0.12964424)
# (4883, 0.12715712, 0.12709785, 0.12497112)
# (4884, 0.12690684, 0.12697063, 0.1257131)
# (4885, 0.12925106, 0.12936233, 0.12724757)
# (4886, 0.12877806, 0.12881175, 0.12672894)
# (4887, 0.12809013, 0.12806016, 0.12700957)
# (4888, 0.12786087, 0.1277768, 0.1261625)
# (4889, 0.13135922, 0.13118882, 0.12834264)
# (4890, 0.12526785, 0.12511778, 0.12400061)
# (4891, 0.12717193, 0.12710619, 0.12633088)
# (4892, 0.13081244, 0.13095993, 0.12888996)
# (4893, 0.1302316, 0.13495785, 0.13117777)
# (4894, 0.12537138, 0.12547424, 0.123612136)
# (4895, 0.12845044, 0.12863946, 0.12629502)
# (4896, 0.14955373, 0.12642303, 0.12623653)
# (4897, 0.1301268, 0.13005415, 0.12943791)
# (4898, 0.13029027, 0.12997541, 0.1281479)
# (4899, 0.13115908, 0.13112889, 0.12983438)
# (4900, 0.13494831, 0.13512217, 0.15322459)
# (4901, 0.12149621, 0.121512435, 0.121005684)
# (4902, 0.12858231, 0.12858184, 0.12843852)
# (4903, 0.123908155, 0.123889394, 0.12349624)
# (4904, 0.13126, 0.13133703, 0.13045542)
# (4905, 0.13330275, 0.13318555, 0.13168505)
# (4906, 0.13101116, 0.13096134, 0.13004586)
# (4907, 0.1297001, 0.1296934, 0.13067009)
# (4908, 0.12452008, 0.1242789, 0.12239585)
# (4909, 0.12924919, 0.12941782, 0.12782963)
# (4910, 0.13132219, 0.13138697, 0.12976116)
# (4911, 0.1273239, 0.1274751, 0.12569882)
# (4912, 0.13227248, 0.13223238, 0.13170138)
# (4913, 0.12638551, 0.1264758, 0.1267005)
# (4914, 0.1303941, 0.1304383, 0.12894502)
# (4915, 0.12939286, 0.12943147, 0.12881681)
# (4916, 0.13165814, 0.13194118, 0.13140535)
# (4917, 0.13619593, 0.13600096, 0.13514364)
# (4918, 0.12907512, 0.12909956, 0.1293368)
# (4919, 0.15278296, 0.14021078, 0.13517767)
# (4920, 0.13384576, 0.13398547, 0.1320621)
# (4921, 0.13384674, 0.13386667, 0.12997402)
# (4922, 0.12625708, 0.12605879, 0.1282664)
# (4923, 0.13231045, 0.1323066, 0.13389981)
# (4924, 0.1331433, 0.13296998, 0.12830198)
# (4925, 0.13331644, 0.13328432, 0.131212)
# (4926, 0.13069215, 0.13058846, 0.13112767)
# (4927, 0.13166879, 0.13159946, 0.12776184)
# (4928, 0.13094354, 0.13118744, 0.13098687)
# (4929, 0.1316387, 0.13180661, 0.13101687)
# (4930, 0.12850428, 0.12839667, 0.12670335)
# (4931, 0.12831816, 0.12821323, 0.12695254)
# (4932, 0.1260963, 0.12626517, 0.12546353)
# (4933, 0.12824461, 0.12828591, 0.12659375)
# (4934, 0.13036671, 0.13059577, 0.12936676)
# (4935, 0.12825502, 0.12830979, 0.12655051)
# (4936, 0.1302656, 0.13040607, 0.12821165)
# (4937, 0.130825, 0.13061962, 0.12883434)
# (4938, 0.12834744, 0.12839165, 0.1270555)
# (4939, 0.1310841, 0.1311175, 0.13015911)
# (4940, 0.13135432, 0.13117893, 0.12911206)
# (4941, 0.13282081, 0.13298093, 0.13128123)
# (4942, 0.1276398, 0.12767115, 0.12735412)
# (4943, 0.13397428, 0.13379657, 0.1328879)
# (4944, 0.13396898, 0.13392597, 0.13267745)
# (4945, 0.1336519, 0.13992965, 0.1295491)
# (4946, 0.1544019, 0.13657732, 0.13576157)
# (4947, 0.12893674, 0.12875627, 0.12550011)
# (4948, 0.13103673, 0.13103572, 0.1396703)
# (4949, 0.13464384, 0.13441432, 0.13404997)
# (4950, 0.12963255, 0.12974131, 0.12538242)
# (4951, 0.13309544, 0.13291663, 0.13458604)
# (4952, 0.13530007, 0.13525867, 0.13761355)
# (4953, 0.13638675, 0.13639297, 0.13167965)
# (4954, 0.13355446, 0.13341996, 0.13062651)
# (4955, 0.1309701, 0.13107587, 0.1315867)
# (4956, 0.12928815, 0.12948853, 0.12666439)
# (4957, 0.12979871, 0.12981282, 0.13255326)
# (4958, 0.1294697, 0.12950808, 0.12966159)
# (4959, 0.1301953, 0.13013864, 0.12739684)
# (4960, 0.12818485, 0.12813722, 0.12876046)
# (4961, 0.12675278, 0.12696403, 0.12793437)
# (4962, 0.13666768, 0.13676348, 0.13296376)
# (4963, 0.13015267, 0.13002805, 0.12942697)
# (4964, 0.13308673, 0.14531845, 0.14270253)
# (4965, 0.15031528, 0.15016995, 0.15116344)
# (4966, 0.14719701, 0.1472665, 0.1409636)
# (4967, 0.13298668, 0.13290532, 0.12599978)
# (4968, 0.12926696, 0.12919766, 0.13380243)
# (4969, 0.16201271, 0.13521448, 0.14617094)
# (4970, 0.14841974, 0.14807595, 0.14981368)
# (4971, 0.15018518, 0.15036577, 0.14264575)
# (4972, 0.14653808, 0.14577085, 0.1389651)
# (4973, 0.1381353, 0.1379936, 0.13629854)
# (4974, 0.1351609, 0.13518266, 0.13830231)
# (4975, 0.14137265, 0.14119363, 0.1394377)
# (4976, 0.13845658, 0.13865376, 0.13196978)
# (4977, 0.13339679, 0.13368767, 0.13470203)
# (4978, 0.13154995, 0.13134526, 0.1358368)
# (4979, 0.14200813, 0.14247215, 0.13944165)
# (4980, 0.13708963, 0.1372573, 0.13164131)
# (4981, 0.13069554, 0.1308853, 0.1331588)
# (4982, 0.13215038, 0.13224946, 0.13408136)
# (4983, 0.13105893, 0.13088602, 0.12892422)
# (4984, 0.13485193, 0.13467443, 0.13445841)
# (4985, 0.13680568, 0.13690403, 0.13754468)
# (4986, 0.132282, 0.13209733, 0.12990457)
# (4987, 0.13363981, 0.13369358, 0.12914972)
# (4988, 0.13028993, 0.13017355, 0.13106762)
# (4989, 0.14083555, 0.14094265, 0.14162874)
# (4990, 0.13292925, 0.13284498, 0.13019198)
# (4991, 0.1299463, 0.12977451, 0.12704131)
# (4992, 0.14231607, 0.15824844, 0.13970433)
# (4993, 0.1364737, 0.13644385, 0.13546017)
# (4994, 0.13857374, 0.13841766, 0.1330027)
# (4995, 0.12846401, 0.12870483, 0.1300923)
# (4996, 0.13825056, 0.13820921, 0.14084907)
# (4997, 0.13921687, 0.13913083, 0.13551123)
# (4998, 0.13586932, 0.13602532, 0.13152815)
# (4999, 0.12611012, 0.12593243, 0.12658845)

# %%
latent1[0]
# Out:
# array([[ 1.8469565e+00, -2.0311482e+00, -5.8038673e+00,  2.7713472e-01,
#          1.6377628e+00,  8.2375157e-01, -2.6657953e+00,  5.0620422e+00,
#         -6.0376823e-02,  3.1874533e+00,  1.0302423e+00, -6.1202307e+00,
#         -2.4329760e+00,  2.4286413e+00, -3.4713202e+00,  7.2898474e+00,
#         -8.9199549e-01, -4.9367228e+00, -3.0691891e+00,  7.6991220e+00,
#         -6.3268328e+00,  4.7815463e-01,  1.4231300e+00,  9.9989214e+00,
#          1.7121749e+00,  5.1866860e+00,  7.1832693e-01,  7.6489711e+00,
#          3.6136081e+00, -7.9121304e-01, -8.2072992e+00, -1.4476049e-01,
#          8.7026179e-01, -2.1837954e-01, -2.9249651e+00, -1.7303201e+00,
#          3.5174718e+00, -6.6384330e+00,  1.3802227e-01,  1.0841151e+00,
#          2.6166854e+00,  1.3699852e+00, -1.0343328e+01,  7.7217674e-01,
#          6.1627530e-02,  7.4885726e+00, -9.6130495e+00,  7.4505650e-02,
#          4.0727293e-01, -3.5477631e+00,  1.5383394e+00,  5.1068234e-01,
#         -1.8481859e+00,  1.0040369e+00,  3.5152572e-01, -5.5479007e+00,
#         -1.9526160e+00,  7.2597873e-01, -3.4359500e+00, -9.3261299e+00,
#          1.7745163e-02, -1.6780776e+00,  1.2746896e+00, -5.7272720e-01,
#          1.2098906e+00,  6.3532716e-01,  1.7118846e+00, -1.8080007e+00,
#          2.5423434e+00, -4.9005291e-01,  6.4682472e-01,  3.3051484e+00,
#          2.5104895e+00,  4.3286586e+00, -6.5607815e+00,  1.9218131e+00,
#         -4.6642742e-01, -2.3815579e+00,  5.2661818e-01,  1.3434341e+00,
#          2.2831996e-01, -3.0726042e+00,  1.2597494e+00,  3.7183020e+00,
#          3.6763927e-01, -2.0342159e+00,  1.2195694e+00,  9.6314877e-01,
#         -4.8797542e-01,  3.1767697e+00,  1.1999153e+00, -2.8238940e+00,
#         -5.8226290e+00, -1.2883611e-02, -1.7558963e+00, -5.5276237e+00,
#         -1.9709206e-01, -2.2831680e-01, -2.3592539e+00, -2.1496456e+00,
#         -1.4953892e+00, -4.0512347e+00, -8.6046352e+00,  5.9799874e-01,
#          8.0593481e+00, -1.6606523e+00, -7.7376013e+00,  2.4069946e+00,
#         -2.0123591e-01, -1.9906071e+00, -1.6398263e+00, -2.7414021e-01,
#         -4.6098369e-01,  2.2620524e-01, -2.0145669e+00,  1.8246689e+00,
#          5.0451813e+00,  2.2364373e+00,  1.3966209e-01,  1.2410618e+00,
#          2.3684325e+00, -8.5168819e+00,  2.7686888e-01,  1.5308719e+00,
#         -1.6407053e+00, -1.7877103e+00,  2.4074275e+00,  8.3009100e-01,
#         -5.1534021e-01,  8.5730970e-01,  8.7445337e-01, -7.7894607e+00,
#         -8.1616390e-01, -1.9456470e+00,  1.9870033e+00,  2.9557383e+00,
#         -2.5790755e-02,  7.9592228e+00,  3.2577515e-01, -4.6146131e+00,
#         -1.9468871e-01,  3.9815571e+00,  9.5461521e+00, -5.7159472e+00,
#          3.6295195e+00,  2.7129033e-01,  1.1015181e-01, -1.7490803e-01,
#          7.4868879e+00, -6.8892157e-01,  6.5193496e+00,  1.9050722e-01,
#          1.3488359e+00,  9.7108835e-01,  8.7379062e-01, -2.6352385e-01,
#         -1.6684120e+00,  2.5495586e-01,  2.2844601e-01, -2.2286940e+00,
#         -8.5143112e-02,  4.9510527e-01,  6.0679513e-01,  3.0783761e+00,
#          2.2724955e-01,  1.8354256e+00,  3.7313807e-01, -1.2828803e+00,
#          7.6903164e-01,  1.7035475e+00,  1.9294790e+00, -4.0620685e-01,
#          1.3326209e+01,  5.1961070e-01, -4.4586840e+00,  8.7391558e+00,
#          1.7998768e+00, -1.8984087e+00,  9.0551978e-01,  2.6489446e-01,
#         -3.7195414e-01,  1.4957498e+00, -5.0387061e-01, -7.5062895e-01,
#          5.5067725e+00,  1.0554621e+00,  1.6877854e+00,  2.6936374e+00,
#         -1.5933223e+00, -3.2075109e+00,  7.9952826e+00,  1.8892831e+00,
#          1.4080014e+00, -1.2716867e+00, -2.2809141e+00,  1.4681828e+00,
#         -6.7889342e+00,  2.0788945e-03, -3.8102582e+00, -4.7607961e-01,
#         -3.6624134e-01, -2.3878949e+00,  9.1099560e-01, -1.2882540e+00,
#          1.7169334e-02, -9.3566608e+00,  5.0206256e-01, -2.1909592e+00,
#          9.8762548e-01, -3.3208060e+00,  4.4782400e+00,  4.4326857e-01,
#          2.6311862e+00, -2.8751147e+00,  1.5391777e+00,  3.2895131e+00,
#          9.7930634e-01,  7.0060062e+00,  1.4503132e+00, -8.7841678e-01,
#         -7.1227646e+00,  4.3160849e+00, -1.9915805e+00, -2.1511126e+00,
#         -1.0309233e+01, -2.9981368e+00,  1.9344069e+00,  2.8194818e-01,
#         -5.2939315e+00, -6.8661928e+00,  3.3781844e-01, -2.1879821e+00,
#          2.5640523e-01,  1.4378984e+00, -4.8505169e-01,  4.2826419e+00,
#          3.1799382e-01,  3.3443811e+00,  2.0756993e+00, -5.8227425e+00,
#         -6.3807836e+00, -2.2880055e-01, -2.0314696e+00,  5.7045406e-01,
#         -5.2226229e+00, -2.2134225e+00,  1.6761039e-01, -3.4752461e-01,
#         -3.9445725e-01,  1.8400429e+00,  1.8142098e+00, -5.8486843e+00,
#         -2.3189158e+00, -1.0127730e-01, -2.0128341e+00, -3.1927428e+00]],
#       dtype=float32)
# array([[ 1.8469565e+00, -2.0311482e+00, -5.8038673e+00,  2.7713472e-01,
#          1.6377628e+00,  8.2375157e-01, -2.6657953e+00,  5.0620422e+00,
#         -6.0376823e-02,  3.1874533e+00,  1.0302423e+00, -6.1202307e+00,
#         -2.4329760e+00,  2.4286413e+00, -3.4713202e+00,  7.2898474e+00,
#         -8.9199549e-01, -4.9367228e+00, -3.0691891e+00,  7.6991220e+00,
#         -6.3268328e+00,  4.7815463e-01,  1.4231300e+00,  9.9989214e+00,
#          1.7121749e+00,  5.1866860e+00,  7.1832693e-01,  7.6489711e+00,
#          3.6136081e+00, -7.9121304e-01, -8.2072992e+00, -1.4476049e-01,
#          8.7026179e-01, -2.1837954e-01, -2.9249651e+00, -1.7303201e+00,
#          3.5174718e+00, -6.6384330e+00,  1.3802227e-01,  1.0841151e+00,
#          2.6166854e+00,  1.3699852e+00, -1.0343328e+01,  7.7217674e-01,
#          6.1627530e-02,  7.4885726e+00, -9.6130495e+00,  7.4505650e-02,
#          4.0727293e-01, -3.5477631e+00,  1.5383394e+00,  5.1068234e-01,
#         -1.8481859e+00,  1.0040369e+00,  3.5152572e-01, -5.5479007e+00,
#         -1.9526160e+00,  7.2597873e-01, -3.4359500e+00, -9.3261299e+00,
#          1.7745163e-02, -1.6780776e+00,  1.2746896e+00, -5.7272720e-01,
#          1.2098906e+00,  6.3532716e-01,  1.7118846e+00, -1.8080007e+00,
#          2.5423434e+00, -4.9005291e-01,  6.4682472e-01,  3.3051484e+00,
#          2.5104895e+00,  4.3286586e+00, -6.5607815e+00,  1.9218131e+00,
#         -4.6642742e-01, -2.3815579e+00,  5.2661818e-01,  1.3434341e+00,
#          2.2831996e-01, -3.0726042e+00,  1.2597494e+00,  3.7183020e+00,
#          3.6763927e-01, -2.0342159e+00,  1.2195694e+00,  9.6314877e-01,
#         -4.8797542e-01,  3.1767697e+00,  1.1999153e+00, -2.8238940e+00,
#         -5.8226290e+00, -1.2883611e-02, -1.7558963e+00, -5.5276237e+00,
#         -1.9709206e-01, -2.2831680e-01, -2.3592539e+00, -2.1496456e+00,
#         -1.4953892e+00, -4.0512347e+00, -8.6046352e+00,  5.9799874e-01,
#          8.0593481e+00, -1.6606523e+00, -7.7376013e+00,  2.4069946e+00,
#         -2.0123591e-01, -1.9906071e+00, -1.6398263e+00, -2.7414021e-01,
#         -4.6098369e-01,  2.2620524e-01, -2.0145669e+00,  1.8246689e+00,
#          5.0451813e+00,  2.2364373e+00,  1.3966209e-01,  1.2410618e+00,
#          2.3684325e+00, -8.5168819e+00,  2.7686888e-01,  1.5308719e+00,
#         -1.6407053e+00, -1.7877103e+00,  2.4074275e+00,  8.3009100e-01,
#         -5.1534021e-01,  8.5730970e-01,  8.7445337e-01, -7.7894607e+00,
#         -8.1616390e-01, -1.9456470e+00,  1.9870033e+00,  2.9557383e+00,
#         -2.5790755e-02,  7.9592228e+00,  3.2577515e-01, -4.6146131e+00,
#         -1.9468871e-01,  3.9815571e+00,  9.5461521e+00, -5.7159472e+00,
#          3.6295195e+00,  2.7129033e-01,  1.1015181e-01, -1.7490803e-01,
#          7.4868879e+00, -6.8892157e-01,  6.5193496e+00,  1.9050722e-01,
#          1.3488359e+00,  9.7108835e-01,  8.7379062e-01, -2.6352385e-01,
#         -1.6684120e+00,  2.5495586e-01,  2.2844601e-01, -2.2286940e+00,
#         -8.5143112e-02,  4.9510527e-01,  6.0679513e-01,  3.0783761e+00,
#          2.2724955e-01,  1.8354256e+00,  3.7313807e-01, -1.2828803e+00,
#          7.6903164e-01,  1.7035475e+00,  1.9294790e+00, -4.0620685e-01,
#          1.3326209e+01,  5.1961070e-01, -4.4586840e+00,  8.7391558e+00,
#          1.7998768e+00, -1.8984087e+00,  9.0551978e-01,  2.6489446e-01,
#         -3.7195414e-01,  1.4957498e+00, -5.0387061e-01, -7.5062895e-01,
#          5.5067725e+00,  1.0554621e+00,  1.6877854e+00,  2.6936374e+00,
#         -1.5933223e+00, -3.2075109e+00,  7.9952826e+00,  1.8892831e+00,
#          1.4080014e+00, -1.2716867e+00, -2.2809141e+00,  1.4681828e+00,
#         -6.7889342e+00,  2.0788945e-03, -3.8102582e+00, -4.7607961e-01,
#         -3.6624134e-01, -2.3878949e+00,  9.1099560e-01, -1.2882540e+00,
#          1.7169334e-02, -9.3566608e+00,  5.0206256e-01, -2.1909592e+00,
#          9.8762548e-01, -3.3208060e+00,  4.4782400e+00,  4.4326857e-01,
#          2.6311862e+00, -2.8751147e+00,  1.5391777e+00,  3.2895131e+00,
#          9.7930634e-01,  7.0060062e+00,  1.4503132e+00, -8.7841678e-01,
#         -7.1227646e+00,  4.3160849e+00, -1.9915805e+00, -2.1511126e+00,
#         -1.0309233e+01, -2.9981368e+00,  1.9344069e+00,  2.8194818e-01,
#         -5.2939315e+00, -6.8661928e+00,  3.3781844e-01, -2.1879821e+00,
#          2.5640523e-01,  1.4378984e+00, -4.8505169e-01,  4.2826419e+00,
#          3.1799382e-01,  3.3443811e+00,  2.0756993e+00, -5.8227425e+00,
#         -6.3807836e+00, -2.2880055e-01, -2.0314696e+00,  5.7045406e-01,
#         -5.2226229e+00, -2.2134225e+00,  1.6761039e-01, -3.4752461e-01,
#         -3.9445725e-01,  1.8400429e+00,  1.8142098e+00, -5.8486843e+00,
#         -2.3189158e+00, -1.0127730e-01, -2.0128341e+00, -3.1927428e+00]],
#       dtype=float32)

# %%
import ot
from matplotlib.colors import LogNorm
import numpy as np
import matplotlib.pyplot as plt

# %%
numload = 50
feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
z_means, z_log_vars, z_sampled = ae.transform(feed_pc)

# %%
recon, loss = ae.partial_fit(feed_pc, beta = 0, GT=None)
print(loss)
# Out:
# 163.81091

# %%
for i,dataset in enumerate(z_log_vars.T[:100]):
    print(i)
    plt.hist(dataset,bins=np.arange(-100,0.1,0.1),alpha=0.2)
    plt.show()
# Out:
# 0
# 1
# 2
# 3
# KeyboardInterruptTraceback (most recent call last)
# <ipython-input-17-8644cf7bd07a> in <module>()
#       1 for i,dataset in enumerate(z_log_vars.T[:100]):
#       2     print(i)
# ----> 3     plt.hist(dataset,bins=np.arange(-100,0.1,0.1),alpha=0.2)
#       4     plt.show()
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, normed, hold, data, **kwargs)
#    3130                       histtype=histtype, align=align, orientation=orientation,
#    3131                       rwidth=rwidth, log=log, color=color, label=label,
# -> 3132                       stacked=stacked, normed=normed, data=data, **kwargs)
#    3133     finally:
#    3134         ax._hold = washold
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in hist(***failed resolving arguments***)
#    6604                 patch = _barfunc(bins[:-1]+boffset, height, width,
#    6605                                  align='center', log=log,
# -> 6606                                  color=c, **{bottom_kwarg: bottom})
#    6607                 patches.append(patch)
#    6608                 if stacked:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.pyc in bar(self, *args, **kwargs)
#    2284             elif orientation == 'horizontal':
#    2285                 r.sticky_edges.x.append(l)
# -> 2286             self.add_patch(r)
#    2287             patches.append(r)
#    2288
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in add_patch(self, p)
#    2005         if p.get_clip_path() is None:
#    2006             p.set_clip_path(self.patch)
# -> 2007         self._update_patch_limits(p)
#    2008         self.patches.append(p)
#    2009         p._remove_method = lambda h: self.patches.remove(h)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_base.pyc in _update_patch_limits(self, patch)
#    2032
#    2033             updatex, updatey = patch.get_transform().\
# -> 2034                 contains_branch_seperately(self.transData)
#    2035             self.update_datalim(xys, updatex=updatex,
#    2036                                 updatey=updatey)
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in contains_branch_seperately(self, other_transform)
#    1374         # for a non-blended transform each separate dimension is the same, so
#    1375         # just return the appropriate shape.
# -> 1376         return [self.contains_branch(other_transform)] * 2
#    1377
#    1378     def __sub__(self, other):
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in contains_branch(self, other)
#    1354         # check that a subtree is equal to other (starting from self)
#    1355         for _, sub_tree in self._iter_break_from_left_to_right():
# -> 1356             if sub_tree == other:
#    1357                 return True
#    1358         return False
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in __eq__(self, other)
#    2449     def __eq__(self, other):
#    2450         if isinstance(other, (CompositeGenericTransform, CompositeAffine2D)):
# -> 2451             return self is other or (self._a == other._a and self._b == other._b)
#    2452         else:
#    2453             return False
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in __eq__(self, other)
#    2449     def __eq__(self, other):
#    2450         if isinstance(other, (CompositeGenericTransform, CompositeAffine2D)):
# -> 2451             return self is other or (self._a == other._a and self._b == other._b)
#    2452         else:
#    2453             return False
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in __eq__(self, other)
#    1679
#    1680     def __eq__(self, other):
# -> 1681         return self._child.__eq__(other)
#    1682
#    1683     # NOTE: Transform.__[gs]etstate__ should be sufficient when using only
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in __eq__(self, other)
#    2343         if isinstance(other, (BlendedAffine2D, BlendedGenericTransform)):
#    2344             return (self._x == other._x) and (self._y == other._y)
# -> 2345         elif self._x == self._y:
#    2346             return self._x == other
#    2347         else:
#
# /usr/local/lib/python2.7/dist-packages/matplotlib/transforms.pyc in __eq__(self, other)
#    1790     def __eq__(self, other):
#    1791         if getattr(other, "is_affine", False):
# -> 1792             return np.all(self.get_matrix() == other.get_matrix())
#    1793         return NotImplemented
#    1794
#
# /home/jcollins/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in all(a, axis, out, keepdims)
#    2243
#    2244     """
# -> 2245     return _wrapreduction(a, np.logical_and, 'all', axis, None, out, keepdims=keepdims)
#    2246
#    2247
#
# /home/jcollins/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# KeyboardInterrupt:

# %%
for dataset in z_log_vars.T[:20]:
    plt.hist(dataset,bins=np.arange(-80,0.1,1),alpha=0.2)
plt.show()

# %%
traindata[0]
# Out:
# array([[ 0.97368664, -0.71363292],
#        [ 0.97368664, -0.71363292],
#        [ 0.97368664, -0.71363292],
#        ...,
#        [ 1.0140427 , -0.37483655],
#        [ 1.0140427 , -0.37483655],
#        [ 1.0140427 , -0.37483655]])

# %%
for dataset in z_means.T[:20]:
    plt.hist(dataset,bins=np.arange(-100,100,1.),alpha=0.2)
plt.show()

# %%
ae.transform(feed_pc)[0].shape
# Out:
# (1000, 100)

# %%
numload = 1000
latent_codes = np.zeros((0,100))
for i in range(-10,10):dd
    feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
    latent_codes = np.append(latent_codes,ae.transform(feed_pc),axis=0)


plt.hist2d(latent_codes[:,0],latent_codes[:,1],norm=LogNorm(0.5, 1000),bins=20, range = [[-1,1],[-1,1]])
plt.show()
# Out:
#   File "<ipython-input-22-5ea8408fdb4b>", line 4
#     feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
#     ^
# IndentationError: unexpected indent

# %%
numload = 200
feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
reconstructions = ae.reconstruct(feed_pc)[0]
latent_codes = ae.transform(feed_pc)

# %%
in_points=tf.placeholder(tf.float32,shape=[100,100,3])
out_points=tf.placeholder(tf.float32,shape=[100,500,2])
init_op = tf.global_variables_initializer()

_, _, in_weights = tf.unstack(in_points,axis=-1)
ground_distance, ground_dist_gradient = ground_distance_tf(in_points[:,:,1:],out_points)

with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    dist, grad = sess.run([ground_distance,ground_dist_gradient], feed_dict={in_points:feed_pc, out_points:reconstructions})

# %%
reconstructions
# Out:
# array([[[ -7.92789   ,   1.6863276 ],
#         [ -6.0499053 ,   1.2907183 ],
#         [ -3.4191995 ,   0.7337208 ],
#         ...,
#         [ -5.399719  ,   1.2065184 ],
#         [ -4.980148  ,   1.0516655 ],
#         [ -1.9284803 ,   0.46541935]],
#
#        [[ -4.3450704 ,   0.9747368 ],
#         [ -3.1714032 ,   0.711394  ],
#         [ -1.7115015 ,   0.4123564 ],
#         ...,
#         [ -4.4967585 ,   1.0210874 ],
#         [ -4.5486956 ,   0.98092633],
#         [ -1.7429587 ,   0.43494958]],
#
#        [[ -3.2769887 ,   0.75575364],
#         [ -2.3740065 ,   0.57077086],
#         [ -1.2686746 ,   0.34898242],
#         ...,
#         [ -2.913241  ,   0.69329005],
#         [ -2.5602899 ,   0.5972383 ],
#         [ -0.8261831 ,   0.27380705]],
#
#        ...,
#
#        [[ -2.848798  ,   0.67896265],
#         [ -2.2163227 ,   0.52937627],
#         [ -1.1756691 ,   0.32394588],
#         ...,
#         [ -5.278678  ,   1.1870376 ],
#         [ -4.743942  ,   1.018565  ],
#         [ -1.7910022 ,   0.44258848]],
#
#        [[ -5.261397  ,   1.169075  ],
#         [ -3.6027398 ,   0.80134463],
#         [ -2.1843395 ,   0.49354196],
#         ...,
#         [-11.678808  ,   2.4893284 ],
#         [-10.275965  ,   2.0736303 ],
#         [ -3.9828987 ,   0.8442383 ]],
#
#        [[-19.449215  ,   4.03411   ],
#         [-19.990559  ,   4.108331  ],
#         [-14.994591  ,   3.0756066 ],
#         ...,
#         [-21.233185  ,   4.3797226 ],
#         [-19.885931  ,   3.8924613 ],
#         [ -7.023012  ,   1.4372308 ]]], dtype=float32)

# %%
dist[0]
# Out:
# array([[1.548934  , 3.0802968 , 0.72839737, ..., 1.4902238 , 1.5148542 ,
#         0.5509331 ],
#        [1.565194  , 3.0695329 , 0.76002306, ..., 1.5115544 , 1.5292788 ,
#         0.58469605],
#        [1.538139  , 3.0359797 , 0.7842886 , ..., 1.4878217 , 1.501229  ,
#         0.60655415],
#        ...,
#        [2.4897516 , 1.3135799 , 3.0416355 , ..., 2.6982105 , 2.4057548 ,
#         3.2140806 ],
#        [2.4897516 , 1.3135799 , 3.0416355 , ..., 2.6982105 , 2.4057548 ,
#         3.2140806 ],
#        [2.4897516 , 1.3135799 , 3.0416355 , ..., 2.6982105 , 2.4057548 ,
#         3.2140806 ]], dtype=float32)

# %%
grad[0]
# Out:
# array([[[ 0.20839977, -0.97804374],
#         [-0.65650094, -0.7543253 ],
#         [-0.9626721 , -0.27067026],
#         ...,
#         [ 0.9699383 ,  0.243351  ],
#         [ 0.9795503 ,  0.20119914],
#         [ 0.6619373 ,  0.7495591 ]],
#
#        [[-0.67767996, -0.7353571 ],
#         [-0.8635891 , -0.50419617],
#         [-0.9304655 , -0.36637947],
#         ...,
#         [-0.38630092, -0.9223728 ],
#         [-0.8964121 , -0.44322172],
#         [ 0.02674261,  0.9996423 ]],
#
#        [[-0.9628488 ,  0.27004132],
#         [-0.94281584,  0.3333141 ],
#         [-0.8545148 ,  0.51942724],
#         ...,
#         [-0.03292192,  0.9994579 ],
#         [-0.6403309 ,  0.7680991 ],
#         [ 0.0336301 ,  0.99943435]],
#
#        ...,
#
#        [[-0.99210596,  0.1254026 ],
#         [-0.9882939 ,  0.15256223],
#         [-0.97928005,  0.20251085],
#         ...,
#         [-0.94955814,  0.3135911 ],
#         [-0.97004575,  0.24292232],
#         [-0.8731324 ,  0.48748326]],
#
#        [[-0.99210596,  0.1254026 ],
#         [-0.9882939 ,  0.15256223],
#         [-0.97928005,  0.20251085],
#         ...,
#         [-0.94955814,  0.3135911 ],
#         [-0.97004575,  0.24292232],
#         [-0.8731324 ,  0.48748326]],
#
#        [[-0.99210596,  0.1254026 ],
#         [-0.9882939 ,  0.15256223],
#         [-0.97928005,  0.20251085],
#         ...,
#         [-0.94955814,  0.3135911 ],
#         [-0.97004575,  0.24292232],
#         [-0.8731324 ,  0.48748326]]], dtype=float32)

# %%
in_points=tf.placeholder(tf.float32,shape=[100,100,3])
out_points=tf.placeholder(tf.float32,shape=[100,500,2])
init_op = tf.global_variables_initializer()

in_weights, _, _ = tf.unstack(in_points,axis=-1)
ground_distance, ground_dist_gradient = ground_distance_tf(in_points[:,:,1:],out_points,mod2pi=False)

conf.numItermax = 5
conf.stopThr = 1e-2
conf.sinkhorn_reg = 0.1
loss = sinkhorn_loss_tf(in_points[:,:,1:],out_points,conf, in_weights=in_weights)
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables()) #execute init_op
    Ms, losses = sess.run([ground_distance, loss], feed_dict={in_points:feed_pc, out_points:reconstructions})
    
emd_losses = [ot.emd2(np.ascontiguousarray(feed_pc[i,:,0]),np.ascontiguousarray(np.ones(500)/500.),Ms[i]) for i in range(100)]

# %%
np.vstack([emd_losses, losses]).T
# Out:
# array([[ 9.94253794,  3.17226696],
#        [ 4.19061901,  2.15693951],
#        [ 5.00150026,  2.17669368],
#        [ 7.44975356,  1.58485901],
#        [15.74331065,  4.5559845 ],
#        [ 7.83502962,  2.66109276],
#        [ 8.53699436,  1.81343365],
#        [14.5894864 ,  4.77518749],
#        [ 7.16490577,  1.5002507 ],
#        [23.63764696,  6.17039871],
#        [ 7.11817148,  2.1011138 ],
#        [10.68708032,  2.10292244],
#        [ 4.92950017,  1.99573588],
#        [12.3558789 ,  2.75070667],
#        [ 4.86376011,  1.94748878],
#        [12.02497643,  3.42879128],
#        [10.55148488,  2.53962326],
#        [ 6.32235711,  1.89407003],
#        [ 6.74490847,  1.51711082],
#        [ 4.96216967,  1.97295761],
#        [13.22111047,  2.24490881],
#        [ 6.95257546,  1.61705971],
#        [ 5.54513431,  2.04946995],
#        [ 5.06014123,  1.79991257],
#        [ 5.09142087,  1.8220346 ],
#        [ 4.88106774,  2.46383905],
#        [ 9.84233864,  2.40103984],
#        [ 3.50736924,  1.65891683],
#        [ 4.77183014,  2.94813228],
#        [ 5.49712523,  1.90061235],
#        [ 8.73607926,  1.55132043],
#        [ 6.41660572,  2.69504714],
#        [ 3.9067101 ,  3.00850725],
#        [ 2.49537751,  1.34916353],
#        [ 9.12987073,  3.03628635],
#        [13.33304422,  2.60550284],
#        [14.32680429,  2.99900842],
#        [ 3.88745126,  2.54398322],
#        [12.00420181,  2.92496729],
#        [ 1.81496323,  1.39181685],
#        [ 3.1143392 ,  1.84556615],
#        [ 5.08865518,  2.8123064 ],
#        [ 7.35062296,  3.17138362],
#        [ 4.09298014,  2.06610298],
#        [ 9.3291332 ,  3.6051476 ],
#        [ 5.04356861,  1.88323426],
#        [13.24488943,  2.93879843],
#        [ 5.01679145,  1.69677258],
#        [ 6.79696612,  3.25578666],
#        [ 6.6955228 ,  2.71877193],
#        [ 7.74618633,  1.79285085],
#        [ 9.68462063,  2.12673163],
#        [ 7.05067995,  2.11938667],
#        [15.18640398,  3.94080567],
#        [13.63745438,  2.93166375],
#        [ 7.93794123,  2.19373417],
#        [ 8.40296132,  3.96953297],
#        [ 5.97407067,  3.13862324],
#        [ 5.97785091,  2.31648397],
#        [ 4.39991616,  1.68608844],
#        [14.03999276,  2.5717361 ],
#        [ 7.39512665,  2.92160678],
#        [ 3.52886809,  1.7661258 ],
#        [ 5.73273626,  3.11114335],
#        [ 2.50917836,  1.28195608],
#        [ 6.00511786,  1.63505411],
#        [10.71300411,  3.43134093],
#        [ 4.00603531,  1.65948248],
#        [20.61821718,  4.06170321],
#        [ 9.16776672,  2.32440448],
#        [14.96399991,  2.4299469 ],
#        [16.13197798,  4.39063072],
#        [ 6.69362987,  1.76486671],
#        [16.33403102,  3.25617242],
#        [ 6.45090094,  2.39412045],
#        [13.92027861,  2.25820661],
#        [ 6.0565238 ,  2.37458682],
#        [ 5.29276328,  1.5528245 ],
#        [ 8.59301389,  2.55594993],
#        [ 8.36952749,  2.67715311],
#        [ 4.58942634,  1.79505622],
#        [10.00927098,  2.47289538],
#        [ 9.57300363,  2.66501331],
#        [ 7.65902966,  3.22758365],
#        [10.12405631,  4.23195171],
#        [ 4.27455706,  1.68174255],
#        [ 3.57546775,  1.80525088],
#        [ 9.57190253,  2.96819687],
#        [ 7.48795346,  1.55123091],
#        [ 8.27956176,  2.47665048],
#        [ 9.07162218,  2.20836782],
#        [10.20546153,  2.14691949],
#        [ 7.23103107,  2.36903644],
#        [ 4.53193165,  2.35898614],
#        [ 9.78898444,  3.32857037],
#        [ 9.72143314,  2.99035406],
#        [ 7.7058297 ,  2.4081974 ],
#        [ 7.86304125,  2.60332417],
#        [10.25144587,  2.22761178],
#        [23.2404462 ,  5.12490749]])

# %%
np.vstack([emd_losses, losses]).T
# Out:
# array([[0.10012206, 0.11451511],
#        [0.16238315, 0.1770643 ],
#        [0.23483574, 0.24871121],
#        [0.11501631, 0.12342104],
#        [0.16470757, 0.17627278],
#        [0.12299131, 0.13391925],
#        [0.149203  , 0.13750276],
#        [0.17957428, 0.19369826],
#        [0.14964896, 0.13951601],
#        [0.11993736, 0.13744301],
#        [0.16138004, 0.17454897],
#        [0.12129371, 0.13198951],
#        [0.19571544, 0.20744021],
#        [0.15042603, 0.16847855],
#        [0.13576658, 0.15029341],
#        [0.12750727, 0.14101464],
#        [0.16292993, 0.16779552],
#        [0.15336171, 0.16708928],
#        [0.13910128, 0.15333018],
#        [0.16452498, 0.17432545],
#        [0.13189799, 0.14526998],
#        [0.20231219, 0.18086123],
#        [0.12961353, 0.14514539],
#        [0.12531325, 0.13685587],
#        [0.16938134, 0.17377566],
#        [0.28153505, 0.22819808],
#        [0.15085958, 0.16509321],
#        [0.10867654, 0.1234898 ],
#        [0.12108528, 0.13468537],
#        [0.1412561 , 0.15430912],
#        [0.16385632, 0.17614026],
#        [0.77795222, 0.22765818],
#        [0.1461731 , 0.16180393],
#        [0.17727558, 0.18583134],
#        [0.18981116, 0.18533874],
#        [0.14116915, 0.15534908],
#        [0.13907021, 0.15243341],
#        [0.40227001, 0.20033586],
#        [0.13498187, 0.15359122],
#        [0.16330724, 0.18186206],
#        [0.13110761, 0.1477657 ],
#        [0.15405387, 0.16858861],
#        [0.16235792, 0.17260146],
#        [0.        , 0.17111298],
#        [0.16941239, 0.1827381 ],
#        [0.16452912, 0.17334357],
#        [0.19876321, 0.21502605],
#        [0.15471708, 0.17113742],
#        [0.46016062, 0.15171435],
#        [0.12395945, 0.14048555]])

# %%
losses
# Out:
# array([0.1139428 , 0.17718747, 0.24870613, 0.12336275, 0.17626499,
#        0.13367459, 0.13721265, 0.19369753, 0.13918507, 0.13703087,
#        0.1745156 , 0.131964  , 0.20718536, 0.16846132, 0.15027456,
#        0.14068186, 0.16787763, 0.16711777, 0.15336277, 0.17451796,
#        0.14474791, 0.18088932, 0.14507659, 0.13660532, 0.17380342,
#        0.22819817, 0.16502477, 0.12334128, 0.13467927, 0.15431537,
#        0.17613819, 0.22752887, 0.1617215 , 0.18560684, 0.185118  ,
#        0.15503603, 0.15212102, 0.19988652, 0.1529526 , 0.18187135,
#        0.14768696, 0.16856432, 0.17260593, 0.16650407, 0.18276863,
#        0.1733332 , 0.2148498 , 0.17114511, 0.14679466, 0.14033288],
#       dtype=float32)

# %%
ot.emd2()
# Out:
# TypeErrorTraceback (most recent call last)
# <ipython-input-38-f4e1f97ab823> in <module>()
# ----> 1 ot.emd2()
#
# TypeError: emd2() takes at least 3 arguments (0 given)

# %%
ae.sess.run(ae.loss,feed_dict={ae.x:feed_pc[:50], ae.beta:[0.]})
# Out:
# 0.18891285

# %%
import time
from latent_3d_points.external.structural_losses import tf_approxmatch


print "##### Approx EMD #####"
nclouds = 1
npoints = 500
ndim=2

points1 = reconstructions[:10]
points2 = feed_pc[:10]

ae.sess.run(ae.loss,feed_dict={ae.x:feed_pc[:50]})


start = time.time()

this = tf_approxmatch.approx_match(points1,points2)
init_op = tf.initialize_all_variables()


#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    transport = sess.run(this)
    #print transport

this_cost = tf_approxmatch.match_cost(points1,points2,transport)
init_op = tf.initialize_all_variables()

#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    cost = sess.run(this_cost)/1000*600
    print np.array(cost)
    
print "latent time: ", time.time()-start


print "\n \n \n ##### True EMD #####"
start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print truecost
print "pot time: ", time.time()-start

print "\n \n \n ##### Fractional difference #####"
print (np.array(cost) - np.array(truecost))/np.array(truecost)

# %%
import time
from latent_3d_points.external.structural_losses import tf_approxmatch


print "##### Approx EMD #####"
nclouds = 1
npoints = 1000
ndim=2

points1 = reconstructions[:10]
points2 = feed_pc[:10]

start = time.time()

this = tf_approxmatch.approx_match(points1,points2)
init_op = tf.initialize_all_variables()


#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    transport = sess.run(this)
    #print transport

this_cost = tf_approxmatch.match_cost(points1,points2,transport)
init_op = tf.initialize_all_variables()

#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    cost = sess.run(this_cost)/1000*600
    print np.array(cost)
    
print "latent time: ", time.time()-start


print "\n \n \n ##### True EMD #####"
start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print truecost
print "pot time: ", time.time()-start

print "\n \n \n ##### Fractional difference #####"
print (np.array(cost) - np.array(truecost))/np.array(truecost)
# Out:
# ##### Approx EMD #####
# [660.61383  114.32982  154.87538   94.38745  122.286865  97.17313
#   97.11448  140.62903  106.648735 476.88892 ]
# latent time:  7.5095140934
#
#
#
#  ##### True EMD #####
# [639.28419992 102.66531813 137.35644056  86.61553843 100.27905424
#   82.00906446  86.33042566 124.9253624   96.09012875 465.56864045]
# pot time:  1.84833312035
#
#
#
#  ##### Fractional difference #####
# [0.03336486 0.11361676 0.12754364 0.08972885 0.21946568 0.18490714
#  0.12491602 0.12570439 0.10988232 0.02431494]

# %%
from latent_3d_points.src.tf_sinkhorn import ground_distance_tf, sinkhorn_knopp_tf

with tf.Session() as sess:
    
    
    
    pointsa = tf.placeholder(tf.float32, shape=(10,1000,2))
    pointsb = tf.placeholder(tf.float32, shape=(10,1000,2))
    a = tf.placeholder(tf.float32, shape=(10,1000))
    b = tf.placeholder(tf.float32, shape=(10,1000))
    
    M = ground_distance_tf(pointsa, pointsb)
    reg = tf.constant(1.)
    plan = sinkhorn_knopp_tf(a, b, M, reg,verbose=True)
    
    cost = tf.trace(tf.matmul(M,plan,transpose_a=True))
    
    sess.run(tf.global_variables_initializer())
    sess.run(tf.local_variables_initializer())
    feed_dict={pointsa:points2,pointsb:points1,a:np.ones((10,1000)),b:np.ones((10,1000))}
    myM = sess.run(M,feed_dict=feed_dict)
    myplan = sess.run(plan,feed_dict=feed_dict)
    #print the random values that we sample
    mycost = sess.run(cost,feed_dict={pointsa:points2,pointsb:points1,a:np.ones((10,1000)),b:np.ones((10,1000))})/1000*600/2
# Out:
# Reached machine precision

# %%
ot.sinkhorn2(np.ones(1000),np.ones(1000),np.array(M[0]),0.01,numItermax=10000, stopThr=0.0001)*600/1000
# Out:
# AxisErrorTraceback (most recent call last)
# <ipython-input-93-8cd61fda94da> in <module>()
# ----> 1 ot.sinkhorn2(np.ones(1000),np.ones(1000),np.array(M[0]),0.01,method='sinkhorn_epsilon_scaling',numItermax=10000, stopThr=0.0001)*600/1000
#
# /home/jcollins/.local/lib/python2.7/site-packages/ot/bregman.pyc in sinkhorn2(a, b, M, reg, method, numItermax, stopThr, verbose, log, **kwargs)
#     240         b = b.reshape((-1, 1))
#     241
# --> 242     return sink()
#     243
#     244
#
# /home/jcollins/.local/lib/python2.7/site-packages/ot/bregman.pyc in sink()
#     229             return sinkhorn_epsilon_scaling(
#     230                 a, b, M, reg, numItermax=numItermax,
# --> 231                 stopThr=stopThr, verbose=verbose, log=log, **kwargs)
#     232     else:
#     233         print('Warning : unknown method using classic Sinkhorn Knopp')
#
# /home/jcollins/.local/lib/python2.7/site-packages/ot/bregman.pyc in sinkhorn_epsilon_scaling(a, b, M, reg, numItermax, epsilon0, numInnerItermax, tau, stopThr, warmstart, verbose, print_period, log, **kwargs)
#     928             transp = G
#     929             err = np.linalg.norm(
# --> 930                 (np.sum(transp, axis=0) - b))**2 + np.linalg.norm((np.sum(transp, axis=1) - a))**2
#     931             if log:
#     932                 log['err'].append(err)
#
# /home/jcollins/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims, initial)
#    2074
#    2075     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# -> 2076                           initial=initial)
#    2077
#    2078
#
# /home/jcollins/.local/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      84                 return reduction(axis=axis, out=out, **passkwargs)
#      85
# ---> 86     return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#      87
#      88
#
# AxisError: axis 1 is out of bounds for array of dimension 1

# %%
np.array(M).shape
# Out:
# (10, 1000, 1000)

# %%
M
# Out:
# [array([[0.14016591, 0.14016591, 0.14016591, ..., 0.3061201 , 0.3061201 ,
#          0.3061201 ],
#         [0.19696716, 0.19696716, 0.19696716, ..., 0.23191432, 0.23191432,
#          0.23191432],
#         [0.23747141, 0.23747141, 0.23747141, ..., 0.18094758, 0.18094758,
#          0.18094758],
#         ...,
#         [0.18468178, 0.18468178, 0.18468178, ..., 0.3465367 , 0.3465367 ,
#          0.3465367 ],
#         [0.04669104, 0.04669104, 0.04669104, ..., 0.42932345, 0.42932345,
#          0.42932345],
#         [0.27204126, 0.27204126, 0.27204126, ..., 0.65489906, 0.65489906,
#          0.65489906]]),
#  array([[0.2573473 , 0.2573473 , 0.2573473 , ..., 0.71835432, 0.71835432,
#          0.71835432],
#         [0.43993314, 0.43993314, 0.43993314, ..., 0.8938068 , 0.8938068 ,
#          0.8938068 ],
#         [0.44093411, 0.44093411, 0.44093411, ..., 0.7850754 , 0.7850754 ,
#          0.7850754 ],
#         ...,
#         [0.15107639, 0.15107639, 0.15107639, ..., 0.4841306 , 0.4841306 ,
#          0.4841306 ],
#         [0.33514347, 0.33514347, 0.33514347, ..., 0.67394   , 0.67394   ,
#          0.67394   ],
#         [0.17276243, 0.17276243, 0.17276243, ..., 0.50172595, 0.50172595,
#          0.50172595]]),
#  array([[0.53684007, 0.53684007, 0.53684007, ..., 0.81956641, 0.81956641,
#          0.81956641],
#         [0.55706175, 0.55706175, 0.55706175, ..., 0.82551916, 0.82551916,
#          0.82551916],
#         [0.41961664, 0.41961664, 0.41961664, ..., 0.65174663, 0.65174663,
#          0.65174663],
#         ...,
#         [0.22648371, 0.22648371, 0.22648371, ..., 0.48997389, 0.48997389,
#          0.48997389],
#         [0.33943376, 0.33943376, 0.33943376, ..., 0.6209822 , 0.6209822 ,
#          0.6209822 ],
#         [0.4251724 , 0.4251724 , 0.4251724 , ..., 0.70272478, 0.70272478,
#          0.70272478]]),
#  array([[0.09317094, 0.09317094, 0.09317094, ..., 0.52306305, 0.60517093,
#          0.60517093],
#         [0.15240089, 0.15240089, 0.15240089, ..., 0.45227069, 0.67584641,
#          0.67584641],
#         [0.24016019, 0.24016019, 0.24016019, ..., 0.42313702, 0.78157974,
#          0.78157974],
#         ...,
#         [0.1531052 , 0.1531052 , 0.1531052 , ..., 0.57364285, 0.64860356,
#          0.64860356],
#         [0.3937224 , 0.3937224 , 0.3937224 , ..., 0.44487907, 0.913074  ,
#          0.913074  ],
#         [0.35811608, 0.35811608, 0.35811608, ..., 0.38399738, 0.89459212,
#          0.89459212]]),
#  array([[0.10299509, 0.10299509, 0.10299509, ..., 0.38284612, 0.38284612,
#          0.91905199],
#         [0.05849429, 0.05849429, 0.05849429, ..., 0.48268371, 0.48268371,
#          0.80774541],
#         [0.20971346, 0.20971346, 0.20971346, ..., 0.24359825, 0.24359825,
#          0.95743749],
#         ...,
#         [0.2711849 , 0.2711849 , 0.2711849 , ..., 0.25883967, 0.25883967,
#          0.75848271],
#         [0.1993574 , 0.1993574 , 0.1993574 , ..., 0.22944384, 0.22944384,
#          0.85818355],
#         [0.04888816, 0.04888816, 0.04888816, ..., 0.38670969, 0.38670969,
#          0.85860447]]),
#  array([[0.26447727, 0.26447727, 0.26447727, ..., 0.67387497, 0.67387497,
#          0.67387497],
#         [0.28668471, 0.28668471, 0.28668471, ..., 0.53511571, 0.53511571,
#          0.53511571],
#         [0.25425343, 0.25425343, 0.25425343, ..., 0.3364769 , 0.3364769 ,
#          0.3364769 ],
#         ...,
#         [0.13045936, 0.13045936, 0.13045936, ..., 0.39191949, 0.39191949,
#          0.39191949],
#         [0.02631823, 0.02631823, 0.02631823, ..., 0.42354794, 0.42354794,
#          0.42354794],
#         [0.1033832 , 0.1033832 , 0.1033832 , ..., 0.52484027, 0.52484027,
#          0.52484027]]),
#  array([[0.14545571, 0.14545571, 0.14545571, ..., 0.71465408, 0.77448469,
#          0.77448469],
#         [0.23058661, 0.23058661, 0.23058661, ..., 0.8059814 , 0.7727106 ,
#          0.7727106 ],
#         [0.12308598, 0.12308598, 0.12308598, ..., 0.78413123, 0.69685719,
#          0.69685719],
#         ...,
#         [0.16090155, 0.16090155, 0.16090155, ..., 0.8154822 , 0.69458103,
#          0.69458103],
#         [0.28770947, 0.28770947, 0.28770947, ..., 0.76819602, 0.85905133,
#          0.85905133],
#         [0.32629096, 0.32629096, 0.32629096, ..., 0.72153009, 0.92528457,
#          0.92528457]]),
#  array([[0.22431838, 0.22431838, 0.22431838, ..., 0.68633489, 0.68633489,
#          0.68633489],
#         [0.61594002, 0.61594002, 0.61594002, ..., 0.94695281, 0.94695281,
#          0.94695281],
#         [0.49436231, 0.49436231, 0.49436231, ..., 0.95299289, 0.95299289,
#          0.95299289],
#         ...,
#         [0.27161453, 0.27161453, 0.27161453, ..., 0.76136582, 0.76136582,
#          0.76136582],
#         [0.55956578, 0.55956578, 0.55956578, ..., 1.02861437, 1.02861437,
#          1.02861437],
#         [0.39399891, 0.39399891, 0.39399891, ..., 0.88369021, 0.88369021,
#          0.88369021]]),
#  array([[0.21044668, 0.21044668, 0.21044668, ..., 0.51153777, 0.51153777,
#          0.31537188],
#         [0.05938936, 0.05938936, 0.05938936, ..., 0.69381408, 0.69381408,
#          0.35483921],
#         [0.14728528, 0.14728528, 0.14728528, ..., 0.72246626, 0.72246626,
#          0.27865539],
#         ...,
#         [0.1741878 , 0.1741878 , 0.1741878 , ..., 0.62620086, 0.62620086,
#          0.24652383],
#         [0.24070938, 0.24070938, 0.24070938, ..., 0.84586793, 0.84586793,
#          0.30343886],
#         [0.23077719, 0.23077719, 0.23077719, ..., 0.86388609, 0.86388609,
#          0.34524219]]),
#  array([[0.33429117, 0.33429117, 0.33429117, ..., 0.23437327, 0.23437327,
#          0.23437327],
#         [0.45139606, 0.45139606, 0.45139606, ..., 0.29806615, 0.29806615,
#          0.29806615],
#         [0.60565924, 0.60565924, 0.60565924, ..., 0.19910401, 0.19910401,
#          0.19910401],
#         ...,
#         [0.57045827, 0.57045827, 0.57045827, ..., 0.14866001, 0.14866001,
#          0.14866001],
#         [0.54075676, 0.54075676, 0.54075676, ..., 0.22291546, 0.22291546,
#          0.22291546],
#         [0.31105183, 0.31105183, 0.31105183, ..., 0.15684873, 0.15684873,
#          0.15684873]])]

# %%
myM
# Out:
# array([[[0.14016576, 0.1969676 , 0.2374714 , ..., 0.18468173,
#          0.04669087, 0.27204064],
#         [0.14016576, 0.1969676 , 0.2374714 , ..., 0.18468173,
#          0.04669087, 0.27204064],
#         [0.14016576, 0.1969676 , 0.2374714 , ..., 0.18468173,
#          0.04669087, 0.27204064],
#         ...,
#         [0.30612004, 0.2319147 , 0.18094759, ..., 0.34653667,
#          0.42932343, 0.6548988 ],
#         [0.30612004, 0.2319147 , 0.18094759, ..., 0.34653667,
#          0.42932343, 0.6548988 ],
#         [0.30612004, 0.2319147 , 0.18094759, ..., 0.34653667,
#          0.42932343, 0.6548988 ]],
#
#        [[0.2573469 , 0.4399331 , 0.440934  , ..., 0.15107547,
#          0.33514354, 0.17276211],
#         [0.2573469 , 0.4399331 , 0.440934  , ..., 0.15107547,
#          0.33514354, 0.17276211],
#         [0.2573469 , 0.4399331 , 0.440934  , ..., 0.15107547,
#          0.33514354, 0.17276211],
#         ...,
#         [0.71835417, 0.89380676, 0.7850753 , ..., 0.4841303 ,
#          0.67394006, 0.50172585],
#         [0.71835417, 0.89380676, 0.7850753 , ..., 0.4841303 ,
#          0.67394006, 0.50172585],
#         [0.71835417, 0.89380676, 0.7850753 , ..., 0.4841303 ,
#          0.67394006, 0.50172585]],
#
#        [[0.5368399 , 0.55706173, 0.4196169 , ..., 0.22648388,
#          0.3394339 , 0.42517233],
#         [0.5368399 , 0.55706173, 0.4196169 , ..., 0.22648388,
#          0.3394339 , 0.42517233],
#         [0.5368399 , 0.55706173, 0.4196169 , ..., 0.22648388,
#          0.3394339 , 0.42517233],
#         ...,
#         [0.81956625, 0.8255191 , 0.65174675, ..., 0.48997393,
#          0.6209822 , 0.7027247 ],
#         [0.81956625, 0.8255191 , 0.65174675, ..., 0.48997393,
#          0.6209822 , 0.7027247 ],
#         [0.81956625, 0.8255191 , 0.65174675, ..., 0.48997393,
#          0.6209822 , 0.7027247 ]],
#
#        ...,
#
#        [[0.22431803, 0.61593974, 0.49436268, ..., 0.2716145 ,
#          0.5595659 , 0.39399904],
#         [0.22431803, 0.61593974, 0.49436268, ..., 0.2716145 ,
#          0.5595659 , 0.39399904],
#         [0.22431803, 0.61593974, 0.49436268, ..., 0.2716145 ,
#          0.5595659 , 0.39399904],
#         ...,
#         [0.6863347 , 0.9469526 , 0.95299304, ..., 0.7613658 ,
#          1.0286144 , 0.88369024],
#         [0.6863347 , 0.9469526 , 0.95299304, ..., 0.7613658 ,
#          1.0286144 , 0.88369024],
#         [0.6863347 , 0.9469526 , 0.95299304, ..., 0.7613658 ,
#          1.0286144 , 0.88369024]],
#
#        [[0.21044658, 0.05938902, 0.14728531, ..., 0.17418787,
#          0.24070938, 0.23077726],
#         [0.21044658, 0.05938902, 0.14728531, ..., 0.17418787,
#          0.24070938, 0.23077726],
#         [0.21044658, 0.05938902, 0.14728531, ..., 0.17418787,
#          0.24070938, 0.23077726],
#         ...,
#         [0.51153773, 0.69381404, 0.7224663 , ..., 0.62620085,
#          0.8458679 , 0.8638861 ],
#         [0.51153773, 0.69381404, 0.7224663 , ..., 0.62620085,
#          0.8458679 , 0.8638861 ],
#         [0.31537184, 0.35483915, 0.27865538, ..., 0.24652389,
#          0.3034388 , 0.3452422 ]],
#
#        [[0.334291  , 0.45139703, 0.60565925, ..., 0.5704589 ,
#          0.54075724, 0.3110508 ],
#         [0.334291  , 0.45139703, 0.60565925, ..., 0.5704589 ,
#          0.54075724, 0.3110508 ],
#         [0.334291  , 0.45139703, 0.60565925, ..., 0.5704589 ,
#          0.54075724, 0.3110508 ],
#         ...,
#         [0.23437303, 0.2980676 , 0.19910401, ..., 0.14866239,
#          0.22291653, 0.15684667],
#         [0.23437303, 0.2980676 , 0.19910401, ..., 0.14866239,
#          0.22291653, 0.15684667],
#         [0.23437303, 0.2980676 , 0.19910401, ..., 0.14866239,
#          0.22291653, 0.15684667]]], dtype=float32)

# %%
mycost
# Out:
# array([ 95.54354 ,  97.262856, 110.53098 ,  77.75858 ,  94.080505,
#         83.99257 ,  71.85829 , 103.707596,  77.571365, 122.55483 ],
#       dtype=float32)

# %%
print np.sum(myplan,-1)
print np.sum(myplan,-2)
# Out:
# [[0.99999976 0.99999976 0.99999976 ... 0.9999999  0.9999999  0.9999999 ]
#  [0.9999995  0.9999995  0.9999995  ... 0.999999   0.999999   0.999999  ]
#  [1.0000012  1.0000012  1.0000012  ... 1.0000008  1.0000008  1.0000008 ]
#  ...
#  [0.9999999  0.9999999  0.9999999  ... 0.99999976 0.99999976 0.99999976]
#  [1.0000001  1.0000001  1.0000001  ... 0.9999994  0.9999994  1.0000002 ]
#  [0.9999991  0.9999991  0.9999991  ... 1.0000007  1.0000007  1.0000007 ]]
# [[1.268126   1.2690521  1.2694818  ... 1.2750163  1.272617   1.291868  ]
#  [0.99700576 0.99761784 1.0031059  ... 1.0001698  1.0022901  1.0004857 ]
#  [1.012918   1.001225   0.9926707  ... 1.0054557  1.0048922  1.0110971 ]
#  ...
#  [0.9935377  1.0161972  1.0045401  ... 0.9972348  1.0073376  0.9995738 ]
#  [1.012133   0.9958998  1.000396   ... 1.0063388  1.0005451  0.9991126 ]
#  [0.9093828  0.89790916 0.9025712  ... 0.90321153 0.90020317 0.90244937]]

# %%
from latent_3d_points.external.structural_losses import tf_approxmatch

# %%
xyz1 = tf.placeholder(tf.float32,shape=[None,2,2])
xyz2 = tf.placeholder(tf.float32,shape=[None,2,2])
match = tf_approxmatch.approx_match(xyz1,xyz2)
matchcost = tf_approxmatch.match_cost(xyz1,xyz2,match)
matchcostgrad = tf_approxmatch.approxmatch_module.match_cost_grad(xyz1,xyz2,match)
xyz1repl = np.array([[[0,0.],[0,0.]]])
xyz2repl = np.array([[[5*np.pi+0.1,0],[0.1,0.1]]])
tf.Session().run([matchcost,matchcostgrad,tf.gradients(matchcost,xyz2)],
         feed_dict={xyz1:xyz1repl,
                    xyz2:xyz2repl})
# Out:
# [array([3.1830142], dtype=float32),
#  MatchCostGrad(grad1=array([[[-0.14644678, -0.35355356],
#         [-0.14644678, -0.35355356]]], dtype=float32), grad2=array([[[-1.       ,  0.       ],
#         [ 0.7071064,  0.7071071]]], dtype=float32)),
#  [array([[[-1.       ,  0.       ],
#           [ 0.7071064,  0.7071071]]], dtype=float32)]]

# %%
xyz1 = tf.placeholder(tf.float32,shape=[None,2,2])
xyz2 = tf.placeholder(tf.float32,shape=[None,2,2])
match = tf_approxmatch.approx_match(xyz1,xyz2)
matchcost = tf_approxmatch.match_cost(xyz1,xyz2,match)
matchcostgrad = tf_approxmatch.approxmatch_module.match_cost_grad(xyz1,xyz2,match)
xyz1repl = np.array([[[0,0.],[0.0,0.0]]])
xyz2repl = np.array([[[-0.1,0],[0.1,0.1]]])
tf.Session().run([match,matchcost,matchcostgrad,tf.gradients(matchcost,xyz2)],
         feed_dict={xyz1:xyz1repl,
                    xyz2:xyz2repl})
# Out:
# [array([[[0.5, 0.5],
#          [0.5, 0.5]]], dtype=float32),
#  array([0.2414212], dtype=float32),
#  MatchCostGrad(grad1=array([[[-0.14644678, -0.35355356],
#         [-0.14644678, -0.35355356]]], dtype=float32), grad2=array([[[-1.       ,  0.       ],
#         [ 0.7071064,  0.7071071]]], dtype=float32)),
#  [array([[[-1.       ,  0.       ],
#           [ 0.7071064,  0.7071071]]], dtype=float32)]]

# %%
tf.gradients(matchcost,xyz2)
# Out:
# [<tf.Tensor 'gradients/MatchCost_3_grad/mul_1:0' shape=(?, 1, 2) dtype=float32>]

# %%
sess.run(tf_approxmatch.approx_match(xyz1,xyz2))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-85-405683bc6570> in <module>()
# ----> 1 sess.run(tf_approxmatch.approx_match(xyz1,xyz2))
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1120     # Create a fetch handler to take care of the structure of fetches.
#    1121     fetch_handler = _FetchHandler(
# -> 1122         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1123
#    1124     # Run request and get response.
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, graph, fetches, feeds, feed_handles)
#     425     """
#     426     with graph.as_default():
# --> 427       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     428     self._fetches = []
#     429     self._targets = []
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     251         if isinstance(fetch, tensor_type):
#     252           fetches, contraction_fn = fetch_fn(fetch)
# --> 253           return _ElementFetchMapper(fetches, contraction_fn)
#     254     # Did not find anything.
#     255     raise TypeError('Fetch argument %r has invalid type %r' % (fetch,
#
# /usr/local/lib/python2.7/dist-packages/tensorflow/python/client/session.pyc in __init__(self, fetches, contraction_fn)
#     287       except ValueError as e:
#     288         raise ValueError('Fetch argument %r cannot be interpreted as a '
# --> 289                          'Tensor. (%s)' % (fetch, str(e)))
#     290       except KeyError as e:
#     291         raise ValueError('Fetch argument %r cannot be interpreted as a '
#
# ValueError: Fetch argument <tf.Tensor 'ApproxMatch_11:0' shape=(1, 1, 1) dtype=float32> cannot be interpreted as a Tensor. (Tensor Tensor("ApproxMatch_11:0", shape=(1, 1, 1), dtype=float32) is not an element of this graph.)

# %%
np.linspace(-lim, lim, 100)
# Out:
# array([-5.        , -4.8989899 , -4.7979798 , -4.6969697 , -4.5959596 ,
#        -4.49494949, -4.39393939, -4.29292929, -4.19191919, -4.09090909,
#        -3.98989899, -3.88888889, -3.78787879, -3.68686869, -3.58585859,
#        -3.48484848, -3.38383838, -3.28282828, -3.18181818, -3.08080808,
#        -2.97979798, -2.87878788, -2.77777778, -2.67676768, -2.57575758,
#        -2.47474747, -2.37373737, -2.27272727, -2.17171717, -2.07070707,
#        -1.96969697, -1.86868687, -1.76767677, -1.66666667, -1.56565657,
#        -1.46464646, -1.36363636, -1.26262626, -1.16161616, -1.06060606,
#        -0.95959596, -0.85858586, -0.75757576, -0.65656566, -0.55555556,
#        -0.45454545, -0.35353535, -0.25252525, -0.15151515, -0.05050505,
#         0.05050505,  0.15151515,  0.25252525,  0.35353535,  0.45454545,
#         0.55555556,  0.65656566,  0.75757576,  0.85858586,  0.95959596,
#         1.06060606,  1.16161616,  1.26262626,  1.36363636,  1.46464646,
#         1.56565657,  1.66666667,  1.76767677,  1.86868687,  1.96969697,
#         2.07070707,  2.17171717,  2.27272727,  2.37373737,  2.47474747,
#         2.57575758,  2.67676768,  2.77777778,  2.87878788,  2.97979798,
#         3.08080808,  3.18181818,  3.28282828,  3.38383838,  3.48484848,
#         3.58585859,  3.68686869,  3.78787879,  3.88888889,  3.98989899,
#         4.09090909,  4.19191919,  4.29292929,  4.39393939,  4.49494949,
#         4.5959596 ,  4.6969697 ,  4.7979798 ,  4.8989899 ,  5.        ])

# %%
reconstructions[:,:,0] = np.mod(reconstructions[:,:,0]+np.pi,2*np.pi)-np.pi

# %%
reconstructions[12]
# Out:
# array([[41.793518  ,  0.5640073 ],
#        [42.51293   ,  0.47025776],
#        [42.365234  ,  1.086246  ],
#        ...,
#        [42.430733  ,  0.81698775],
#        [42.42978   ,  0.79243857],
#        [42.185936  ,  0.83409566]], dtype=float32)

# %%
feed_pc[0]
# Out:
# array([[-1.77030349,  0.4676643 ],
#        [-1.77030349,  0.4676643 ],
#        [-1.77030349,  0.4676643 ],
#        ...,
#        [-1.16792515,  0.67233879],
#        [-1.16792515,  0.67233879],
#        [-1.16792515,  0.67233879]])

# %%
reconstructions[0]
# Out:
# array([[ 0.79865503, -0.22795632],
#        [ 1.0072377 , -0.14852503],
#        [ 0.64558613, -0.54770565],
#        ...,
#        [ 0.8766489 , -0.27920833],
#        [ 1.0309498 ,  0.04436365],
#        [ 1.000967  , -0.10502619]], dtype=float32)

# %%
countcut=0.9
lim=np.pi
bins=np.linspace(-lim, lim, 100)

#for i in range(len(feed_pc)):
for i in range(0,20):   

    M = np.sqrt(ot.dist(feed_pc[i],reconstructions[i]))
    truecost = ot.emd2(np.ones(1000),np.ones(1000),M)/1000*500

    print truecost
    
    fig, ax = plt.subplots(1, 2,figsize=[12,6])
    counts, bx, by = np.histogram2d(feed_pc[i][:,0],feed_pc[i][:,1],bins=bins)
    ax[0].imshow(counts.T , norm=LogNorm(countcut, 1000), origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    ax[0].axvline(3.14,linewidth=0.5, color='black')
    #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
    counts, bx, by = np.histogram2d(np.mod(np.pi+reconstructions[i,:,0],2*np.pi)-np.pi,reconstructions[i][:,1],bins=bins)
    ax[1].imshow(counts.T, norm=LogNorm(countcut, 1000), origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    plt.show()
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-2-ea44ce181f34> in <module>()
#       1 countcut=0.9
# ----> 2 lim=np.pi
#       3 bins=np.linspace(-lim, lim, 100)
#       4
#       5 #for i in range(len(feed_pc)):
#
# NameError: name 'np' is not defined

# %%
countcut=0.9
lim=np.pi
bins=np.linspace(-lim, lim, 100)

#for i in range(len(feed_pc)):
for i in range(0,20):   

#     M = np.sqrt(ot.dist(feed_pc[i],reconstructions[i]))
#     truecost = ot.emd2(np.ones(1000),np.ones(1000),M)/1000*500

#     print truecost
    
    fig, ax = plt.subplots(1, 2,figsize=[12,6])
    counts, bx, by = np.histogram2d(feed_pc[i][:,1],feed_pc[i][:,2],bins=bins,weights=feed_pc[i][:,0]*500)
    ax[0].imshow(counts.T , origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    ax[0].axvline(3.14,linewidth=0.5, color='black')
    #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
    counts, bx, by = np.histogram2d(np.mod(np.pi+reconstructions[i,:,0],2*np.pi)-np.pi,reconstructions[i][:,1],bins=bins)
    ax[1].imshow(counts.T, origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    plt.show()

# %%
all_pc_data._index_in_epoch = 0
numload = 50
feed_pc, feed_model_names, _ = all_pc_data.next_batch(numload )
reconstructions = [ae.reconstruct(feed_pc)[0] for i in range(10)]

in_points=tf.placeholder(tf.float32,shape=[50,100,3])
out_points=tf.placeholder(tf.float32,shape=[50,500,2])
init_op = tf.global_variables_initializer()

in_weights, _, _ = tf.unstack(in_points,axis=-1)
ground_distance, ground_dist_gradient = ground_distance_tf(in_points[:,:,1:],out_points,mod2pi=True)

# conf.numItermax = 5
# conf.stopThr = 1e-2
conf.sinkhorn_reg = 0.01
loss = sinkhorn_loss_tf(in_points[:,:,1:],out_points,conf, in_weights=in_weights)
with tf.Session() as sess:
    sess.run(tf.initialize_all_variables()) #execute init_op
    losses = [sess.run(loss, feed_dict={in_points:feed_pc, out_points:reconstructions[i]}) for i in range(len(reconstructions))]
# Out:
# WARNING:tensorflow:From /home/jcollins/.local/lib/python2.7/site-packages/tensorflow/python/util/tf_should_use.py:118: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.

# %%
countcut=0.9
lim=np.pi
bins=np.linspace(-lim, lim, 63)

#for i in range(len(feed_pc)):
for i in range(0,20):   

#     M = np.sqrt(ot.dist(feed_pc[i],reconstructions[i]))
#     truecost = ot.emd2(np.ones(1000),np.ones(1000),M)/1000*500

#     print truecost
    print i, losses[0][i]
    fig, ax = plt.subplots(1, 3,figsize=[15,5])
    counts, bx, by = np.histogram2d(feed_pc[i][:,1],feed_pc[i][:,2],bins=bins,weights=feed_pc[i][:,0]*500)
    ax[0].imshow(counts.T , norm=LogNorm(countcut, 500), origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    ax[0].axvline(3.14,linewidth=0.5, color='black')
    #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
    for j in range(2):
        counts, bx, by = np.histogram2d(np.mod(np.pi+reconstructions[j][i,:,0],2*np.pi)-np.pi,reconstructions[j][i][:,1],bins=bins)
        ax[j+1].imshow(counts.T, norm=LogNorm(countcut, 500), origin='lower',cmap='Oranges',extent=[-lim, lim, -lim, lim])
    plt.show()
# Out:
# 0 0.11107145
# 1 0.10404909
# 2 0.10046664
# 3 0.08730476
# 4 0.07892183
# 5 0.07814277
# 6 0.10259735
# 7 0.12894444
# 8 0.14432484
# 9 0.11796435
# 10 0.08442816
# 11 0.0996672
# 12 0.073641375
# 13 0.15328594
# 14 0.109183446
# 15 0.086716436
# 16 0.0817312
# 17 0.106091805
# 18 0.1844707
# 19 0.07078211

# %%
import time
points1 = reconstructions[:100]
points2 = feed_pc[:100]

start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

qcd_truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print qcd_truecost
print time.time()-start

print np.average(qcd_truecost)
print np.std(qcd_truecost)
# Out:
# [75.07462589 56.59483998 42.21813977 29.98111    17.60743652 29.26905909
#  44.23036638 53.78889053 22.61921665 38.94040913 11.0146198  58.48786779
#  35.10435213 44.75039082 17.64397472 41.23235729 12.16824136  7.42036687
#  30.34516555 39.58170748 40.88762488 20.45590575 16.7558164  17.43403559
#  19.83347945 23.14521052 39.10715683 51.91705182 43.43254131 37.39027438
#  17.95735649 92.67533288 15.50884697 24.08738266 42.56493747 80.18168389
#  34.37575292 67.37336177 67.9504303  60.89538383 55.73237276 86.31614223
#  31.48024747 83.45726199 66.72014241 16.2673117   9.21094226 19.93969679
#  36.58169053 26.42489868 24.59880662 48.06636576 50.30116624 28.14479361
#  69.66059955 18.40395326 28.08811332 28.32299312 11.0570396  64.34625717
#  22.95063903 18.55958876 22.99913801 29.17480983 37.2018918  16.75521239
#  51.61739273 42.60858388 60.27166046 25.36606832 55.87213338 60.04971272
#  14.98368623 17.67129109 17.08163441 26.67722976 36.18497717 37.07946846
#  43.08057645 36.57171829 49.53001533 13.66398629 27.97462342 59.46705654
#  47.6702977  63.26296251 49.27080523 44.23530523 22.28304867 44.84163437
#  61.3513845  22.03408509 55.61353401 44.14098217 10.95055356 22.98068739
#  42.54581478 43.63572026 40.69493707 79.63915112]
# 16.0734450817
# 38.43667497332868
# 19.509840253436874

# %%
import pandas as pd
numjets = 0
numvalid = 10000
outstore = pd.HDFStore("/data1/users/jcollins/Heidelberg_sample/train_points_top.h5")
topdata = outstore.select("points",start=numjets,stop=numjets+numvalid).values
topdata = topdata.reshape(numvalid,1000,2)
top_pc_data = PointCloudDataSet(topdata,copy=False)
gc.collect()


numload = 1000
top_feed_pc, feed_model_names, _ = top_pc_data.next_batch(numload )
top_reconstructions = ae.reconstruct(top_feed_pc)[0]
top_latent_codes = ae.transform(top_feed_pc)

# %%
countcut=0.9
lim=1.5
bins=np.linspace(-lim, lim, 30)

#for i in range(len(feed_pc)):
for i in range(10):   

    M = np.sqrt(ot.dist(top_feed_pc[i],top_reconstructions[i]))
    truecost = ot.emd2(np.ones(1000),np.ones(1000),M)/1000*500

    print truecost
    
    fig, ax = plt.subplots(1, 2,figsize=[6,3])
    counts, bx, by = np.histogram2d(top_feed_pc[i][:,0],top_feed_pc[i][:,1],bins=bins)
    ax[0].imshow(counts.T , norm=LogNorm(countcut, 1000), origin='lower',cmap='Oranges')
    #ax[0].hist2d(feed_pc[i][:,0],feed_pc[i][:,1],range=[[-lim,lim],[-lim,lim]],bins=bins, norm=LogNorm(0.5, 1000))
    counts, bx, by = np.histogram2d(top_reconstructions[i][:,0],top_reconstructions[i][:,1],bins=bins)
    ax[1].imshow(counts.T, norm=LogNorm(countcut, 1000), origin='lower',cmap='Oranges')
    plt.show()
# Out:
# 67.1590192909
# 32.9848128951
# 43.5306045562
# 96.9595536488
# 56.5107807271
# 31.1558567445
# 28.482677467
# 50.0595193685
# 111.557907183
# 86.6148343221

# %%
import time
from latent_3d_points.external.structural_losses import tf_approxmatch


print "##### Approx EMD #####"
nclouds = 1
npoints = 1000
ndim=2

points1 = top_reconstructions[:10]
points2 = top_feed_pc[:10]

start = time.time()

this = tf_approxmatch.approx_match(points1,points2)
init_op = tf.initialize_all_variables()


#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    transport = sess.run(this)
    #print transport

this_cost = tf_approxmatch.match_cost(points1,points2,transport)
init_op = tf.initialize_all_variables()

#run the graph
with tf.Session() as sess:
    sess.run(init_op) #execute init_op
    #print the random values that we sample
    cost = sess.run(this_cost)/1000*600
    print np.array(cost)
    
print time.time()-start


print "\n \n \n ##### True EMD #####"
start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print time.time()-start
print truecost

print "\n \n \n ##### Fractional difference #####"
print (np.array(cost) - np.array(truecost))/np.array(truecost)
# Out:
# ##### Approx EMD #####
# [ 85.88746   45.76537   57.824436 127.84058   77.66613   44.46702
#   37.862076  70.76115  139.55957  116.11902 ]
# 3.83007621765
#
#
#
#  ##### True EMD #####
# 1.67375588417
# [ 80.59082315  39.58177547  52.23672547 116.35146438  67.81293687
#   37.38702809  34.17921296  60.07142324 133.86948862 103.93780119]
#
#
#
#  ##### Fractional difference #####
# [0.06572257 0.15622326 0.10696901 0.09874495 0.14529961 0.18937023
#  0.10775154 0.17795023 0.04250469 0.11719718]

# %%
import time
points1 = reconstructions[:1000]
points2 = feed_pc[:1000]

start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

qcd_truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print qcd_truecost
print time.time()-start

print np.average(qcd_truecost)
print np.std(qcd_truecost)

import time
points1 = top_reconstructions[:1000]
points2 = top_feed_pc[:1000]

start = time.time()
M = [np.sqrt(ot.dist(points1[i],points2[i])) for i in range(len(points1))]

top_truecost = np.array([ot.emd2(np.ones(1000),np.ones(1000),Mat) for Mat in M])/1000*600
print top_truecost
print time.time()-start

print np.average(top_truecost)
print np.std(top_truecost)
# Out:
# [ 75.07462589  56.59483998  42.21813977  29.98111     17.60743652
#   29.26905909  44.23036638  53.78889053  22.61921665  38.94040913
#   11.0146198   58.48786779  35.10435213  44.75039082  17.64397472
#   41.23235729  12.16824136   7.42036687  30.34516555  39.58170748
#   40.88762488  20.45590575  16.7558164   17.43403559  19.83347945
#   23.14521052  39.10715683  51.91705182  43.43254131  37.39027438
#   17.95735649  92.67533288  15.50884697  24.08738266  42.56493747
#   80.18168389  34.37575292  67.37336177  67.9504303   60.89538383
#   55.73237276  86.31614223  31.48024747  83.45726199  66.72014241
#   16.2673117    9.21094226  19.93969679  36.58169053  26.42489868
#   24.59880662  48.06636576  50.30116624  28.14479361  69.66059955
#   18.40395326  28.08811332  28.32299312  11.0570396   64.34625717
#   22.95063903  18.55958876  22.99913801  29.17480983  37.2018918
#   16.75521239  51.61739273  42.60858388  60.27166046  25.36606832
#   55.87213338  60.04971272  14.98368623  17.67129109  17.08163441
#   26.67722976  36.18497717  37.07946846  43.08057645  36.57171829
#   49.53001533  13.66398629  27.97462342  59.46705654  47.6702977
#   63.26296251  49.27080523  44.23530523  22.28304867  44.84163437
#   61.3513845   22.03408509  55.61353401  44.14098217  10.95055356
#   22.98068739  42.54581478  43.63572026  40.69493707  79.63915112
#   41.72781545  18.56916522  30.8958045   39.02115967  47.21097319
#   40.32864972  23.35090109  24.05117354  22.46620121  48.62582777
#   33.16558616  13.91447202  24.4855528   24.28479643  48.65224843
#   24.43238413   8.0282178   19.52371471  24.61709884  24.55601344
#   28.57794529  11.06515321  20.82372459  54.77990029  50.26898883
#   39.6309856   55.19786569  41.41886274  27.61426786  22.22010099
#   56.20686728  50.42855697  35.69930006  21.74825774  32.15308938
#   22.93792009  18.63486237  33.9324495    5.73107905  26.56896992
#   62.05631615  26.62035545  14.55803147  31.04111755  32.63616093
#   56.41945089  26.63656533  53.41208245  65.09584201  23.8416233
#   19.20102434  27.36410954  42.33787939  52.25135065  15.86819809
#   27.66301933  23.54974856  56.25412967  54.60996546  18.04446681
#   58.4434769   18.48750859  10.50410959  23.72552217  64.6687342
#   22.59096535  31.98244427  41.12208632  48.43455237  44.84030522
#    8.0581351   58.65008905  61.30744728 102.40266683  44.82518032
#   40.90178253  85.80754184  63.80510807  39.76969754  48.15790679
#   10.00028833  38.09306264  36.87164995  35.83771372  21.06873725
#   17.60205328  21.24652819  26.51815616  41.92841002  86.39491257
#   41.19325418  28.06252216  14.81715036  69.05937299  45.63901708
#   27.06654738  34.22483993  56.10735629  41.74957574  37.55847551
#   24.66219293  25.8617498   78.73288115  21.15053515  28.35674605
#   65.18756277  15.4330689   24.60049648  28.08815958   5.57215942
#   34.68659776  43.05930689  36.77407757  31.25135756  10.13444161
#   31.69277946  35.93725881  12.19718903  48.00551688  13.33200328
#   45.36138847  40.85384215  75.66951059  26.05193971   9.20922937
#   43.91835838  16.51052228  88.27081753  36.55098305  24.39376412
#   22.92255529  25.16234303  39.3671818   28.79988688  52.70147369
#   22.28143195  30.18547364  54.22057995  27.28833228   6.16640985
#   41.87879439  17.75529032  14.63491666  43.40599719  34.76050511
#   45.53866984  56.212357    34.307917    76.23420077  15.41169587
#   13.40873841  91.15916868  53.25021616  40.83967384  40.03643687
#   30.88359637  53.13331516  56.93738166  46.879873    29.46278445
#   54.33089553  30.01038554  15.25514279  35.36369164  60.57825752
#   30.61670366  39.28979596  38.03053237  46.00822145  47.46537664
#   30.63313947  91.36994126  26.53361087  50.19172785  11.25642931
#   22.97679064   9.67208218  17.43161798  21.67419731  17.55268984
#   17.8605979   21.91519517  20.48440812  16.06967284  51.5518483
#   20.59131345  42.97330374  29.59655516  12.37159386  44.92398333
#   23.4061555   11.03398516  48.96958352  26.56423363  34.96773409
#   15.1447392   30.4390101   53.36045603  46.89052482  41.54334621
#   50.95841353  16.65879435  24.95470189  71.70790845  22.79879368
#   69.12321637  17.65957454  47.76627791  40.9087495   38.56264877
#   46.73841838 113.72256189  45.10518096  30.10818025  22.50205814
#   52.46995303  52.97445844  19.89247376  13.44949881  28.58669323
#   27.0199189    7.58000854  29.24046715  16.49822746  37.16007107
#   17.09881329  20.71423656  41.67318804  32.93264522  49.65876349
#   31.07560841  18.90294665  28.69415292  19.98414521  10.46227785
#   63.62737454  16.297973    27.80710341  10.63975573  34.97638813
#   26.87441318  17.11998213  43.84447218  37.85689816  21.70386201
#   28.64186707   6.65053839  20.50749774  42.99090824  33.65124517
#   32.6629976   45.42559019  28.95300183  26.00725253  32.96101853
#   32.03923621  21.77748784  11.84778457  26.32482579  55.93157361
#   53.26339554  26.45461393  68.84866257  79.2029772   61.61072013
#   41.82846669  52.46494708  98.16675212  19.18511531  41.09778872
#   34.21380937  20.75580581  45.14579649  47.42426941  59.35918204
#   48.40272298  51.88788812  41.13351787  43.28607022  57.19396866
#   17.51691394  85.02263162  14.99892366  48.53227969  37.6277572
#    8.5912495   74.37031706  77.22088583  16.88075168  33.1883794
#   44.47756536  69.70487707  42.25140602  17.96655707  49.61115365
#   29.04434223  43.38781827  18.96373195  83.61514004  37.66217726
#   37.14843533  33.31193512  39.52115425  53.51736886  24.21839587
#   45.04658927  18.08989776  47.29001011  50.53872234  77.92929284
#   38.42371452  14.86809884  37.31024578  28.29977833  10.62698779
#   13.19933989  45.80544037  58.64257828  34.55563088  54.12947056
#   37.06187173  13.52272224  41.91241596   8.40199717  94.82459887
#   20.01877119  54.23509565  35.16390675  18.582987    67.64680306
#   42.27265628  48.1135369   50.18799901  24.77945512  22.81267469
#   24.60188442  75.12209121  26.88814533   9.31477902   5.92524804
#   32.3401082    7.10742529  29.82372504  64.39705235  23.86300717
#   85.69067721  37.70442487  49.79445016  13.24289191  54.72665264
#   57.34228019  44.57228216  62.49486566  16.29332671  53.58342947
#   52.66842201  27.03960991  72.3631889   11.1207893   53.0900323
#   28.97299061  34.65932535  32.23943603  35.59965197  24.8088386
#   14.44499166  30.37098266  13.77347781  34.57923127  32.82791758
#    8.14481413  27.7568704  105.93845774  45.13757282  17.27472157
#   30.23267045  41.33721089  36.90565756  30.64494713  48.34703951
#   23.44018508  12.89498587  17.06139372  53.97440771  22.09138731
#   40.71382364  55.97031382  27.96816571  26.77889396  68.5174113
#   14.01032817  25.44552028  17.28230348  27.29590394  64.71988245
#   57.15080663  37.07743109  45.40253631  30.40158221  23.36784152
#   47.34700261  15.59100704  35.08782862  70.39754276  59.0877696
#   51.68520832  65.49736652  18.48280942  36.25639905  76.13077472
#   75.31453742  61.60096899  63.64160815  38.74477574  54.67481356
#    9.97457937  44.79008076  32.02330415  65.76048368  22.14653888
#   14.68552023  53.2751552   67.72337729  13.22491363  21.32149989
#   68.60710091  33.3525511   26.22267196  30.49325028  70.55875514
#   24.21242367  42.86151129  28.35593855  21.73099718  57.88522166
#   23.11434501  47.74904854  41.73788476  25.01540821  55.15621979
#   12.65603318  38.49020969  45.18713841  27.03331935  15.85265382
#   39.31702421  30.76125144   8.29250107  29.50319476  41.53278627
#   74.95800478  40.98565543  43.82796326  65.44210164  59.84292329
#   60.9843792   49.47701288  17.36039778  51.82339452  59.16198309
#   28.95855799  31.2474038   27.300108    38.5190367   23.96168424
#   19.79797659  20.92323194  20.86946895  36.49306391  17.08727006
#   31.98004028  32.05679907  22.04923781  30.89910646  21.24541451
#   52.19082315  66.45983645  20.40942232  68.69340687  86.2326005
#   31.56523647  32.91074097  66.45980295  31.08319952  16.87209784
#   30.35514639  63.75438552  59.02613595  40.19788448  20.80647703
#   53.95670891  61.65254492  40.26420592  28.4565143   14.88730427
#   47.31243674  55.39531079  20.46412095  23.19040867  19.89178415
#   14.76679595  45.11054929  36.06671269  41.884694    61.0421825
#   48.07891066  46.61416974  21.34223613  22.36726213  25.82699147
#   24.846268    60.79194737  35.76968381  34.19436973  41.93815578
#   61.78437908  11.8200655   83.83224081  32.45072368  19.62396742
#   41.53574921  27.00493623  63.23725245  16.07832118  43.6016159
#   43.65654275  23.11678907  19.03377117  11.95377358  15.59736612
#   26.17410446  29.99042696  58.52256361  35.38862926  34.95186171
#   33.90679418  17.04351179  37.66170973  16.35083562  75.73738431
#   60.26955433  32.99783412  62.40654599  82.93735407  16.60680722
#   16.48824297  57.64067933  41.61991558  34.19871575  22.30454308
#   62.78434775  18.4778687   51.55299798  55.7314082   38.47867863
#    8.65268723  40.3391371   27.43474546  30.95902936  33.9148358
#   55.33258488  20.016466    34.38105267  15.71063769  28.85379699
#   24.33654072  32.48970661  61.66629808  28.11870856  46.32363934
#    7.4710354   51.85793895  52.32371139  13.40044994  35.39178931
#   58.2580868   32.46851846  29.78799399  41.48434957  34.51759183
#   30.19854297  15.31243044  54.88693321  31.69241288  52.69617451
#   19.76138999 104.04266213  49.10495744  42.26637642  31.72069111
#   51.81206026  12.60548397  25.87156674  52.88293988  47.47375861
#   10.49848561  50.98205071  46.41144807  25.10290248  24.65252837
#   56.15202176  22.57296808  25.38901159  50.13482713  38.79016661
#   47.36101532  31.8651192   42.86437309  64.04219354  35.56422407
#   24.69902534  20.54564596  39.64318027   4.23592365  51.16113359
#   33.91743533  37.24423788  30.79770002  12.93426359  18.06265006
#   63.00384318  61.24630204   8.08641916  23.09024148  74.08700253
#   23.8114539   29.82750798  24.83963653  27.82559653  39.69250318
#   49.25876966  28.45746367  44.83844513  21.23825581  30.46428268
#   25.79278546  28.00535684  57.74443603  34.79458429  65.26065469
#   24.22046295  13.04505964  74.73100002  73.2376531   26.76902503
#   18.16593554  26.67694047  22.26397162  17.37443165  51.26007807
#   22.3984717   56.19002875  47.756173    38.59015571  30.70248378
#   68.23534516   3.92899259  33.22475682  13.49828517  56.15097631
#   61.93991116  21.29553957  86.2739503   13.20306599  66.35523487
#   32.08724629  23.83380477  39.88645669  69.0249112   61.97746081
#   37.67390094  16.83439814  29.61530764  17.68197197  43.22871201
#   67.51427258  43.86299995  44.60783654   7.8378337   30.85113069
#   43.06295178  66.37856669  17.61906809  52.74493718  31.89329129
#   10.82699032  28.02745863  26.60451516  70.51699139  37.80487112
#    8.07295679  67.42209065  19.57993831  19.69618155  54.42453148
#   29.66404779  56.63826606  46.8748487   20.78287432  16.05655152
#   21.56675516  25.09035094  62.16255975  16.30181891  19.70219944
#   40.7944044   45.56286703  33.0039642   34.26863617  43.46991985
#   17.85833913  61.07954439  21.23388909  37.79724649  31.49307019
#   22.1110074   60.56946141  34.59988354  12.37649059  39.42226813
#   32.72071513  87.77257855  52.419192    22.69083393  25.5106008
#   58.33887832  54.93439923  53.51680652  20.03172425  31.84853169
#   42.76010174  29.55533255  25.42517949  51.46332315  37.55706631
#   19.62597562  39.20152836  11.57333272  35.66007732   9.54459973
#   55.18199076  45.26838536  25.50509063  43.66760939  31.43156946
#   44.3618358   47.88431221  11.21029854  27.33705609  54.96328432
#   32.15191604  42.68237851  96.6212367   21.31180797  49.64211388
#   58.10625345  19.47053861  40.98744361  15.7701882   41.41631496
#   45.87322347  23.77452729  60.17650778  29.93344963  25.36520123
#   37.05631162  22.95593624  47.59110856  33.60740698  30.96377249
#   34.83208604  35.07937793  65.04841078  24.08310684  76.81114576
#   13.54221678  46.17121633  13.54659417  30.10409112  26.89134869
#   35.34370223  27.49401234  20.83418465  61.10836428  18.9883923
#   19.23380351  27.03915614  19.7728189   71.76480722  45.91478479
#   41.37083459  22.72654897  56.29382422  43.08432648  18.51350526
#   18.58943398  24.70796028  16.88172342  40.80888187  10.62795411
#   39.67985974  15.35278179  40.68536524  16.8927542   61.86622961
#   34.0361672   23.69248149  34.15980549  27.73688931  23.22429051
#   28.30719443  16.33415878  44.80829218  29.23628407  24.07808665
#   53.5410831   25.33317806  25.5094315   10.20477355  26.19457064
#   11.98185048  27.74323845  47.85735855  21.68816774  43.48945319
#   36.98599976  26.15569983  22.17462613  10.9131756   34.63762816
#   15.71038278  27.17277443  30.02276492  20.10466566  51.71619929
#   50.94646122  32.14784588  36.20810558  35.92303895  16.39961583
#   33.378717    18.66810713  16.91658914  29.62010435  94.98117533
#   10.61063422  20.13742145  47.79439671  22.67557936  51.4631951
#   53.17429221  41.97403735  51.66026671  33.1023524   10.95602146
#   24.75846095  45.18593969  49.55239689  34.04025841  42.58835703
#   40.75208051  29.82147869  15.65893254  46.20950252  49.34467823
#   71.42082038  49.3899446   12.45984215  22.85953451  43.11383934
#   50.71827283  12.43806656  87.05598855  32.60385821  55.72811165
#   20.72864758  20.02005056  36.62094253  25.33334968  18.60676021
#   65.72652379  63.45414928  70.35970733  25.56929555  44.99617057
#   24.49121323  21.59807223  30.82814807  43.27868884  25.36273402
#   23.53627532  34.42958085  45.15589622  40.87453267  36.82735137
#   13.91418624  26.99578901  40.92273814  43.98301417  19.66459589]
# 162.934448957
# 36.8541667254848
# 18.701666525610328
# [ 80.59082315  39.58177547  52.23672547 116.35146438  67.81293687
#   37.38702809  34.17921296  60.07142324 133.86948862 103.93780119
#   62.01026564  73.49715593  53.96829432  49.11399169  49.89957878
#   64.34541473  64.11943537  64.45984485  60.33892626  58.95238363
#   75.36776392  65.85201998  41.37665215  64.24517156  88.85586262
#   77.76082408  56.83132698  97.69397598  77.19346311  72.65693647
#   55.94546356 127.19154642  70.74041979  57.55997759  47.08260976
#   74.42275471  59.19544244  72.54801334 115.12985161  55.8889974
#   51.35890498  52.33906969  81.60037862  94.94452496  66.52158567
#   34.48066381  53.27900728  53.72140808  46.16394525  46.96410383
#   75.45240992  45.30231187  78.99344902  76.31675518  72.3091096
#   93.54647164  56.11302072  46.23586556  54.0249273   64.23281609
#   60.6494446   55.75252769  63.99031554  67.59850251  46.76216406
#   42.16104063  63.48464633  60.99538708  48.13322728  43.36716451
#   48.24410823  57.42884523  52.27953389  54.28778835  72.62123582
#   55.06353362  59.92139846  60.56918286  57.4448647   52.12808167
#   47.45943327  72.64867611  49.65958295  63.3824215   72.41459309
#   79.05618833  98.5279781   45.92173155  92.82896317  62.87130709
#   45.658214    51.86056666  68.00277282  48.54643078 114.41160026
#   51.41448292  56.22475198  49.97313348  87.12093717  77.5473568
#   78.2942872   80.84878435  47.38010855  58.74823886  40.9750969
#   98.71568559  54.16620828  97.58915353  67.88586673  76.27039371
#   43.36037782  49.53009659  54.48332724  53.99144511  71.98932449
#   65.29704156  65.0942406   64.37119453  76.83372412  67.12714548
#   69.78213365  65.77293296  40.52811252 102.7030189   61.89872074
#   91.06648706  84.54873036  54.83395673 107.6899394   50.98372654
#   89.31830179  47.65684583  69.14911599  75.89362251  79.77512999
#   31.75122364  54.06425217  66.3414061   55.58593367  90.16830098
#   58.88534122  94.49187849  44.93543059 126.7915787   55.9433522
#   56.75027139 115.51493961  53.5739538   51.73861155  64.40417247
#   55.39339182 104.2216719   58.19901249  41.86111558  78.38315165
#   56.63337268  67.87591455  64.42592734  85.17865336  45.27993223
#   64.2344014   94.12704434  75.16813225  59.48692114  70.44160624
#   52.04692771  63.94184029 108.97339918 117.9142266   79.21245316
#   61.44525075  55.57466665  59.13457567  47.81387954  56.91526475
#   84.02867045  66.46919019  92.33348078  63.23232543  49.85085729
#   89.78776103  61.47928762  35.86759359  72.61981459  38.93722917
#   45.69164629 119.93183989  72.64137752  68.0710672   34.22638459
#   89.56839207  67.73205074  50.62548267  60.53447423  53.50243525
#   47.17358968  53.74307008  83.67421287  62.78774789  54.10084461
#   46.36541159  51.74191413 104.58075722  78.24953551  84.69568253
#   71.21337661  44.54451763  44.5932271   91.66996605  66.92148618
#  133.35734971  87.29261797  60.76789688  54.07688095  59.52599827
#   41.85827425  84.4923894   62.1782273   74.11009467  34.37670966
#   61.2657633   56.88232329  66.89289113  72.44728446  92.45170928
#   32.20828763  66.76440497  49.95624555  43.61009726  46.60824904
#   63.99866311  47.04330198  60.10961724  84.38110468 100.47844717
#  106.6693121   80.2790041   51.19563812  65.86284669  65.21723998
#   50.37185754  55.05805697  55.71966125  66.8857723   90.97981943
#   86.81775292  55.06524212  52.15752072  40.31460338  74.11739548
#   60.69964229  60.9426835   84.02877845  71.13011162  51.87306812
#   48.78360568  41.83005608  49.59462398  99.2632857   47.78607307
#   65.58973262  71.71680548  85.17487069  42.25646301  66.64631059
#   64.49307239  45.31409586  50.39497656  56.57613584  68.55429132
#   50.62941489 107.29504285  53.66319051  74.70788868  44.70383517
#   60.52625183  62.48861408  87.9785775   54.78028009  65.22404211
#   56.77480458  49.97533198  46.72815137  57.84684386  39.00110569
#   50.75261391  75.37162354  58.40919424  89.25394249  65.21587697
#   56.38742699  44.54550305  73.15538146  66.34661983  50.14576344
#   59.49979105  98.77979968  84.49746541  67.97539781  80.66713628
#   62.36511166  47.78898959  46.51696109  61.81805251  49.50299259
#   42.62499415  53.11816352  66.79146978  69.04496749  61.51663086
#   55.42991403  55.89151382  59.23811505  68.00086399  53.64824744
#   75.1437887   84.28792473  53.66480338  74.240182    71.54526226
#   41.78962157  70.70350608  63.53151785  59.92474755  81.62849272
#   95.73802038  75.67330501  45.33038966  46.94101776  66.02746113
#  112.48655458  45.0834541   64.28490976  63.65838724  73.21831572
#   55.54437587  51.30200981  44.24368289  30.10796159  58.25618803
#   56.4661478   83.81311778  74.99641156  75.02526189  50.20343097
#   50.94279901  71.67778455  46.0072708   57.58562765  36.78596783
#   75.32989628  42.99053272  41.99670741  47.17223737  89.52664345
#  103.61748299  65.01116294  46.3327927   47.5585496   82.03846716
#   83.28170213  83.18585827  48.52516523  67.9347435   42.42487123
#   37.70561895  65.81871661  84.19810572  63.06013551  41.89386347
#   56.85275496  49.40234597  65.10387027  65.73679757 103.45620728
#   49.87427087  58.31366245  64.00184499  80.35625239  86.81295451
#   88.79087411  70.30405249  49.42666688  80.15055392  55.38520724
#   45.59340935  51.21526525  67.33892777 101.07050417  82.72852109
#  137.96196788  85.42791609  46.18690221  87.70030575  37.00110405
#   62.25000275  81.71331577  58.33722596 118.59973002  92.75581101
#   41.49159406  66.83196003  83.09751943  58.72240055  47.91553439
#  132.97093939  79.59274756  63.03502365 135.2691745   51.80100189
#  109.98458867  97.85094541  68.82804869  57.41268271  57.22840684
#   37.08445358  32.60501802  82.49409991  50.46372806 103.35420705
#  145.66475621  43.72610442  79.59535939  61.80147789  60.76761691
#   71.81395754  61.4703986   50.03179796  46.79014799  57.56602934
#   51.34217245  58.38918378  29.21697488  67.74374438  69.97697649
#   35.15877108  63.34917627  60.70203091  57.24126458  37.62665714
#   87.76173825  83.92664553  88.97093308  54.36269161  88.82638055
#   80.34411471  75.54254782  71.85237662 106.27116007  86.80344974
#  134.32868984  88.81073582  66.45341083  64.92077284  69.02558884
#   75.73946298  61.39129445  42.67095392  54.22529543  38.23369736
#   51.89429731  57.57467888  46.13440071  70.6253241   38.49548956
#   51.53516968  49.06956357  63.47108594  71.37247676  43.20592307
#   57.68744772  52.24934311  57.01145762  45.45620342  85.65065867
#  149.38174515  67.80277937 120.88757481  38.92495992  62.52459894
#   82.10003603  67.62316485  44.49444681  52.59481346  54.85952625
#   32.66532958  61.2215953   41.83488467  63.47834936  50.86772621
#   59.10106093  42.89489108  75.19317768 114.45623048  44.02183506
#  100.85369799  86.16358102  64.53694463  74.75784886 187.51624747
#   53.52722224  61.42584499  72.40174851  54.5875712   58.35639815
#   42.11129962  31.64829029  66.56890497  44.54556891  68.54851137
#   68.24495232 105.16188158  93.67415318  56.41194501  48.49266279
#   35.74396576  50.90459636  53.51931324 109.89163551  51.20983229
#   61.52197054  48.38123594  36.95733389  50.6660054   58.78293042
#   55.68355315  33.67115483  64.86965416 110.07017921  82.22377272
#   50.89293659  23.58193687  69.84084692  55.14332596  87.10270113
#  114.19262108  63.07066712  93.15646258  76.61785     53.76114862
#   53.63637826  43.16744125 132.82937293 101.09614352  89.08704033
#   81.18557207  53.38738316  44.13330379  80.32218446  37.08466677
#   72.07396586  60.22674249 107.39839205  88.05094978  40.64558266
#   60.87539301  57.87981385  44.28235336  54.86433136  55.45680033
#   61.38512349  32.77812507  36.55115111  39.28773303  55.08223768
#   68.9406769   62.08538779  61.91887118  80.25795093  36.74645047
#   52.1352097   45.83779562  73.65068321  99.42574722  72.00493558
#   57.58141298  57.20771274 105.6255292   30.15688815  70.98539461
#   95.0057497   60.02720916  47.94858052 101.69388523  54.94612949
#   80.79481009 144.26129981  67.2397512  108.06033043  57.49485259
#   97.25458315  39.86918981  52.06314365  45.666415    59.73985384
#   78.39970836  62.12003971  84.97205366  57.20223019  32.93542665
#   50.28743364  76.16300079  49.92437486  59.64127662  36.56369574
#   79.50774875  73.96238756 105.06054019  50.28036697  50.48703629
#   46.72898494  33.67373691  41.09463095  75.2632341   82.50285841
#  101.66420756  41.6097129   75.14888103  68.3233262   47.80138595
#   35.51443497  80.44671394  47.75200333  55.66953568  98.96149842
#   40.30473187  72.94765368  53.94648429  50.71635396  58.01689572
#   73.11674495  92.59357049  67.72906298  62.9911842   71.9250783
#   87.24659636  43.90600737  45.19412049  43.8331772   68.85759048
#   58.69353622  82.72134303  62.04208884  42.64234457  62.28012266
#   42.41334568  98.33174174  58.65769356  51.77706898  74.32270233
#   35.09220173  61.29053611  40.32797572  65.81250401  62.38223723
#   40.71616216  33.13393804  84.68937202  38.2425204  157.82677365
#   49.37750783  79.62474187  31.92433487  56.432109    45.60427142
#   46.70787372 110.26724051  54.77658312  57.18324807  90.76999371
#   66.88459028  55.57681865  46.00359113  61.66547642  95.05419807
#   73.24516645  72.35407027 132.87561728  59.00274459  66.17070036
#  116.98446101 127.96219045  59.13477408  79.97442409  40.26747083
#   96.9770753   68.03805715  41.8000071   49.34164149  60.95027355
#   78.58702794  83.75421243  51.05741504  96.25511294  49.27742316
#  107.97093467  59.76803228  33.79385963  37.27926288  57.12821895
#  114.85632727  95.43974848 102.70786926  42.53008708  76.13844771
#   39.47668776  51.48754295  97.45808897  76.71519614  50.20424411
#   78.06678256  88.83344124  32.81617857  52.60624894  40.03639008
#   63.15235017  99.70198727  85.19335766  74.82523127  60.64941738
#   50.96410747  57.55316074  54.7825086   68.33177109  51.00146193
#   49.13600635  45.55078886  48.89534436  49.31810276  64.24247875
#   70.95884751  49.76068364  46.99809777  92.35165719  56.56479695
#   51.39766894  42.90489293 105.26489151  57.19978566 109.81128566
#   54.14542243  86.70623215  46.68019096  41.86954573  36.71076314
#   68.25875634  86.49280594  34.29397452 104.96416799 100.78680518
#   42.48627104  37.16305134  69.84053578  43.61181306  62.48363733
#   35.59375135  52.34885006  76.92297373  59.6547584   60.09599807
#   30.56395136  41.41172393  84.40274922  43.97430488  57.92245003
#   64.10689577  49.89821392  92.31415101  81.27768195  63.22312812
#   61.88399189  94.48818495  57.7620184   96.74333065 107.4677595
#   67.83483104  63.44311662  46.8514481   86.47646516  35.87842862
#   54.43531837  63.73862004  49.78687634  34.69253585  47.48663942
#   55.8264635   40.45585271  61.40825987  54.5739511   65.59080415
#   48.70113428  75.82516984 140.26029866  71.33086446  69.10141271
#   44.06717987  70.77026412  75.0570009   53.04675013  44.30974252
#   48.58525418  88.79889094  60.02884313  63.09577849  75.16581362
#   56.20140717  72.02494766  58.74258664  68.79451669  49.96080156
#   61.65571841  63.44910297  43.91894063 125.19731337  48.86050696
#   70.85460657  41.51631783  86.39631398  68.0197266   59.06107558
#   73.20926412  47.22865671  67.69756791  52.97534648  44.44090889
#   63.25038719  68.43588918  41.79269785  54.06256518  59.32827356
#   39.77935067  63.42424573  80.3957316   51.37942885 119.02075474
#   39.73848961  73.61453146  71.64268881  58.52653829  64.65201357
#  116.91766338 104.61211775  51.67134711  49.54536949 133.97187165
#  106.73898184  42.42546259  73.67377039  52.28821422  55.95717938
#   88.2051977   46.18960255  60.47099241  52.01280041 103.51762459
#   75.38457172  36.81589495  40.22303603  90.97684739  82.58052483
#   92.16879308  39.50267544  40.65540293  60.62050234  83.18449809
#   56.42336377  45.44596805  76.49222261  67.86643179  79.56127626
#   48.63867861  34.25359137  82.75798784 142.01712464  50.80090197
#   34.62474004  74.04646574  69.47353629  56.08556428  42.98343813
#  100.98684279  81.38918525  61.96083702  65.45915068  79.83289218
#   84.35361076  77.00146684  65.09394821  92.51251533  45.09457978
#   46.95192518  36.76460591  58.54090782  42.37476147  50.86087856
#   64.60730532  81.99450421  53.16271578  89.71038471  66.93706964
#   73.9770998   81.42068161  50.33919447  56.90181174  62.95402529
#   64.16089442  49.51702962  64.37329025  67.61382685 135.5907598
#   75.62414691  72.11201775  57.74338663  81.85447863  62.37778848
#   72.96391427  67.10199313  88.12674258  44.31846019  39.36955023
#   53.10249381  54.83741165  47.76315586  62.51624507  76.81276881
#   77.3335532   43.63279052  44.01787442 110.60375615  79.33546819
#   47.53457882  49.77999259  55.07446687 108.80150944  77.62643957
#   44.86882139  32.77518349  77.6178903   88.52893277  55.67062406
#   43.10369072  66.71732834  92.00322787  81.82412024  36.07761802
#   44.19232989  46.84962656  48.00837146  82.60994453  56.64089393
#   43.29895554  53.60948222  73.52819157  53.12447393  48.46438289
#   78.48232847  71.72490285  46.84745842  48.69151382  75.01907276
#   67.77418981  59.4981871   43.43225413 103.27395051  41.68360098
#   80.21834822  91.35537101  88.83144157  47.41151469  55.51032794
#   76.99179484  49.80180327 122.3892566   64.49043294  81.19978158
#   55.63543585  68.60183452 118.83256113  61.30045152  50.99405722
#   42.27706025  53.3705329   66.48234792 117.95894867  53.19927297
#   47.44458684  62.67176525  59.49035596  99.99403491  29.98236864
#   53.11464344  50.95756885  40.17676535  63.66881749  61.80182078
#   70.93685237  48.03528559  54.48018442  60.16109991  72.10593101]
# 162.325098991
# 65.6196890009331
# 21.915922654578914

# %%
from sklearn.metrics import roc_curve

y_true = np.append(np.zeros(len(qcd_truecost)),np.ones(len(top_truecost)))
y_score = np.append(qcd_truecost, top_truecost)
my_roc = roc_curve(y_true, y_score, pos_label=None, sample_weight=None, drop_intermediate=True)

plt.plot(my_roc[1],np.nan_to_num(1/my_roc[0]))
plt.ylim([1,10**2])
plt.semilogy()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in divide
#   import sys

# %%
from sklearn.metrics import roc_curve

y_true = np.append(np.zeros(len(qcd_truecost)),np.ones(len(top_truecost)))
y_score = np.append(qcd_truecost, top_truecost)
my_roc = roc_curve(y_true, y_score, pos_label=None, sample_weight=None, drop_intermediate=True)

plt.plot(my_roc[1],np.nan_to_num(1/my_roc[0]))
plt.ylim([1,10**2])
plt.semilogy()
plt.show()
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:10: RuntimeWarning: divide by zero encountered in divide
#   # Remove the CWD from sys.path while we load stuff.

# %%
import time
numload = 1000
feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
reconstructions = ae.reconstruct(feed_pc)[0]
latent_codes = ae.transform(feed_pc)
points1 = reconstructions[:1000]
#points1 = feed_pc[:1000]
latent_codes = ae.transform(feed_pc[:1000])

# %%
plt.figure(figsize=[12,6])
plt.subplot(1,2,1)
plt.scatter(jet_masses(reconstructions[:1000]),latent_codes,s=0.5)
plt.xlabel('Jet mass of decoded image [GeV]')
plt.ylabel('Latent code')
plt.subplot(1,2,2)
plt.scatter(jet_masses(feed_pc[:1000]),latent_codes,s=0.5)
plt.xlabel('Jet mass of original image [GeV]')
plt.ylabel('Latent code')
plt.show()

# %%
plt.figure(figsize=[10,10])
plt.scatter(jet_masses(reconstructions[:1000]),latent_codes,s=0.5)
plt.xlabel('Jet mass of decoded image [GeV]')
plt.ylabel('Latent code')
plt.show()

# %%
latent_codes
# Out:
# array([[0.00000000e+00],
#        [0.00000000e+00],
#        [5.81276476e-01],
#        [1.26240134e+00],
#        [3.47610474e-01],
#        [1.75073600e+00],
#        [1.39840186e-01],
#        [1.92238939e+00],
#        [3.10518295e-01],
#        [1.17008245e+00],
#        [3.96468550e-01],
#        [7.54160583e-02],
#        [4.76377696e-01],
#        [0.00000000e+00],
#        [2.68678188e-01],
#        [6.89374804e-01],
#        [0.00000000e+00],
#        [8.80986333e-01],
#        [0.00000000e+00],
#        [1.44568950e-01],
#        [2.33953893e-01],
#        [3.62116545e-01],
#        [0.00000000e+00],
#        [7.80828893e-02],
#        [1.66362613e-01],
#        [2.27818418e+00],
#        [2.96546161e-01],
#        [0.00000000e+00],
#        [2.14791155e+00],
#        [9.05103624e-01],
#        [0.00000000e+00],
#        [1.44773412e+00],
#        [1.10544348e+00],
#        [6.39003396e-01],
#        [2.02482671e-01],
#        [0.00000000e+00],
#        [8.25659990e-01],
#        [7.49899149e-01],
#        [8.32780004e-01],
#        [1.34153813e-01],
#        [8.90361369e-01],
#        [5.57683110e-02],
#        [5.33578575e-01],
#        [1.07533646e+00],
#        [4.20880318e-03],
#        [1.06929123e+00],
#        [1.92124224e+00],
#        [3.85040462e-01],
#        [1.01076722e+00],
#        [3.44540715e-01],
#        [0.00000000e+00],
#        [5.73047221e-01],
#        [3.43369842e-01],
#        [1.24316823e+00],
#        [9.14587438e-01],
#        [7.76466668e-01],
#        [7.99124002e-01],
#        [0.00000000e+00],
#        [4.63264227e-01],
#        [1.29138005e+00],
#        [3.52702916e-01],
#        [6.87514424e-01],
#        [1.31725430e-01],
#        [0.00000000e+00],
#        [7.74806440e-01],
#        [6.77116573e-01],
#        [8.08697939e-02],
#        [5.89160919e-02],
#        [8.90794396e-01],
#        [8.27843785e-01],
#        [9.12262082e-01],
#        [1.43211198e+00],
#        [4.27171707e-01],
#        [9.39660966e-02],
#        [8.51593316e-01],
#        [4.95821804e-01],
#        [5.02975881e-01],
#        [0.00000000e+00],
#        [1.08130276e+00],
#        [3.75758410e-02],
#        [1.22922421e-01],
#        [7.80793786e-01],
#        [0.00000000e+00],
#        [3.49909484e-01],
#        [3.26663303e+00],
#        [7.31189549e-02],
#        [8.10876250e-01],
#        [1.95963740e-01],
#        [2.15019286e-01],
#        [2.59439528e-01],
#        [1.03716183e+00],
#        [6.92556858e-01],
#        [0.00000000e+00],
#        [4.78884876e-01],
#        [0.00000000e+00],
#        [2.87180007e-01],
#        [6.16516471e-01],
#        [1.23133898e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.57854825e-01],
#        [0.00000000e+00],
#        [1.23960376e-02],
#        [5.42621255e-01],
#        [4.67741579e-01],
#        [1.11317962e-01],
#        [2.50179768e-02],
#        [8.86347592e-01],
#        [4.21330452e-01],
#        [6.35774851e-01],
#        [4.04379606e-01],
#        [9.44339395e-01],
#        [0.00000000e+00],
#        [5.59861600e-01],
#        [1.39546382e+00],
#        [2.40622807e+00],
#        [1.39976609e+00],
#        [1.16890049e+00],
#        [2.90336192e-01],
#        [8.78177941e-01],
#        [2.66411513e-01],
#        [1.27987695e+00],
#        [1.61636025e-01],
#        [4.10973430e-02],
#        [0.00000000e+00],
#        [1.24640465e-02],
#        [2.53185272e-01],
#        [5.79816818e-01],
#        [6.35921955e-04],
#        [2.57261008e-01],
#        [1.76930487e-01],
#        [1.08497709e-01],
#        [1.05117917e+00],
#        [7.16951847e-01],
#        [3.34163606e-01],
#        [0.00000000e+00],
#        [1.54830432e+00],
#        [1.62781692e+00],
#        [8.65990639e-01],
#        [1.78631675e+00],
#        [1.00064337e+00],
#        [5.73410511e-01],
#        [3.90586764e-01],
#        [8.91650558e-01],
#        [1.02414072e+00],
#        [0.00000000e+00],
#        [5.05662620e-01],
#        [1.09095478e+00],
#        [1.40610349e+00],
#        [2.76488096e-01],
#        [0.00000000e+00],
#        [1.35200173e-01],
#        [2.24019146e+00],
#        [0.00000000e+00],
#        [3.12431604e-01],
#        [0.00000000e+00],
#        [9.17162299e-01],
#        [5.29734492e-01],
#        [1.07692146e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.04336083e+00],
#        [9.47667837e-01],
#        [1.92394257e+00],
#        [9.28522050e-02],
#        [6.85787916e-01],
#        [1.18918395e+00],
#        [1.33036196e-01],
#        [6.83232665e-01],
#        [0.00000000e+00],
#        [9.13030028e-01],
#        [9.38266993e-01],
#        [2.31496662e-01],
#        [1.00717306e+00],
#        [5.78582585e-01],
#        [9.75075364e-01],
#        [2.93605119e-01],
#        [5.58190227e-01],
#        [5.34974694e-01],
#        [8.61786366e-01],
#        [1.53501940e+00],
#        [2.39153773e-01],
#        [2.19208598e-02],
#        [9.28895831e-01],
#        [1.12646371e-01],
#        [0.00000000e+00],
#        [1.44175506e+00],
#        [3.81617188e-01],
#        [1.26301146e+00],
#        [0.00000000e+00],
#        [3.88605684e-01],
#        [4.62861091e-01],
#        [1.66814041e+00],
#        [4.65489924e-01],
#        [5.07663846e-01],
#        [4.94143248e-01],
#        [8.25304985e-01],
#        [8.12158406e-01],
#        [3.59296858e-01],
#        [8.46246183e-02],
#        [1.23224795e-01],
#        [3.04270416e-01],
#        [4.21533167e-01],
#        [2.14572638e-01],
#        [9.63206589e-02],
#        [3.57461065e-01],
#        [0.00000000e+00],
#        [3.70667577e-01],
#        [7.85765350e-02],
#        [6.15778685e-01],
#        [0.00000000e+00],
#        [2.43259639e-01],
#        [3.80608082e-01],
#        [1.51065660e+00],
#        [4.17520642e-01],
#        [0.00000000e+00],
#        [3.44953865e-01],
#        [3.88249159e-02],
#        [1.91078782e-02],
#        [8.44339430e-01],
#        [3.71310711e-01],
#        [3.99431586e-01],
#        [0.00000000e+00],
#        [7.71205485e-01],
#        [3.26459110e-01],
#        [4.02266383e-02],
#        [3.45379889e-01],
#        [6.92039967e-01],
#        [1.16705561e+00],
#        [2.44288826e+00],
#        [8.04264426e-01],
#        [1.69267952e-01],
#        [7.93583572e-01],
#        [3.55957747e-02],
#        [8.04888248e-01],
#        [2.81298459e-01],
#        [8.88218641e-01],
#        [8.95482421e-01],
#        [3.57575417e-02],
#        [3.22647154e-01],
#        [5.61428070e-03],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.64147663e-01],
#        [2.69428611e-01],
#        [2.13949156e+00],
#        [1.95220679e-01],
#        [1.07999116e-01],
#        [1.01565719e-02],
#        [0.00000000e+00],
#        [3.67579877e-01],
#        [4.32395816e-01],
#        [5.59060931e-01],
#        [1.53872383e+00],
#        [9.50295448e-01],
#        [4.11297679e-02],
#        [7.77903259e-01],
#        [6.02793634e-01],
#        [9.14517641e-01],
#        [4.14355397e-02],
#        [1.19198728e+00],
#        [2.81482428e-01],
#        [8.24674249e-01],
#        [7.78486550e-01],
#        [3.49625587e-01],
#        [4.81476307e-01],
#        [7.70769417e-02],
#        [7.71087527e-01],
#        [6.95025563e-01],
#        [4.56211597e-01],
#        [8.53333950e-01],
#        [6.44982696e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [7.98775613e-01],
#        [3.21463525e-01],
#        [3.89991462e-01],
#        [2.54009366e-01],
#        [2.06276506e-01],
#        [0.00000000e+00],
#        [7.18008280e-01],
#        [1.01810622e+00],
#        [0.00000000e+00],
#        [8.43420148e-01],
#        [6.93618596e-01],
#        [7.71987736e-01],
#        [0.00000000e+00],
#        [4.73375738e-01],
#        [5.47193885e-02],
#        [8.70071709e-01],
#        [0.00000000e+00],
#        [1.63212168e+00],
#        [2.60907739e-01],
#        [2.31040096e+00],
#        [1.25920081e+00],
#        [2.66803235e-01],
#        [0.00000000e+00],
#        [5.37141800e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.81484866e-01],
#        [1.35357976e-02],
#        [1.16038561e+00],
#        [9.20402288e-01],
#        [2.15843320e-02],
#        [3.38168144e-02],
#        [1.83340400e-01],
#        [0.00000000e+00],
#        [5.91119826e-01],
#        [4.62538004e-02],
#        [2.89307475e-01],
#        [0.00000000e+00],
#        [9.01048541e-01],
#        [2.60148704e-01],
#        [2.41026783e+00],
#        [0.00000000e+00],
#        [3.75873238e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.30724907e+00],
#        [7.75359869e-01],
#        [5.86825609e-01],
#        [2.20453024e+00],
#        [0.00000000e+00],
#        [1.21237254e+00],
#        [7.18362212e-01],
#        [0.00000000e+00],
#        [6.78168118e-01],
#        [0.00000000e+00],
#        [9.29888010e-01],
#        [0.00000000e+00],
#        [1.22868907e+00],
#        [0.00000000e+00],
#        [1.05466950e+00],
#        [1.19725287e+00],
#        [7.43105292e-01],
#        [8.03249836e-01],
#        [4.80784535e-01],
#        [3.12608421e-01],
#        [1.07362473e+00],
#        [0.00000000e+00],
#        [3.81968439e-01],
#        [9.41447318e-02],
#        [3.83668542e-02],
#        [1.28438282e+00],
#        [5.02151251e-03],
#        [3.05022925e-01],
#        [3.59766543e-01],
#        [2.77675772e+00],
#        [8.40567172e-01],
#        [8.41341615e-02],
#        [1.51702911e-01],
#        [1.23664236e+00],
#        [1.50413841e-01],
#        [1.57788843e-01],
#        [1.30447119e-01],
#        [7.38011956e-01],
#        [5.39073706e-01],
#        [1.01268554e+00],
#        [1.60636425e-01],
#        [3.93548131e-01],
#        [2.87591648e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [7.91962504e-01],
#        [6.07649922e-01],
#        [8.71587694e-02],
#        [3.73299241e-01],
#        [4.34673399e-01],
#        [1.31319225e-01],
#        [7.19435871e-01],
#        [7.37086654e-01],
#        [0.00000000e+00],
#        [5.80085754e-01],
#        [8.26096535e-01],
#        [3.59071374e-01],
#        [0.00000000e+00],
#        [3.03727686e-01],
#        [1.82731509e-01],
#        [2.12209606e+00],
#        [8.54458451e-01],
#        [1.10619116e+00],
#        [2.37242609e-01],
#        [4.95143235e-01],
#        [1.02997684e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.50909477e-01],
#        [4.31525260e-01],
#        [1.86621398e-01],
#        [1.55275017e-01],
#        [1.34526819e-01],
#        [1.28979146e-01],
#        [1.02398849e+00],
#        [1.34227574e-01],
#        [3.75305176e-01],
#        [2.97430843e-01],
#        [0.00000000e+00],
#        [1.06717765e+00],
#        [1.15777910e+00],
#        [6.71570003e-01],
#        [0.00000000e+00],
#        [7.72741735e-02],
#        [0.00000000e+00],
#        [1.05363584e+00],
#        [2.43233472e-01],
#        [2.61770815e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [3.91827643e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [7.03715801e-01],
#        [6.92205548e-01],
#        [0.00000000e+00],
#        [4.61939484e-01],
#        [3.76165628e-01],
#        [1.15087092e+00],
#        [8.71100426e-02],
#        [0.00000000e+00],
#        [4.88649070e-01],
#        [1.45225120e+00],
#        [1.21178067e+00],
#        [8.29189539e-01],
#        [0.00000000e+00],
#        [1.68595505e+00],
#        [2.57842571e-01],
#        [8.04139555e-01],
#        [5.89248359e-01],
#        [2.18560427e-01],
#        [6.68518841e-02],
#        [0.00000000e+00],
#        [4.26928014e-01],
#        [4.29780126e-01],
#        [8.62339556e-01],
#        [2.62951285e-01],
#        [6.06607080e-01],
#        [1.58394337e-01],
#        [1.31118464e+00],
#        [5.72900891e-01],
#        [2.76394725e-01],
#        [6.38481081e-02],
#        [9.66249406e-02],
#        [6.08380079e-01],
#        [5.87575078e-01],
#        [4.90548611e-02],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [4.01592016e-01],
#        [8.23458731e-02],
#        [1.15049362e+00],
#        [9.18249369e-01],
#        [8.28520894e-01],
#        [6.48629963e-02],
#        [0.00000000e+00],
#        [6.51506782e-02],
#        [5.44036031e-02],
#        [3.55730534e-01],
#        [9.08966184e-01],
#        [3.02684039e-01],
#        [3.04020405e-01],
#        [3.84579420e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [6.44568205e-01],
#        [5.21918118e-01],
#        [2.05220371e-01],
#        [1.17456627e+00],
#        [8.03719282e-01],
#        [0.00000000e+00],
#        [8.09430122e-01],
#        [8.92376602e-02],
#        [4.75977063e-02],
#        [9.17748988e-01],
#        [9.57465172e-03],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.26010180e-02],
#        [3.03228021e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.76651466e-01],
#        [4.60402340e-01],
#        [3.95406485e-01],
#        [0.00000000e+00],
#        [1.86298370e-01],
#        [0.00000000e+00],
#        [9.25678670e-01],
#        [1.35115707e+00],
#        [8.56556177e-01],
#        [7.93457508e-01],
#        [6.69318914e-01],
#        [1.11798495e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.18809670e-01],
#        [1.07616448e+00],
#        [1.91263139e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.52503359e-01],
#        [1.28448582e+00],
#        [9.11225021e-01],
#        [6.48526967e-01],
#        [1.41810369e+00],
#        [1.12268686e+00],
#        [3.64221871e-01],
#        [6.57352626e-01],
#        [1.23589349e+00],
#        [0.00000000e+00],
#        [4.96079683e-01],
#        [0.00000000e+00],
#        [1.18683720e+00],
#        [8.78328800e-01],
#        [0.00000000e+00],
#        [5.80967546e-01],
#        [9.30490494e-02],
#        [7.54982233e-03],
#        [7.96834648e-01],
#        [1.55750096e-01],
#        [9.12659347e-01],
#        [4.64537919e-01],
#        [9.22414064e-01],
#        [0.00000000e+00],
#        [3.98746610e-01],
#        [7.41484761e-01],
#        [4.36988473e-01],
#        [0.00000000e+00],
#        [4.86344993e-01],
#        [8.77877355e-01],
#        [0.00000000e+00],
#        [7.92486668e-01],
#        [1.09548044e+00],
#        [4.51915115e-01],
#        [8.83197904e-01],
#        [7.06724763e-01],
#        [0.00000000e+00],
#        [5.81026196e-01],
#        [0.00000000e+00],
#        [2.28402424e+00],
#        [3.14468145e-03],
#        [1.48017967e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [9.34702456e-02],
#        [1.88712955e-01],
#        [1.69316733e+00],
#        [4.77334738e-01],
#        [4.39202756e-01],
#        [0.00000000e+00],
#        [3.43832225e-01],
#        [9.74431932e-02],
#        [9.32828784e-01],
#        [1.55076504e+00],
#        [1.72949344e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [5.79591274e-01],
#        [2.60805428e-01],
#        [1.09357178e+00],
#        [1.17410886e+00],
#        [8.61395955e-01],
#        [4.76118922e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.01813257e+00],
#        [0.00000000e+00],
#        [8.88161659e-01],
#        [1.82182193e-02],
#        [7.95365453e-01],
#        [1.55405402e-01],
#        [7.65915453e-01],
#        [3.19363832e-01],
#        [1.68541670e+00],
#        [3.64634663e-01],
#        [9.02830839e-01],
#        [1.09239292e+00],
#        [4.22343165e-01],
#        [5.13708532e-01],
#        [6.63974583e-02],
#        [8.09313536e-01],
#        [2.47079551e-01],
#        [2.16677833e+00],
#        [8.92519712e-01],
#        [2.09785163e-01],
#        [5.72691262e-01],
#        [1.96755302e+00],
#        [5.13164401e-02],
#        [2.02475786e-02],
#        [0.00000000e+00],
#        [3.73447567e-01],
#        [2.91081220e-01],
#        [1.38160515e+00],
#        [8.30644071e-01],
#        [0.00000000e+00],
#        [3.85967970e-01],
#        [1.51249260e-01],
#        [0.00000000e+00],
#        [1.00954592e+00],
#        [0.00000000e+00],
#        [1.12500989e+00],
#        [0.00000000e+00],
#        [8.97156835e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [5.89711607e-01],
#        [1.27218032e+00],
#        [1.85678363e-01],
#        [2.75070047e+00],
#        [8.33275557e-01],
#        [5.44170499e-01],
#        [2.98142165e-01],
#        [4.05851036e-01],
#        [2.00412959e-01],
#        [8.38845968e-03],
#        [0.00000000e+00],
#        [9.15063381e-01],
#        [7.40585864e-01],
#        [5.76131344e-02],
#        [2.90957540e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.80733609e-01],
#        [1.15193057e+00],
#        [2.72793770e-02],
#        [8.51089835e-01],
#        [1.84828371e-01],
#        [1.18718219e+00],
#        [8.89714003e-01],
#        [0.00000000e+00],
#        [7.79009104e-01],
#        [0.00000000e+00],
#        [1.89764053e-01],
#        [1.84958279e-01],
#        [1.14139771e+00],
#        [7.41838217e-01],
#        [0.00000000e+00],
#        [6.10574961e-01],
#        [5.94723701e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [3.43496799e-01],
#        [7.43664265e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.07385850e+00],
#        [1.38239741e+00],
#        [1.74284667e-01],
#        [0.00000000e+00],
#        [1.62602812e-01],
#        [8.51452589e-01],
#        [0.00000000e+00],
#        [8.46477449e-01],
#        [1.03532124e+00],
#        [3.08497190e-01],
#        [0.00000000e+00],
#        [4.88644242e-02],
#        [0.00000000e+00],
#        [1.11827338e+00],
#        [3.38326752e-01],
#        [0.00000000e+00],
#        [8.00197303e-01],
#        [3.33996475e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.08757520e+00],
#        [0.00000000e+00],
#        [1.67529851e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.75223875e+00],
#        [8.26346874e-01],
#        [1.39793277e+00],
#        [5.76967120e-01],
#        [9.11358237e-01],
#        [1.29179120e-01],
#        [6.14615083e-02],
#        [3.95550758e-01],
#        [1.32840723e-01],
#        [9.00192320e-01],
#        [1.21967065e+00],
#        [3.61689180e-01],
#        [0.00000000e+00],
#        [1.00123346e+00],
#        [6.55624330e-01],
#        [2.44153643e+00],
#        [0.00000000e+00],
#        [8.93712401e-01],
#        [7.80390680e-01],
#        [1.04383874e+00],
#        [8.35594714e-01],
#        [0.00000000e+00],
#        [8.98831248e-01],
#        [7.52055645e-03],
#        [4.83268797e-01],
#        [5.07792771e-01],
#        [7.73387790e-01],
#        [2.75203377e-01],
#        [0.00000000e+00],
#        [1.66399479e-01],
#        [1.06396437e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.66755486e-01],
#        [4.85786021e-01],
#        [9.67291951e-01],
#        [1.25707269e-01],
#        [1.96904749e-01],
#        [1.04944289e-01],
#        [5.91723680e-01],
#        [1.68752491e-01],
#        [9.88273323e-02],
#        [1.06835216e-01],
#        [0.00000000e+00],
#        [1.42461395e+00],
#        [3.12029213e-01],
#        [3.57653260e-01],
#        [4.77711797e-01],
#        [1.54957926e+00],
#        [8.17044258e-01],
#        [1.21350318e-01],
#        [6.87655509e-01],
#        [0.00000000e+00],
#        [7.61030495e-01],
#        [1.29893780e-01],
#        [1.07836115e+00],
#        [0.00000000e+00],
#        [8.60340834e-01],
#        [8.69684696e-01],
#        [1.43012732e-01],
#        [2.44324875e+00],
#        [1.45030415e+00],
#        [4.45240140e-02],
#        [9.11187291e-01],
#        [1.07151210e+00],
#        [3.74843538e-01],
#        [0.00000000e+00],
#        [4.02380347e-01],
#        [3.86196882e-01],
#        [3.00580412e-01],
#        [1.81480527e+00],
#        [1.26237786e+00],
#        [4.20782506e-01],
#        [1.30492616e+00],
#        [1.57259941e-01],
#        [1.46858990e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.01994467e+00],
#        [9.00167584e-01],
#        [2.96582460e-01],
#        [4.78615373e-01],
#        [5.80830336e-01],
#        [5.60520887e-02],
#        [7.20173538e-01],
#        [1.39557719e-02],
#        [1.60266280e-01],
#        [0.00000000e+00],
#        [4.64715660e-01],
#        [4.12063479e-01],
#        [5.83675623e-01],
#        [8.85302901e-01],
#        [1.57032132e+00],
#        [7.83784866e-01],
#        [0.00000000e+00],
#        [1.27944767e-01],
#        [8.93540263e-01],
#        [7.90563107e-01],
#        [2.11035466e+00],
#        [9.28451300e-01],
#        [3.16634834e-01],
#        [1.06416941e+00],
#        [3.90857905e-01],
#        [8.66944432e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [3.76249790e-01],
#        [1.35552019e-01],
#        [1.43201232e+00],
#        [0.00000000e+00],
#        [1.25845242e+00],
#        [1.95158839e-01],
#        [1.53633356e-02],
#        [5.72496176e-01],
#        [3.24151337e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.80101275e+00],
#        [1.34518296e-01],
#        [3.13205719e-02],
#        [1.64146090e+00],
#        [2.65574455e-03],
#        [1.97297335e-03],
#        [8.74461055e-01],
#        [8.95297766e-01],
#        [1.08222747e+00],
#        [3.74752581e-01],
#        [0.00000000e+00],
#        [2.75049269e-01],
#        [9.65705454e-01],
#        [0.00000000e+00],
#        [1.77958739e+00],
#        [0.00000000e+00],
#        [1.08436787e+00],
#        [2.20874935e-01],
#        [8.13147366e-01],
#        [0.00000000e+00],
#        [9.58227217e-02],
#        [6.78666532e-02],
#        [1.27668083e-01],
#        [3.21243227e-01],
#        [2.65362382e-01],
#        [1.81898272e+00],
#        [3.51100206e-01],
#        [2.51067847e-01],
#        [9.04572725e-01],
#        [7.66656637e-01],
#        [1.51738560e+00],
#        [1.05237961e-03],
#        [1.71306521e-01],
#        [5.82765758e-01],
#        [1.47001892e-01],
#        [3.17903817e-01],
#        [3.04682642e-01],
#        [6.15216374e-01],
#        [8.13187659e-02],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.20274127e-01],
#        [4.21566695e-01],
#        [1.23191237e+00],
#        [1.35889143e-01],
#        [5.80440998e-01],
#        [6.05977178e-02],
#        [8.53104353e-01],
#        [1.32073432e-01],
#        [1.55614996e+00],
#        [3.17572498e+00],
#        [1.07017732e+00],
#        [1.02102828e+00],
#        [9.30885673e-02],
#        [4.52796221e-02],
#        [2.11531782e+00],
#        [3.55409801e-01],
#        [7.32211232e-01],
#        [1.12303412e+00],
#        [1.44003779e-01],
#        [1.10552597e+00],
#        [1.02690399e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [2.52064466e-01],
#        [8.01822245e-01],
#        [5.54036736e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [8.32397401e-01],
#        [6.00329220e-01],
#        [0.00000000e+00],
#        [6.66509569e-02],
#        [1.89281332e+00],
#        [4.12464380e-01],
#        [8.97812486e-01],
#        [9.07755375e-01],
#        [6.79485738e-01],
#        [0.00000000e+00],
#        [3.66198748e-01],
#        [3.39437068e-01],
#        [7.23876476e-01],
#        [2.71749318e-01],
#        [7.64727831e-01],
#        [1.47072339e+00],
#        [0.00000000e+00],
#        [1.06197202e+00],
#        [1.52082372e+00],
#        [2.51560777e-01],
#        [1.11638403e+00],
#        [1.56701446e+00],
#        [2.78311968e-03],
#        [1.44045627e+00],
#        [5.76872468e-01],
#        [2.80169845e-01],
#        [1.85448468e-01],
#        [8.41235995e-01],
#        [0.00000000e+00],
#        [1.82539666e+00],
#        [7.41842747e-01],
#        [0.00000000e+00],
#        [3.03836972e-01],
#        [1.73608947e+00],
#        [7.80520439e-02],
#        [7.89767981e-01],
#        [1.11132860e-03],
#        [3.92910123e-01],
#        [0.00000000e+00],
#        [1.18698239e-01],
#        [8.34651291e-02],
#        [0.00000000e+00],
#        [4.07827586e-01],
#        [4.46635425e-01],
#        [5.05022943e-01],
#        [0.00000000e+00],
#        [5.79853773e-01],
#        [8.35107684e-01],
#        [0.00000000e+00],
#        [2.14497709e+00],
#        [0.00000000e+00],
#        [2.87801057e-01],
#        [8.49698663e-01],
#        [1.37880832e-01],
#        [5.52208841e-01],
#        [0.00000000e+00],
#        [8.72319937e-01],
#        [0.00000000e+00],
#        [1.10786772e+00],
#        [1.07290459e+00],
#        [0.00000000e+00],
#        [8.04504216e-01],
#        [9.25426781e-02],
#        [8.38829994e-01],
#        [6.29602671e-01],
#        [0.00000000e+00],
#        [4.44426656e-01],
#        [7.63564944e-01],
#        [8.47282708e-02],
#        [0.00000000e+00],
#        [3.23613852e-01],
#        [4.81191278e-02],
#        [8.82731915e-01],
#        [8.10191631e-02],
#        [1.13043809e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [9.01401579e-01],
#        [0.00000000e+00],
#        [6.82080507e-01],
#        [1.04932368e-01],
#        [0.00000000e+00],
#        [3.05793524e+00],
#        [1.94988638e-01],
#        [2.23785639e-02],
#        [8.55953753e-01],
#        [1.95465356e-01],
#        [1.17747128e-01],
#        [8.72582674e-01],
#        [8.72108638e-02],
#        [6.79377615e-01],
#        [9.27886486e-01],
#        [8.38546753e-02],
#        [2.82335311e-01],
#        [6.85845375e-01],
#        [1.07522935e-01],
#        [2.41961217e+00],
#        [8.37027550e-01],
#        [5.98405004e-02],
#        [1.01931930e+00],
#        [1.01666415e+00],
#        [4.73390579e-01],
#        [0.00000000e+00],
#        [3.68162304e-01],
#        [8.59623849e-01],
#        [1.55991817e+00],
#        [4.41600233e-01],
#        [8.20508599e-01],
#        [1.57350063e+00],
#        [0.00000000e+00],
#        [2.28660631e+00],
#        [0.00000000e+00],
#        [2.93531001e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [6.61293685e-01],
#        [5.84117591e-01],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [0.00000000e+00],
#        [1.09330988e+00],
#        [1.19858313e+00],
#        [1.04246438e-01],
#        [1.06676054e+00],
#        [2.07142234e-02],
#        [8.65851581e-01],
#        [4.37581122e-01],
#        [3.29748034e-01],
#        [1.14751387e+00],
#        [5.14091849e-01],
#        [5.85771501e-01],
#        [9.17689145e-01],
#        [8.35654616e-01],
#        [2.91855526e+00],
#        [1.52846813e-01]], dtype=float32)

# %%
numload = 10000
feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
feed_pc[0]
# Out:
# array([[ 0.017118  ,  0.19660918],
#        [ 0.017118  ,  0.19660918],
#        [ 0.017118  ,  0.19660918],
#        ...,
#        [-0.3880499 , -0.32016189],
#        [ 0.01924656,  0.57144681],
#        [ 0.63545814,  0.64884996]])

# %%
numpoints = len(jets[0])
Delta_Rs = np.linalg.norm(feed_pc,axis=2)
#    p_parr = np.sum(np.cos(Delta_Rs),axis=1)
np.sum(np.sin(jets[:,:,1]),axis=1)*600/1000
# Out:
# array([ 1.04154646, -1.01855432,  0.82381232,  2.8626084 ,  4.66926383,
#         0.44145631, -0.78976928,  0.42520581, -0.56581046,  7.00944821,
#        -0.0294308 , -1.07126786, -1.61526932, -0.52807492, -0.11218356,
#        12.31053926, -1.94153188, -0.13629966,  1.2301602 , -1.22495414,
#         1.48715351,  0.66155514, -0.25137587,  0.2585713 ,  0.59379215,
#         0.61316492,  3.14910778,  0.09642428, 12.5186531 ,  0.95693838,
#         1.4083551 ,  0.16460985, -0.01416972,  1.16919155, -0.13955238,
#        -0.5423792 , -0.71587804,  0.51078518,  0.19862528, -0.3253633 ,
#         6.62082248,  3.83881109, -0.72389678, -0.05940396,  3.14886234,
#        -0.53045421,  0.09860626,  0.27655945,  0.23807206, -2.60423897,
#         0.73574803,  0.37317332,  1.43749019, -0.45112478, -0.37274221,
#         0.76862296,  3.13978595,  0.17130608, -0.19702835,  2.82923504,
#         0.23081686, -0.2364088 ,  6.86463026,  1.0664655 ,  0.46326879,
#         2.82499946,  0.27885064,  3.50456043,  2.10245745,  1.76229868,
#         1.78779817,  0.07763941,  7.35550224,  0.74356322, -0.01826497,
#         4.56115388,  1.61097018, -0.51655204,  1.4049577 ,  0.81708419,
#        -0.10938158, -0.53901616, -0.0606621 ,  1.75859268, -0.21197403,
#         0.52744096, -0.09505115,  0.28208335,  0.20719031,  0.75428567,
#         3.40008808,  7.48347856,  1.63698554,  0.02191812, -1.09407387,
#         1.68435453,  0.90205874,  0.65809958, -0.45938392,  0.29595829])

# %%
jets[:,:,0]
# Out:
# array([[ 0.01869681,  0.01869681,  0.01869681, ..., -0.23907139,
#         -0.09400195, -0.65201326],
#        [ 0.01031599,  0.01031599,  0.01031599, ...,  0.03088808,
#          0.28167166,  0.82886674],
#        [ 0.00961767,  0.00961767,  0.00961767, ...,  0.17601627,
#         -0.60450113, -0.11882481],
#        ...,
#        [ 0.00723219,  0.00723219,  0.00723219, ...,  0.24995147,
#          0.08002635, -0.34747694],
#        [ 0.03372887,  0.03372887,  0.03372887, ...,  0.01355405,
#          0.27136203,  0.16863137],
#        [ 0.01648945,  0.01648945,  0.01648945, ...,  0.48698032,
#          0.45907187,  0.58905874]])

# %%
plt.hist(jet_masses(feed_pc), bins=np.arange(0,500,20))
plt.show()

# %%
jets = feed_pc
numpoints = len(jets[0])
Delta_Rs = np.linalg.norm(feed_pc,axis=2)
p_parr = np.sum(np.cos(Delta_Rs))
masses = np.sqrt(numpoints**2 - np.power(p_parr,2))*p_norm/numpoints
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in sqrt
#   """

# %%
p_parr
# Out:
# 96376.95345754223

# %%
np.cos(3.14)
# Out:
# -0.9999987317275395

# %%
numload = 1000
feed_pc, feed_model_names, _ = valid_pc_data.next_batch(numload )
#reconstructions = ae.reconstruct(feed_pc)[0]
latent_codes = ae.transform(feed_pc)

# %%
jet_masses(feed_pc[(latent_codes ==0.).flatten()])
# Out:
# array([ 35.28688225,  93.1821818 ,  68.674639  ,  66.82980052,
#         74.14441173,  34.51399374,  69.14875579,  36.95418762,
#         58.10141722,  35.03645862,  59.17256632,  46.93591623,
#         65.7136201 ,  58.5225264 ,  49.73832894,  41.92313558,
#         81.62550544,  81.31715223,  61.86501389,  70.09262545,
#         55.00411739,  50.09787022,  56.01598295,  41.08508213,
#         37.45209645,  26.12286477,  46.64123251,  33.62808724,
#         76.62201858,  59.6882946 ,  97.54313234,  61.19816435,
#         27.00050637,  52.88769576,  93.3634272 ,  69.40321466,
#         32.31190283,  47.50241584,  80.27918911,  80.08367439,
#         86.4246068 ,  59.84014424,  73.06503657,  35.90446185,
#         70.4502928 ,  52.35135732,  62.28219444,  27.45181723,
#         56.91367661,  37.44571713,  43.88163728,  56.53454517,
#         91.66736612,  48.45572223,  55.14218424,  26.93894511,
#         59.53523344,  90.1539713 ,  43.64649611,  49.89533825,
#         65.84580757,  42.11258539,  97.3171227 ,  45.04015666,
#         46.21149635,  71.63280443,  36.14872306,  61.65227236,
#         45.54911287,  37.93193813,  54.78876747,  34.71695685,
#        100.02645786,  68.21195162,  75.768582  ,  51.56694665,
#         40.00198564,  43.23367958,  70.44861527, 101.19563627,
#         41.73448593,  31.39235417,  54.61747945,  56.4572098 ,
#         51.54040873,  67.94888728,  37.51586475,  42.78711439,
#         80.11819091,  51.86788966,  48.34883333,  91.84683399,
#         45.77275205,  39.92642275,  52.75218904,  47.32243419,
#         55.98520083,  82.68766854,  45.61003702,  42.7051605 ,
#         60.22818747,  74.57660678,  66.25466975,  39.864538  ,
#         39.86681393,  25.90240572,  48.60932759,  90.54353159,
#         67.84688184,  40.00981836,  59.90611129,  49.75137847,
#         76.0041969 ,  33.55803456,  66.79866087,  69.21268003,
#         33.83956797,  23.40577664,  42.52865609,  71.8177223 ,
#         56.59952514,  48.94900377,  52.27414965,  61.24064454,
#         81.51764542,  60.81839655,  49.96314163, 110.46750154,
#         65.12068263,  41.34715175,  46.86050114,  52.28805766,
#         23.41105657,  92.60821602,  71.80767413,  52.05142282,
#         51.70879551,  63.96617024,  36.92808492,  43.20384962,
#         57.03148588,  51.16910368,  85.1407818 ,  34.68172351,
#         19.54053885,  57.55029557,  42.38512005,  43.45997926,
#         68.09668215,  66.77180648,  72.62217626,  36.31502032,
#         53.87678934, 100.92803828,  58.88627974,  64.37792831,
#         49.10851287,  37.38773483,  26.64621837,  42.12888596,
#         38.51362378,  51.34929142,  54.24228687,  45.32238571,
#         35.57858911,  40.42293558,  36.19864913,  62.66984304,
#         93.30993071,  31.51732052,  72.83016654,  76.49838461,
#         59.13718956,  60.04609675,  49.96580297,  33.33030191,
#         36.12848431,  72.84062346,  67.86850581,  81.62057131,
#         74.68857538,  50.22673152,  42.39591083,  26.44911897,
#         90.2626258 ,  27.61483219,  52.97737403,  68.28025919,
#         26.62486653,  75.40507966,  72.18536944,  55.31051795,
#         30.23830252,  66.33369862,  42.95643726,  76.28329998,
#         46.80120154,  47.67915222,  55.28590597,  53.9225991 ,
#         44.96265947,  52.51077726,  35.85717445,  35.40481082,
#         52.73402834,  72.54180395,  54.07385799,  54.41453671,
#         50.59149317,  63.87311168,  49.88413271,  45.78044381,
#         32.81126033,  69.93170073,  88.78167012,  50.48067352,
#         55.08690839,  59.65341875,  94.19767128,  37.83855896,
#         49.18986125, 100.74418062,  40.95266265,  43.1785508 ,
#         63.50385505,  29.81875453,  51.94088964,  29.32006456,
#         37.44830469,  63.14469073,  54.0927274 ,  84.97594196,
#         53.52706232,  67.69196318,  41.0681129 ,  67.14905404,
#         45.08989077,  42.39043337,  85.20161635,  51.58207432,
#         65.14523471,  67.71167796,  84.81499228,  25.72294655,
#         28.93684888,  62.28044843,  27.43730813,  46.08969156,
#         48.66315166,  31.9231934 ,  54.11525918,  60.91349808,
#         38.66339513,  65.64695387,  51.75131368,  50.75836379,
#         94.48028625,  60.15983962,  29.61289759,  44.01336946,
#         33.76926562,  36.92642324,  35.52348492,  37.53000243,
#         56.7545509 ,  34.82973537,  67.30038014])

# %%
latent_codes[latent_codes ==0.][0]
# Out:
# 0.0

# %%
(latent_codes ==0.)
# Out:
# array([[ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False]])
